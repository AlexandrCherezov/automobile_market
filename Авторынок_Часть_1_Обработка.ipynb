# %% [markdown]
# # Исследование состояния авторынка Казахстана
#
# Заказчик - компания Меркур Авто - ставит задачу:
# - Определить рыночные сегменты на авторынке Казахстанв
# - Разработать маркетинговый план развития компании
#
# Нам предоставлены файлы, содержащие в себе данные за 2019 год:
# - Сведения о продажи автомобилей в Казахстане 2019 год в разрезе месяцев, моделей автомобилей и их комплектаций и года выпуска автомобилей.
#
# **В исследовании:**
# - Произведем автоматизированную загрузку в рабочую папку предоставленных таблиц
# - Выясним, по какому признаку возможно объединение
# - Для каждого принятого признака произведем:
#  - загрузку файлов в тетрадку Юпитера или Коллаба
#  - обработку данных
#  - объединение файлов и получение сводного датафрейма
#  - выгрузку сводных данных в рабочую папку в формате Excel
# - Проведем анализ полученных сводных данных.
#
# **Ход исследования:**
# - Загрузка данных из предоставленных файлов и подготовка их к анализу
# - Изучение общей информации о датафрейме и предобработка данных
# - Исследовательский анализ данных:
#  - Анализ рынка автомобилей Казахстана
#  - Анализ позиции Меркур Авто: внутренная и внешняя среда
# - Выводы и рекомендации

# %% [markdown]
# ## Загрузка и подготовка данных к анализу
#
#
# **Путь к файлу**
#
# [Ссылка на данные](https://disk.yandex.ru/d/-ehmXsTcOM3rUQ).
#
#
#
# Изучим данные и выполним предобработку. Есть ли в данных пропуски и дубликаты? Убедимся, что типы данных во всех колонках соответствуют сохранённым в них значениям.

# %% [markdown]
# Загрузим библиотеку Яндекс.Диск

# %%
pip install yadisk --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Импортируем библиотеки:
# - **pandas**
# - **sys**
# - **IPython.display** для отображения данных
# - **warnings** для отключения предупреждений
# - **yadisk** для работы с данными Яндекс.Диска
# - **os** для управления папками с данными
# - **tqdm** для корректного отображения данных
# - **openpyxl** для работы с таблицами Excel
# - **logging** - для отображения логов
# - **tqdm** - для отображения прцесса вычисления кода
# - **re** - для обрабоьки регулярных выражений
# - **math** - для округления данных float

# %%
# импортируем библиотеки
import pandas as pd
import sys
from IPython.display import display
import os
from tqdm import tqdm
import warnings
from openpyxl import load_workbook
from openpyxl.cell.text import Font, InlineFont
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.styles.numbers import BUILTIN_FORMATS
import yadisk
import logging
import re
import math

# %% [markdown]
# Перейдем в рабочую область

# %%
os.chdir('/home/jovyan/work')

# %% [markdown]
# Введем идентификационные данные для подключения

# %%
from cfg import app_id, secret_id, ya_token

# %% [markdown]
# Получим токен для доступа к Яндекс.диску

# %%
# получаем токен для доступа к яндекс диску


y = yadisk.YaDisk(app_id, secret_id, ya_token)

if y.check_token():
    print("Sucessfully received token!")
else:
    print("Something went wrong. Not sure how though...")
# Out:
# Sucessfully received token!

# %% [markdown]
# Создадим список файлов для загрузки с Яндекс.Диска

# %%
# создаем список файлов для загрузки
list_of_files = []
for el in list(y.listdir('car_market_of_Kazakhstan')):
    if el['path'].endswith('.csv'):
        list_of_files.append(el['path'])
print("\033[34m""\033[1m""Создан список файлов list_of_files")
list_of_files
# Out:
# Создан список файлов list_of_files
# ['disk:/car_market_of_Kazakhstan/auto_kz_2019_датасет.csv']

# %% [markdown]
# ### Для отслеживания работы кода создадим файл `mylog.log`, куда будем сохранять логи.

# %%
logging.basicConfig(
    level=logging.INFO,
    filename = "mylog_cars.log",
    format = "%(asctime)s - %(module)s - %(levelname)s - %(funcName)s: %(lineno)d - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    filemode="w"
    )

logging.info('info')
logging.debug('debug')
logging.warning('warning_message')
logging.error("An ERROR")
logging.critical("A CRITICAL")

# %% [markdown]
# ### Создадим функции

# %% [markdown]
# Создадим функцию `load_files_collab` для загрузки данных в Гугл Коллаб

# %%
def load_files_collab(url_path, file_name):
      Da = gc.open_by_url(url_path)
      Da_df = Da.worksheet(file_name)
      rows = Da_df.get_all_values()
      df= pd.DataFrame.from_records(rows[1:], columns = rows[0])
      #display(df)
      print("\033[34m""\033[1m""Первые строки датафрейма")
      display(df.head(5))
      print("\033[34m""\033[1m""Информация о типах данных")
      print()
      display(df.info())
      print("\033[34m""\033[1m""Доля пропущенных значений ")
      display(round(df.isna().mean() * 100).astype(int))
      return(df)

# %% [markdown]
# Создадим функцию `load_files` для загрузки данных в Юпитер

# %%
def load_files(file_name):
    df= pd.read_csv(file_name, sep = ';')
    print("\033[34m""\033[1m""Первые строки датафрейма")
    display(df.head(5))
    print("\033[34m""\033[1m""Информация о типах данных")
    print()
    display(df.info())
    print("\033[34m""\033[1m""Доля пропущенных значений ")
    display(round(df.isna().mean() * 100).astype(int))
    print("\033[34m""\033[1m""Количество явных дубликатов ")
    display(df.duplicated().sum())
    return(df)

# %% [markdown]
# Создадим функцию `go_to_numeric` для приведения данных к числовому формату

# %%
def go_to_numeric(column_name):
    data[column_name] = pd.to_numeric(data[column_name])

# %% [markdown]
# Функцию `df_download`для выгрузки файлов с наиболее характерными параметрами и целесообразными результатами в форматах:
# - .csv
# - .xlsx

# %%
def df_download(data_name, df_name_xlsx, df_name_csv):

    # Выгрузим файл в формате .csv
    data_name.to_csv(df_name_csv)
    print("\033[34m"'Выгружен файл '"\033[1m", df_name_csv, "\033[0m")

    # Выгрузим файл в папку в формате Excel
    # Воспользуемся функцией to_excel() , для чего ранее мы установили openpyxl, чтобы записывать файлы в Excel.

    workbook = Workbook()
    sheet = workbook.active

    for row in dataframe_to_rows(data_name, header=True):
        sheet.append(row)

    # изменим высоту первой строки
    sheet.row_dimensions[1].height = 30

    # изменим ширину некоторых колонок
    columns_to_change = [chr(i) for i in range(66, 81)]
    for cell in columns_to_change:
        sheet.column_dimensions[cell].width = 12

    # изменим ширину некоторых колонок
    columns_to_change_2 = [chr(i) for i in range(87, 89)] + [chr(i) for i in range(81, 83)]
    for cell in columns_to_change_2:
        sheet.column_dimensions[cell].width = 20

    # сохраним заданную изначально размерность колонок с результатами
    columns_to_save_dim = ['L']
    for cell in columns_to_save_dim:
        for row in range(2, data_name.shape[0]+3):
            row=str(row)
            sheet[cell+row].number_format = '0.0'

    # зададим размерность колонок с датой
    columns_to_save_dim_time = ['D']
    for cell in columns_to_save_dim_time:
        for row in range(2, data_name.shape[0]+3):
            row=str(row)
            sheet[cell+row].number_format = 'dd.mm.yyyy'

    # установим жирный шрифт для ячеек первой колонки
    columns_to_font = ['E']
    for cell in columns_to_font:
        for row in range(2, data_name.shape[0]+3):
            row=str(row)
            sheet[cell+row].font = Font(size=12, bold=True)

    # установим жирный шрифт для ячеек первой строки
    cell_to_change = ['A1','B1','C1','D1','E1','F1','G1','H1','I1','J1','G1','K1','L1','M1','N1','O1'
                     ,'P1','Q1','R1','S1','T1','U1','V1','W1','X1']
    for cell in cell_to_change:
        sheet[cell].font = Font(size=12, bold=True)

    # удалим 2 строку (пустую)
    sheet.delete_rows(2)

    # зафиксируем первую строку при прокрутке по вертикали
    sheet.freeze_panes = 'A2'

    # выгрузим таблицу в рабочую область
    workbook.save(df_name_xlsx)
    print("\033[34m"'Выгружен файл '"\033[1m", df_name_xlsx, "\033[0m")

    return

# %% [markdown]
# ### Загрузка файлов в рабочую папку
#
# Создадим в рабочей области папку для загрузки файлов с Яндекс.Диска и перейдем в нее

# %%
# создаем папку загрузки
load_path = 'car_market_files'
if not os.path.exists(load_path):
    os.mkdir(load_path)
os.chdir(load_path)

# %% [markdown]
# Загрузим (скопируем) файлы с Яндекс.Диска в созданную папку в рабочей области

# %%
# загружаем файлы с яндекс диска
for file in tqdm(list_of_files):
    y.download(file.split(':')[1], file.split('/')[-1])
    #y.download()
print("\033[34m""\033[1m""Файлы загружены в папку в рабочей области car_market_files")
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.03s/it]
# Файлы загружены в папку в рабочей области car_market_files

# %% [markdown]
# Перейдем в рабочую папку

# %%
os.chdir(path="/home/jovyan/work/car_market_files")

# %% [markdown]
# ### Загрузка и изучение данных

# %% [markdown]
# Загрузим в тетрадку файл. Воспользуемся функцией `load_files`
# Заказчик сообщил нам структуру файла
#
# |Название столбца |Что означает |
# |:-----|:----|
# Год | год продажи (2019)
# Месяц | месяц продажи (январь - сентябрь)
# Компания | название автоцентра
# Бренд | название продаваемой марки автомобиля
# Модель | название модели автомобиля
# Модификация | модификация модели автомобиля (удаляем)
# Год выпуска | год производства автомобиля
# Страна-производитель | страна, где произведен автомобиль
# Вид топлива | бензин, дизель, электричество, гибрид
# Объём двигателя л | объем двигателя автомобиля в литрах
# Коробка передач | тип коробки переключения передач (оставляем два варианта: автоматическая, механическая, то есть все что не механика ставим автомат, на DSG, S-Tronic и прочее делить не надо, равно как и количество передач)
# Тип привода | в итоге оставляем RWD - задний привод, FWD - передний привод, 4WD - полный привод, 2WD - все остальное (подключаемый полный привод и где нет четкого указания передний или задний это привод)
# Сегмент | сегмент, к которому относится авто (удаляем)
# Регион | регион продажи
# Наименование дилерского центра | совпадает с компанией - можно удалить
# Тип клиента | юридическое или физическое лицо (в рамках анализа не критично - можно удалить)
# Форма расчета | наличный и безналичный расчет (много пропусков - можно удалять)
# Количество | количество автомобилей в заказе
# Цена USD | цена автомобиля
# Продажа USD | цена заказа (цена авто умноженная на количество и за вычетом скидок если есть)
# Область | область продажи
# Сегментация 2013 | сегмент автомобиля актуальный
# Класс 2013 | класс автомобиля актуальный
# Сегментация Eng | английская сегментация (удаляем)
# Локализация производства | удаляем (совпадает со страной производителем)
# Признаки-категории:
#  |- сегмент
#  |- класс
#  |- тип привода
#  |- коробка передач

# %% [markdown]
# Определим, что будут отображаться все имеющиеся в датафрейме столбцы

# %%
pd.set_option('max_columns', None)

# %% [markdown]
# Загрузим файл из рабочей папки и ознакомимся с ним

# %%
try:
    data = load_files_collab('https://docs.google.com/spreadsheets/d/1mvrRlLTL3U6Gu1HJsPM-b0MhvF6r8uF2MZu4E9NqQgk/edit?usp=sharing', 'innopolistg')
except:
    data = load_files(os.listdir()[0])
# Out:
# Первые строки датафрейма
#     Год   Месяц     Компания Бренд Модель Модификация Год выпуска  \
# 0  2019     Май  Mercur Auto  Audi     A3        TFSI        2018
# 1  2019  Август  Mercur Auto  Audi     A3        TFSI        2018
# 2  2019  Апрель  Mercur Auto  Audi     A4        TFSI        2018
# 3  2019    Июль  Mercur Auto  Audi     A4        TFSI        2018
# 4  2019    Июль  Mercur Auto  Audi     A4        TFSI        2018
#
#   Страна-производитель Вид топлива Объём двиг, л, Коробка передач Тип привода  \
# 0             Германия      Бензин            1,4        S-tronic    передний
# 1             Германия      Бензин            1,4        S-tronic    передний
# 2             Германия      Бензин            1,4        S-Tronic         FWD
# 3             Германия      Бензин            1,4        S-tronic    передний
# 4             Германия      Бензин            1,4        S-tronic    передний
#
#                        Сегмент  Регион Наименование дилерского центра  \
# 0  Легковые автомобили Premium  Алматы             Mercur Auto Алматы
# 1  Легковые автомобили Premium  Алматы             Mercur Auto Алматы
# 2  Легковые автомобили Premium  Алматы             Mercur Auto Алматы
# 3  Легковые автомобили Premium  Алматы             Mercur Auto Алматы
# 4  Легковые автомобили Premium  Алматы             Mercur Auto Алматы
#
#   Тип клиента Форма расчета  Количество Цена, USD Продажа, USD   Область  \
# 0   Физ. Лицо   безналичный         1.0     28115        28115  г.Алматы
# 1    Юр. Лицо      наличный         1.0  32246,99     32246,99  г.Алматы
# 2   Физ. Лицо   безналичный         1.0     32000        32000  г.Алматы
# 3    Юр. Лицо   безналичный         1.0     31929        31929  г.Алматы
# 4   Физ. Лицо      наличный         1.0     31929        31929  г.Алматы
#
#       Сегментация 2013 Класс 2013 Сегментация Eng Локализация производства
# 0  Легковые автомобили    C класс               C                   Импорт
# 1  Легковые автомобили    C класс               C                   Импорт
# 2  Легковые автомобили    D класс               D                   Импорт
# 3  Легковые автомобили    D класс               D                   Импорт
# 4  Легковые автомобили    D класс               D                   Импорт
# Информация о типах данных
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39966 entries, 0 to 39965
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Год                             39966 non-null  int64
#  1   Месяц                           39966 non-null  object
#  2   Компания                        39966 non-null  object
#  3   Бренд                           39966 non-null  object
#  4   Модель                          39966 non-null  object
#  5   Модификация                     36375 non-null  object
#  6   Год выпуска                     39465 non-null  object
#  7   Страна-производитель            39966 non-null  object
#  8   Вид топлива                     36826 non-null  object
#  9   Объём двиг, л,                  35708 non-null  object
#  10  Коробка передач                 36711 non-null  object
#  11  Тип привода                     35677 non-null  object
#  12  Сегмент                         33205 non-null  object
#  13  Регион                          39966 non-null  object
#  14  Наименование дилерского центра  39966 non-null  object
#  15  Тип клиента                     32919 non-null  object
#  16  Форма расчета                   14038 non-null  object
#  17  Количество                      39960 non-null  float64
#  18  Цена, USD                       39966 non-null  object
#  19  Продажа, USD                    39966 non-null  object
#  20  Область                         39966 non-null  object
#  21  Сегментация 2013                39966 non-null  object
#  22  Класс 2013                      39966 non-null  object
#  23  Сегментация Eng                 39966 non-null  object
#  24  Локализация производства        39966 non-null  object
# dtypes: float64(1), int64(1), object(23)
# memory usage: 7.6+ MB
# None
# Доля пропущенных значений
# Год                                0
# Месяц                              0
# Компания                           0
# Бренд                              0
# Модель                             0
# Модификация                        9
# Год выпуска                        1
# Страна-производитель               0
# Вид топлива                        8
# Объём двиг, л,                    11
# Коробка передач                    8
# Тип привода                       11
# Сегмент                           17
# Регион                             0
# Наименование дилерского центра     0
# Тип клиента                       18
# Форма расчета                     65
# Количество                         0
# Цена, USD                          0
# Продажа, USD                       0
# Область                            0
# Сегментация 2013                   0
# Класс 2013                         0
# Сегментация Eng                    0
# Локализация производства           0
# dtype: int64
# Количество явных дубликатов
# 18698

# %%
data['Вид топлива'].unique()
# Out:
# array(['Бензин', 'Дизель', nan, 'дизель ', 'бензин ', 'гибрид', '2',
#        '1,6', '0', 'Электро', 'Электричество'], dtype=object)

# %%
data.loc[(data['Вид топлива'].isna())].count()
# Out:
# Год                               3140
# Месяц                             3140
# Компания                          3140
# Бренд                             3140
# Модель                            3140
# Модификация                       2919
# Год выпуска                       2721
# Страна-производитель              3140
# Вид топлива                          0
# Объём двиг, л,                     324
# Коробка передач                    532
# Тип привода                        550
# Сегмент                            827
# Регион                            3140
# Наименование дилерского центра    3140
# Тип клиента                       1876
# Форма расчета                      468
# Количество                        3140
# Цена, USD                         3140
# Продажа, USD                      3140
# Область                           3140
# Сегментация 2013                  3140
# Класс 2013                        3140
# Сегментация Eng                   3140
# Локализация производства          3140
# dtype: int64

# %% [markdown]
# Ознакомимся с рядом качественных показателей

# %%
print("\033[34m""\033[1m"
    ' Количество уникальных Компаний - ', data['Компания'].nunique(),'\n',
    'Количество уникальных Брендов - ', data['Бренд'].nunique(),'\n',
      'Количество уникальных Регионов - ', data['Регион'].nunique(),'\n',
      'Количество уникальных Областей - ', data['Область'].nunique(),'\n',
    )
# Out:
#  Количество уникальных Компаний -  40
#  Количество уникальных Брендов -  46
#  Количество уникальных Регионов -  26
#  Количество уникальных Областей -  18

# %%
print("\033[34m""\033[1m"
      'Список Регионов - ', data['Регион'].unique(),'\n',
      'Список Областей - ', data['Область'].unique(),'\n')
# Out:
# Список Регионов -  ['Алматы' 'Нур-Султан' 'Усть-Каменогорск' 'Уральск' 'Костанай' 'Павлодар'
#  'Семей' 'Шымкент' 'Актау' 'Атырау' 'Актобе' 'Караганда' 'Петропавловск'
#  'Кокшетау' 'Рудный' 'Кызылорда' 'Тараз' 'Туркестан' 'Талдыкорган'
#  'ЭКСПОРТ' 'Кульсары' 'Каскелен' 'Экибастуз' 'Риддер' 'Сарыагаш'
#  'Зыряновск']
#  Список Областей -  ['г.Алматы' 'г.Нур-Султан' 'Восточно-Казахстанская область'
#  'Западно-Казахстанская область' 'Костанайская область'
#  'Павлодарская область' 'Южно-Казахстанская область'
#  'Мангистауская область' 'Атырауская область' 'Актюбинская область'
#  'Карагандинская область' 'Северо-Казахстанская область'
#  'Акмолинская область' 'Кызылординская область' 'Жамбылская область'
#  'Туркестанская область' 'Алматинская область' 'Экспорт область']

# %% [markdown]
# <div style="border-radius: 45px;border:solid green 7px; padding: 40px">
#
# Отметим, что:
# - общее количество записей - почти 40 тысяч
# - названия столбцов представлены НЕ по правилам хорошего тона
# - в датафрейме 25 столбцов и часть из них неинформативна, можно удалить
# - почти все данные представлены в формате `object`. Потребуется данные в столбце:
#  - `Год выпуска`,	`Объём двиг, л,`,	`Цена, USD`, 	`Продажа, USD` - привести к числовому формату
# - в нескольких столбцах еть пропущенные значения
# - количество явных дубликатов - более 18 тысяч, то есть почти половина записей продублирована.
#     - **По пояснению Заказчика выявленные дубликаты таковыми не являются. Причина здесь в предоставлении неперсонифицированных данных (без указания ID сделки).**
# - в датафрейме представлены:
#     - Количество уникальных Компаний -  40
#     - Количество уникальных Брендов -  46
#     - Количество уникальных Регионов -  26
#     - Количество уникальных Областей -  18

# %% [markdown]
# <div style="border-radius: 45px;border:solid blue 7px; padding: 40px">
#
# pd.reset_option('max_columns')
#
#     для отмены

# %% [markdown]
# <a id="4"></a>
# ## Предварительная обработка данных

# %% [markdown]
# ### Приведем названия столбцов  к "змеиному" виду

# %%
colms = data.columns.str.lower().str.replace(' ', '_').str.replace(',', '').str.replace('-', '_').tolist()
data.columns = colms

# %%
print(data.columns)
# Out:
# Index(['год', 'месяц', 'компания', 'бренд', 'модель', 'модификация',
#        'год_выпуска', 'страна_производитель', 'вид_топлива', 'объём_двиг_л',
#        'коробка_передач', 'тип_привода', 'сегмент', 'регион',
#        'наименование_дилерского_центра', 'тип_клиента', 'форма_расчета',
#        'количество', 'цена_usd', 'продажа_usd', 'область', 'сегментация_2013',
#        'класс_2013', 'сегментация_eng', 'локализация_производства'],
#       dtype='object')

# %% [markdown]
# ### Удалим столбцы, которые не окажут влияния на анализ в соответствии с ТЗ.
# Заказчик в ТЗ довел до нас, что следующие столбцы не окажут влияния на анализ и их можно удалить:
#
# |Название столбца |Что означает |
# |:-----|:----|
# - Модификация | модификация модели автомобиля (удаляем)
# - Сегмент | сегмент, к которому относится авто (удаляем)
# - Наименование дилерского центра | совпадает с компанией - можно удалить
# - Тип клиента | юридическое или физическое лицо (в рамках анализа не критично - можно удалить)
# - Форма расчета | наличный и безналичный расчет (много пропусков - можно удалять)
# - Сегментация Eng | английская сегментация (удаляем)
# - Локализация производства | удаляем (совпадает со страной производителем)
#
# Тем не менее, чтобы не потерять информацию, ознакомимся с содержанием некоторых из них:

# %% [markdown]
# #### Оставим пока `Тип клиента` и `Наименование дилерского центра` - они могут быть востребованы при анализе

# %% [markdown]
# #### Ознакомимся, какие термины присутствуют в столбце `сегмент`, `сегментация_eng` и `класс_2013`

# %%
print(data.сегмент.unique())
# Out:
# ['Легковые автомобили Premium' 'Внедорожники Premium' nan
#  'Легковые автомобили' 'B класс ' 'Среднеразмерные SUV ' 'Внедорожники '
#  'Внедорожники' 'Полноразмерные SUV ' 'Субкомпактные SUV ' 'салон'
#  'Легковые автомобили ' 'B' 'B-SUV' 'C-SUV' 'C' 'D-SUV' 'D' 'MPV' 'LCV'
#  'городской' 'малотоннажные' '16+1' 'VAN' 'Ambulance' 'Шасси'
#  'Крупнотоннажные' 'среднетоннажные'
#  'Промтоварный фургон 4600*2200*2200*40' 'Изотермический фургон'
#  'Изотермический фургон 4600*2200*2200' 'Промтоварный фургон Т25 с б.д.'
#  'борт' 'Промтоварный фургон' 'Промтоварный фургон 4600*2200*2200*25'
#  'Бортовая платформа с тентом'
#  'Изотермический фургон с холодильным оборудованием'
#  'Промтоварный фургон Т40' 'Изотермический фургон 5200*2200*2200*'
#  'Борт 5200*2200*400' 'Промтоварный фургон Т40 с б.д.' 'туристический'
#  '43+1' 'Легковой автомобиль' 'внедорожник' 'пикап'
#  'коммерческий транспорт' 'коммерческие' 'Коммерческие автомобили'
#  'Коммерческие и грузовые' 'Компактные SUV ' 'Легковые' 'Компактные SUV'
#  'SUV ' 'Coupe ' 'седан' 'Грузовой автомобиль' 'C класс ' 'C класс'
#  'D класс ' 'D класс' 'A класс ' 'A класс' 'F класс' 'B класс'
#  'Стандартные SUV ' 'Стандартные SUV' 'Субкомпактные SUV' '#Н/Д'
#  'Развозные автомобили ' 'Развозные автомобили' 'E-Premium'
#  'Полноразмерные SUV Premium' 'F-Premium' 'Среднеразмерные SUV Premium'
#  'Крупнотоннажные грузовики' 'Микроавтобусы' 'Большие автобусы' 'Минивэны'
#  'Compact SUV' 'Medium SUV' 'Large SUV' 'Sportcar' 'Премиум SUV'
#  'premium SUV' 'Премиум SUV ' 'Premium' '0' 'Урал-Кров Авто'
#  'Кристалл Авто' 'БИПЭК Авто' 'ASTER Auto' 'Автоцентр Астэк'
#  'магистральные перевозки' 'E класс ' 'E класс' 'SUV cars'
#  'Среднеразмерные SUV' 'Пикапы ' 'Пикапы' 'Полноразмерные SUV'
#  'Микроавтобусы ' 'Малотоннажные грузовики ' 'Pick-ups' 'Pick-Up'
#  'легковой' 'SUV' 'Борт с тентом 3700*2000*2000' 'Промтоварный фургон Т50'
#  'Малотоннажные грузовики' 'PICKUP' 'sedan' 'автобус'
#  'Изотермический фургон 5900*2200*2200 Стандарт'
#  'Изотермический фургон 5900*2200*2200 Премиум' 'Bus' 'Автобусы' '5doors'
#  '5 door' '5 doors']

# %%
print(sorted(data.сегментация_eng.unique()))
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G2', 'K1', 'K2', 'K3', 'K4', 'L1', 'L2', 'M', 'N', 'O']

# %%
print(sorted(data.класс_2013.unique()))
# Out:
# ['A класс', 'B класс', 'C класс', 'D класс', 'E класс', 'F класс', 'Pick-ups', 'Большие автобусы', 'Компактвэн', 'Компактные SUV', 'Крупнотоннажные грузовики', 'Малотоннажные грузовики', 'Микроавтобусы', 'Полноразмерные SUV', 'Полноразмерный Минивэн', 'Развозные автомобили', 'Спортивные автомобили', 'Среднеразмерные SUV', 'Среднетоннажные грузовики', 'Средние автобусы', 'Субкомпактные SUV']

# %% [markdown]
# Видим, что в столбцах `сегментация_eng` и `класс_2013` информация совпадает.

# %% [markdown]
# <div style="border-radius: 45px;border:solid green 7px; padding: 40px">
#
# В столбцах `сегментация_eng` и `класс_2013` информация дублируется. причем в последнем информация более разнообразная, более полная. Удалим столбец `сегментация_eng`.
#
# В столбце `сегмент` информация отчасти дублирует информацию столбца `класс_2013`, но и содержит отличительные зарактеристик6, например: 'Изотермический фургон 5200*2200*2200*', 'Борт 5200*2200*400' 'Промтоварный фургон Т40 с б.д.' 'туристический'. Пока оставим этот столбец.

# %% [markdown]
# #### Ознакомимся, какие термины присутствуют в столбце `модификация`

# %%
data['модификация'].unique()
# Out:
# array(['TFSI', 'TFSI Allroad', 'A8L TFSI', ..., 'B3P2M3TX5C', 'V90CC Pro',
#        'KAMAZ 58815Z'], dtype=object)

# %% [markdown]
# <div style="border-radius: 45px;border:solid green 7px; padding: 40px">
#
# В столбце `модификация` может присутствовать информация и виде двигателя, трансмиссии. Пока оставим этот столбец.

# %% [markdown]
# #### Удалим столбцы, которые не окажут влияния на анализ в соответствии с ТЗ:
# |Название столбца |Что означает |
# |:-----|:----|
# - Форма расчета | наличный и безналичный расчет (много пропусков - можно удалять)
# - Сегментация Eng | английская сегментация (удаляем)
# - Локализация производства | удаляем (совпадает со страной производителем)

# %%
# Номера столбцов под удаление
colms_to_del_num = [-9,-2,-1]

# %%
for i in colms_to_del_num:
    data = data.drop(colms[i], axis=1)
#data.columns

# %% [markdown]
# ### Приведем к числовому формату столбцы:
# -  `год_выпуска`, `объём_двиг_л`, `цена_usd`, `продажа_usd`
#
# (ранее -назывались как `Год выпуска`, `Объём двиг, л,`, `Цена, USD`, `Продажа, USD`)

# %%
# зададим список столбцов
col_list_four = ['год_выпуска', 'объём_двиг_л', 'цена_usd', 'продажа_usd']

# %%
for j in col_list_four:
    data[j] = data[j].str.strip().str.replace(',', '.')
    data[j] = data[j].str.replace(' ', '')

# %%
data['год_выпуска'] = data['год_выпуска'].str.replace('2\xa0018', '2018')
data['год_выпуска'] = data['год_выпуска'].str.replace('2\xa0019', '2019')

# %%
#data['год_выпуска'] = data['год_выпуска'].str.replace(' ', '')

# %%
int_cols = ['цена_usd', 'продажа_usd']
for col in int_cols:
    # downcast='signed' приводит данные к минимально возможному типу числовых данных
    data[col] = pd.to_numeric(data[col], downcast='signed')
print(data[int_cols].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39966 entries, 0 to 39965
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   цена_usd     39966 non-null  float64
#  1   продажа_usd  39966 non-null  float64
# dtypes: float64(2)
# memory usage: 624.6 KB
# None

# %% [markdown]
# ### Выведем на экран уникальные значения, указанные в столбце `бренд`

# %%
sorted(data.бренд.unique().astype(str))
# Out:
# ['ANKAI',
#  'Audi',
#  'BMW',
#  'Cadillac',
#  'Chevrolet',
#  'Daewoo',
#  'Dong Feng',
#  'Ford',
#  'Foton',
#  'GAZ',
#  'Hino',
#  'Hyundai',
#  'Hyundai Truck & Bus',
#  'Infiniti',
#  'Isuzu',
#  'Iveco',
#  'Jac',
#  'Jaguar',
#  'KAMAZ',
#  'Kia',
#  'Lada',
#  'Land Rover',
#  'Lexus',
#  'Lifan',
#  'MAN',
#  'Mazda',
#  'Mercedes-Benz',
#  'Mercedes-Benz Trucks',
#  'Mini',
#  'Mitsubishi',
#  'Nefaz',
#  'Nissan',
#  'Peugeot',
#  'Porsche',
#  'Ravon',
#  'Renault',
#  'Scania',
#  'Shacman',
#  'Skoda',
#  'Subaru',
#  'Toyota',
#  'UAZ',
#  'Volkswagen',
#  'Volvo',
#  'Yutong',
#  'Урал']

# %% [markdown]
# Дублирующихся названий брендов не выявлено

# %% [markdown]
# ### Выведем на экран уникальные значения, указанные в столбце `модель`

# %%
sorted(data.модель.unique().astype(str))
# Out:
# ['2206',
#  '2217',
#  '2310',
#  '2705',
#  '2752',
#  '3',
#  '3 серия',
#  '300',
#  '301',
#  '3151',
#  '3221',
#  '32551',
#  '3302',
#  '3303',
#  '3308',
#  '3309',
#  '3741',
#  '3909',
#  '3962',
#  '4308',
#  '4311',
#  '43118',
#  '4320',
#  '4320-1951-40',
#  '4320-1951-60',
#  '43253',
#  '43502',
#  '44108',
#  '45141',
#  '45142',
#  '45143',
#  '4x4',
#  '5 серия',
#  '500',
#  '5299',
#  '53215',
#  '53504',
#  '53605',
#  '54115',
#  '5490',
#  '5557',
#  '58815Z',
#  '6',
#  '6 серия',
#  '65111',
#  '65115',
#  '65116',
#  '65117',
#  '6520',
#  '65206',
#  '65225',
#  '66052',
#  '6606',
#  '7 серия',
#  '8 серия',
#  '911 Carrera S',
#  'A-Class',
#  'A3',
#  'A4',
#  'A6',
#  'A7',
#  'A8',
#  'ASX',
#  'Accent',
#  'Actros',
#  'Almera',
#  'Amarok',
#  'Arkana',
#  'Aveo',
#  'BC 095',
#  'BC 211 MA',
#  'BJ1069VDJEA-F1',
#  'BJ3253DMPKB-AD',
#  'BS 106 A',
#  'BS 106 D',
#  'BWC6665GA5',
#  'C-Class',
#  'C-HR',
#  'CLA-Class',
#  'CLS-Class',
#  'CX-5',
#  'CX-9',
#  'Cabrio',
#  'Caddy Kasten ',
#  'Caddy Maxi Kombi',
#  'Camaro',
#  'Camry',
#  'Captiva',
#  'Caravelle',
#  'Cargo',
#  'Cayenne',
#  'Cerato',
#  'Corolla',
#  'Countryman',
#  'County',
#  'Creta',
#  'D-MAX',
#  'Daily',
#  'Daily A',
#  'Daily V',
#  'Discovery',
#  'Discovery Sport',
#  'Dokker',
#  'Duster',
#  'E-Class',
#  'E-PACE',
#  'ES',
#  'EX8',
#  'Eclipse Cross',
#  'Elantra',
#  'Escalade',
#  'F-Pace',
#  'F-Type',
#  'Fiesta',
#  'Forester',
#  'G-Class',
#  'G-Series',
#  'GLA-Class',
#  'GLC Coupe',
#  'GLC-Class',
#  'GLE Coupe',
#  'GLE-Class',
#  'GLS-Class',
#  'GX',
#  'Granta',
#  'H350',
#  'HD 160',
#  'HD 170',
#  'HD 35',
#  'HD 65',
#  'HD 78',
#  'HD 79',
#  'HF-D105',
#  'HFF6124G03EV3',
#  'HFF6127GZ-4',
#  'HFF6850G',
#  'HIGHLANDER',
#  'HILUX DC',
#  'Hatch',
#  'I-Pace',
#  'Jetta',
#  'Juke',
#  'Kalina',
#  'Kaptur',
#  'Kodiaq',
#  'Koleos',
#  'LC Prado',
#  'LC200',
#  'LS',
#  'LX',
#  'Largus',
#  'Legacy',
#  'Logan',
#  'MYWAY',
#  'Macan',
#  'Master',
#  'Mondeo',
#  'Multivan',
#  'Murano',
#  'Murman',
#  'N120',
#  'N56',
#  'N75',
#  'NMR',
#  'NMS85',
#  'NPR',
#  'NPS',
#  'NQR',
#  'NX',
#  'Nexia R3',
#  'Next',
#  'Niva',
#  'Octavia',
#  'Optima',
#  'Outback',
#  'Outlander',
#  'P-Series',
#  'Pajero IV',
#  'Pajero Sport',
#  'Panamera',
#  'Partner Panel Van',
#  'Patriot',
#  'Patriot Pickup',
#  'Picanto',
#  'Polo',
#  'Q5',
#  'Q50',
#  'Q7',
#  'Q8',
#  'QX50',
#  'QX60',
#  'QX80',
#  'Qashqai',
#  'Quoris',
#  'R-Series',
#  'R4',
#  'RAV4',
#  'RS5',
#  'RX',
#  'RXH',
#  'Range Rover',
#  'Range Rover Evoque',
#  'Range Rover Sport',
#  'Range Rover Velar',
#  'Rapid',
#  'Rio',
#  'S-Class',
#  'S-Series',
#  'S3',
#  'S5',
#  'S7',
#  'S90',
#  'SX3258DR384',
#  'Sandero',
#  'Santa Fe',
#  'Setra',
#  'Solano',
#  'Sonata',
#  'Sorento',
#  'Soul',
#  'Sportage',
#  'Sprinter',
#  'Stinger',
#  'Stralis',
#  'Superb',
#  'T6',
#  'TG',
#  'TQ-1/H-1',
#  'Tahoe',
#  'Teramont',
#  'Terrano',
#  'Tiguan',
#  'Tipper',
#  'Touareg',
#  'Tourismo',
#  'Tracker',
#  'Transporter',
#  'Transporter Kasten',
#  'Transporter Kombi ',
#  'Traverse',
#  'Tucson',
#  'UX',
#  'Universe',
#  'V-Class',
#  'V90',
#  'Vesta',
#  'Vito',
#  'X-Trail',
#  'X1',
#  'X2',
#  'X200',
#  'X3',
#  'X4',
#  'X5',
#  'X50',
#  'X6',
#  'X60',
#  'X7',
#  'X70',
#  'XC40',
#  'XC60',
#  'XC90',
#  'XE',
#  'XF',
#  'XJ',
#  'XRAY',
#  'XT5',
#  'XV',
#  'Z4',
#  'ZK6108HGH',
#  'i8',
#  'iev',
#  'ВИС']

# %% [markdown]
# Дублирующихся названий брендов не выявлено

# %% [markdown]
# ### Обработака данных в столбце `вид_топлива`
# Выведем на экран уникальные значения, указанные в столбце `вид_топлива`

# %%
sorted(data.вид_топлива.unique().astype(str))
# Out:
# ['0',
#  '1,6',
#  '2',
#  'nan',
#  'Бензин',
#  'Дизель',
#  'Электричество',
#  'Электро',
#  'бензин ',
#  'гибрид',
#  'дизель ']

# %% [markdown]
# "Почистим" данные:
# - '0', '1,6', '2'
#     - проверим строки, насколько соответствует отображение данных по столбцам
#     - найдем марку и модель автомобиля и найдем в интернете соответствующий вид топлива
# - nan -   найдем марку и модель автомобиля и найдем в интернете соответствующий вид топлива
# - приведем данные к единообразию

# %% [markdown]
# #### Для значений '0', '1,6', '2'
# - проверим строки, насколько соответствует отображение данных по столбцам
# - найдем марку и модель автомобиля и найдем в интернете коответствующий объем двигателя

# %%
data.query('вид_топлива == "0"')
# Out:
#         год   месяц    компания бренд модель модификация год_выпуска  \
# 37121  2019  Январь  БИПЭК АВТО   UAZ   3741        3741        2018
# 37122  2019  Январь  БИПЭК АВТО   UAZ   3741        3741        2018
# 37123  2019  Январь  БИПЭК АВТО   UAZ   3741        3741        2018
#
#        страна_производитель вид_топлива объём_двиг_л коробка_передач  \
# 37121  Республика Казахстан           0        2.693            5 МТ
# 37122  Республика Казахстан           0        2.693            5 МТ
# 37123  Республика Казахстан           0        2.693            5 МТ
#
#       тип_привода                сегмент       регион  \
# 37121      Полный  Развозные автомобили   Талдыкорган
# 37122      Полный  Развозные автомобили        Актобе
# 37123      Полный  Развозные автомобили         Актау
#
#       наименование_дилерского_центра тип_клиента  количество  цена_usd  \
# 37121         БИПЭК АВТО Талдыкорган         NaN         1.0   14200.0
# 37122              БИПЭК АВТО Актобе         NaN         3.0   14200.0
# 37123               БИПЭК АВТО Актау         NaN         2.0   14200.0
#
#        продажа_usd                область         сегментация_2013  \
# 37121      14200.0    Алматинская область  Коммерческие автомобили
# 37122      42600.0    Актюбинская область  Коммерческие автомобили
# 37123      28400.0  Мангистауская область  Коммерческие автомобили
#
#                     класс_2013
# 37121  Малотоннажные грузовики
# 37122  Малотоннажные грузовики
# 37123  Малотоннажные грузовики

# %% [markdown]
# [Сайт](uaz.ru/cars/classic) сообщает нам, что этот автомобиль оснащается (только) бензиновым двигателем.
# Внесем изменения в датафрейм

# %%
data.loc[(data['бренд'] == "UAZ") & (data['модель'] == "3741"), 'вид_топлива'] = 'p'

# %%
data.loc[(data['бренд'] == "UAZ") & (data['модель'] == "3741"), 'вид_топлива'] = \
    data.loc[(data['бренд'] == "UAZ") & (data['модель'] == "3741"), 'вид_топлива'].str.replace('0', 'p')

# %%
data.query('вид_топлива == "1,6"')
# Out:
#         год   месяц        компания    бренд   модель модификация год_выпуска  \
# 23728  2019  Январь  Renault Россия  Renault   Duster     E1FB4JA        2018
# 23733  2019  Январь  Renault Россия  Renault   Duster     E1FB2JA        2018
# 23734  2019  Январь  Renault Россия  Renault   Duster     E0DB2JA        2018
# 23735  2019  Январь  Renault Россия  Renault   Duster     E0DB2JA        2018
# 23736  2019  Январь  Renault Россия  Renault   Duster     E0DB2JA        2018
# 23751  2019  Январь  Renault Россия  Renault   Duster     E0DB2JA        2018
# 23754  2019  Январь  Renault Россия  Renault   Duster     E1FB4JA        2018
# 23763  2019  Январь  Renault Россия  Renault   Duster     E1FB4JA        2018
# 23764  2019  Январь  Renault Россия  Renault   Duster     E1FB4JA        2018
# 24997  2019  Январь  Renault Россия  Renault  Sandero  SXP16PA5RB        2018
# 24998  2019  Январь  Renault Россия  Renault  Sandero   SXP16K5RB        2018
# 24999  2019  Январь  Renault Россия  Renault  Sandero   SXP16K5RB        2018
# 25002  2019  Январь  Renault Россия  Renault  Sandero  SUT16PA5RB        2018
# 25023  2019  Январь  Renault Россия  Renault  Sandero  SXP16PA5RB        2018
#
#        страна_производитель вид_топлива объём_двиг_л коробка_передач  \
# 23728  Российская Федерация         1,6           MT             4WD
# 23733  Российская Федерация         1,6           MT             4WD
# 23734  Российская Федерация         1,6           AT        Передний
# 23735  Российская Федерация         1,6           AT        Передний
# 23736  Российская Федерация         1,6           AT        Передний
# 23751  Российская Федерация         1,6           AT        Передний
# 23754  Российская Федерация         1,6           MT             4WD
# 23763  Российская Федерация         1,6           MT             4WD
# 23764  Российская Федерация         1,6           MT             4WD
# 24997  Российская Федерация         1,6            0               0
# 24998  Российская Федерация         1,6           MT        Передний
# 24999  Российская Федерация         1,6           MT        Передний
# 25002  Российская Федерация         1,6            0               0
# 25023  Российская Федерация         1,6            0               0
#
#       тип_привода сегмент            регион наименование_дилерского_центра  \
# 23728         4WD       0         Караганда        Кристалл Авто Караганда
# 23733         4WD       0         Караганда        Кристалл Авто Караганда
# 23734    Передний       0         Караганда        Кристалл Авто Караганда
# 23735    Передний       0         Караганда        Кристалл Авто Караганда
# 23736    Передний       0         Караганда        Кристалл Авто Караганда
# 23751    Передний       0  Усть-Каменогорск    БИПЭК АВТО Усть-Каменогорск
# 23754         4WD       0            Алматы              ASTER AUTO Алматы
# 23763         4WD       0        Нур-Султан                Автоцентр Астэк
# 23764         4WD       0     Петропавловск                Автоцентр Астэк
# 24997           0       0            Атырау                 Урал-Кров Авто
# 24998    Передний       0           Уральск                 Урал-Кров Авто
# 24999    Передний       0           Уральск                 Урал-Кров Авто
# 25002           0       0            Атырау                 Урал-Кров Авто
# 25023           0       0        Нур-Султан                Автоцентр Астэк
#
#       тип_клиента  количество     цена_usd  продажа_usd  \
# 23728         NaN         1.0  12249.61125  12249.61125
# 23733         NaN         1.0  12249.61125  12249.61125
# 23734         NaN         1.0  12249.61125  12249.61125
# 23735         NaN         1.0  12249.61125  12249.61125
# 23736         NaN         1.0  12249.61125  12249.61125
# 23751         NaN         1.0  12249.61125  12249.61125
# 23754         NaN         1.0  12249.61125  12249.61125
# 23763         NaN         1.0  12249.61125  12249.61125
# 23764         NaN         1.0  12249.61125  12249.61125
# 24997         NaN         1.0  12476.89637  12476.89637
# 24998         NaN         1.0  12476.89637  12476.89637
# 24999         NaN         1.0  12476.89637  12476.89637
# 25002         NaN         1.0  12476.89637  12476.89637
# 25023         NaN         1.0  12476.89637  12476.89637
#
#                               область     сегментация_2013         класс_2013
# 23728          Карагандинская область         Внедорожники  Субкомпактные SUV
# 23733          Карагандинская область         Внедорожники  Субкомпактные SUV
# 23734          Карагандинская область         Внедорожники  Субкомпактные SUV
# 23735          Карагандинская область         Внедорожники  Субкомпактные SUV
# 23736          Карагандинская область         Внедорожники  Субкомпактные SUV
# 23751  Восточно-Казахстанская область         Внедорожники  Субкомпактные SUV
# 23754                        г.Алматы         Внедорожники  Субкомпактные SUV
# 23763                    г.Нур-Султан         Внедорожники  Субкомпактные SUV
# 23764    Северо-Казахстанская область         Внедорожники  Субкомпактные SUV
# 24997              Атырауская область  Легковые автомобили            B класс
# 24998   Западно-Казахстанская область  Легковые автомобили            B класс
# 24999   Западно-Казахстанская область  Легковые автомобили            B класс
# 25002              Атырауская область  Легковые автомобили            B класс
# 25023                    г.Нур-Султан  Легковые автомобили            B класс

# %% [markdown]
# [Сайт](https://www.drom.ru/catalog/renault/duster/320471/) сообщает нам, что этот автомобиль Renault модели Duster оснащается (только) бензиновым двигателем.
# Внесем изменения в датафрейм

# %%
data.loc[(data['бренд'] == "Renault") & (data['модель'] == "Duster")\
        & (data['вид_топлива'] == "1,6"), 'вид_топлива'] = 'p'

# %% [markdown]
# Для автомобиля Renault модели Sandero столбцы 'объём_двиг_л' и 'коробка_передач' "съехали" влево на одну позицию - исправим это. **Забегая вперед внесем исправления во всем датафрейме**
# Данные из столбца 'вид_топлива' потеряны.
# [Сайт](https://www.drom.ru/catalog/renault/sandero/211452/) сообщает нам, что этот автомобиль Renault модели Sandero оснащается (только) бензиновым двигателем.
# Внесем изменения в датафрейм.

# %%
data.loc[(data['объём_двиг_л'] == "MT") | (data['объём_двиг_л'] == "AT"), 'коробка_передач'] = \
    data.loc[(data['объём_двиг_л'] == "MT") | (data['объём_двиг_л'] == "AT"), 'объём_двиг_л']

# %%
data.loc[(data['объём_двиг_л'] == "MT") | (data['объём_двиг_л'] == "AT"), 'объём_двиг_л'] = \
    data.loc[(data['объём_двиг_л'] == "MT") | (data['объём_двиг_л'] == "AT"), 'вид_топлива']

# %%
data.loc[(data['бренд'] == "Renault") & (data['модель'] == "Sandero")\
        & (data['вид_топлива'] == "1,6"), 'вид_топлива'] = 'Бензин'

# %%
data.query('вид_топлива == "2"')
# Out:
#         год   месяц        компания    бренд  модель модификация год_выпуска  \
# 23723  2019  Январь  Renault Россия  Renault  Duster     E2GB4AG        2019
# 23724  2019  Январь  Renault Россия  Renault  Duster    E2GB4AGA        2018
# 23725  2019  Январь  Renault Россия  Renault  Duster    E2GB4AGA        2018
# 23726  2019  Январь  Renault Россия  Renault  Duster    E2GB4AGA        2018
# 23727  2019  Январь  Renault Россия  Renault  Duster     E2GB4AG        2018
# 23729  2019  Январь  Renault Россия  Renault  Duster    E1FB4AGA        2018
# 23730  2019  Январь  Renault Россия  Renault  Duster    E1FB4AGA        2018
# 23731  2019  Январь  Renault Россия  Renault  Duster     E1FB4AG        2018
# 23732  2019  Январь  Renault Россия  Renault  Duster     E1FB4AG        2018
# 23746  2019  Январь  Renault Россия  Renault  Duster   E2PGB4AGA        2018
# 23747  2019  Январь  Renault Россия  Renault  Duster     E2GB4AG        2018
# 23748  2019  Январь  Renault Россия  Renault  Duster    E1FB4AGA        2018
# 23749  2019  Январь  Renault Россия  Renault  Duster    E1FB4AGA        2018
# 23750  2019  Январь  Renault Россия  Renault  Duster    E1FB4AGA        2018
# 23752  2019  Январь  Renault Россия  Renault  Duster   E2PGB4AGA        2018
# 23753  2019  Январь  Renault Россия  Renault  Duster    E2GB4AGA        2018
# 23755  2019  Январь  Renault Россия  Renault  Duster     E1FB4AG        2018
# 23758  2019  Январь  Renault Россия  Renault  Duster   E2PGB4AGA        2018
# 23759  2019  Январь  Renault Россия  Renault  Duster    E2GB4AGA        2018
# 23760  2019  Январь  Renault Россия  Renault  Duster    E2GB4AGA        2018
# 23761  2019  Январь  Renault Россия  Renault  Duster    E2GB4AGA        2018
# 23762  2019  Январь  Renault Россия  Renault  Duster    E2GB4AGA        2018
# 23765  2019  Январь  Renault Россия  Renault  Duster     E1FB4AG        2018
#
#        страна_производитель вид_топлива объём_двиг_л коробка_передач  \
# 23723  Российская Федерация           2            2              MT
# 23724  Российская Федерация           2            2              AT
# 23725  Российская Федерация           2            2              AT
# 23726  Российская Федерация           2            2              AT
# 23727  Российская Федерация           2            2              MT
# 23729  Российская Федерация           2            2              AT
# 23730  Российская Федерация           2            2              AT
# 23731  Российская Федерация           2            2              MT
# 23732  Российская Федерация           2            2              MT
# 23746  Российская Федерация           2            2              AT
# 23747  Российская Федерация           2            2              MT
# 23748  Российская Федерация           2            2              AT
# 23749  Российская Федерация           2            2              AT
# 23750  Российская Федерация           2            2              AT
# 23752  Российская Федерация           2            2              AT
# 23753  Российская Федерация           2            2              AT
# 23755  Российская Федерация           2            2              MT
# 23758  Российская Федерация           2            2              AT
# 23759  Российская Федерация           2            2              AT
# 23760  Российская Федерация           2            2              AT
# 23761  Российская Федерация           2            2              AT
# 23762  Российская Федерация           2            2              AT
# 23765  Российская Федерация           2            2              MT
#
#       тип_привода сегмент            регион наименование_дилерского_центра  \
# 23723         4WD       0           Уральск                 Урал-Кров Авто
# 23724         4WD       0        Нур-Султан           Кристалл Авто Астана
# 23725         4WD       0        Нур-Султан           Кристалл Авто Астана
# 23726         4WD       0         Кызылорда        Кристалл Авто Кызылорда
# 23727         4WD       0         Караганда        Кристалл Авто Караганда
# 23729         4WD       0         Караганда        Кристалл Авто Караганда
# 23730         4WD       0         Караганда        Кристалл Авто Караганда
# 23731         4WD       0         Караганда        Кристалл Авто Караганда
# 23732         4WD       0         Караганда        Кристалл Авто Караганда
# 23746         4WD       0  Усть-Каменогорск    БИПЭК АВТО Усть-Каменогорск
# 23747         4WD       0  Усть-Каменогорск    БИПЭК АВТО Усть-Каменогорск
# 23748         4WD       0           Шымкент             БИПЭК АВТО Шымкент
# 23749         4WD       0           Шымкент             БИПЭК АВТО Шымкент
# 23750         4WD       0           Шымкент             БИПЭК АВТО Шымкент
# 23752         4WD       0            Алматы              ASTER AUTO Алматы
# 23753         4WD       0            Алматы              ASTER AUTO Алматы
# 23755         4WD       0            Алматы              ASTER AUTO Алматы
# 23758         4WD       0        Нур-Султан                Автоцентр Астэк
# 23759         4WD       0        Нур-Султан                Автоцентр Астэк
# 23760         4WD       0        Нур-Султан                Автоцентр Астэк
# 23761         4WD       0          Костанай                Автоцентр Астэк
# 23762         4WD       0        Нур-Султан                Автоцентр Астэк
# 23765         4WD       0        Нур-Султан                Автоцентр Астэк
#
#       тип_клиента  количество     цена_usd  продажа_usd  \
# 23723         NaN         1.0  12249.61125  12249.61125
# 23724         NaN         1.0  12249.61125  12249.61125
# 23725         NaN         1.0  12249.61125  12249.61125
# 23726         NaN         1.0  12249.61125  12249.61125
# 23727         NaN         1.0  12249.61125  12249.61125
# 23729         NaN         1.0  12249.61125  12249.61125
# 23730         NaN         1.0  12249.61125  12249.61125
# 23731         NaN         1.0  12249.61125  12249.61125
# 23732         NaN         1.0  12249.61125  12249.61125
# 23746         NaN         1.0  12249.61125  12249.61125
# 23747         NaN         1.0  12249.61125  12249.61125
# 23748         NaN         1.0  12249.61125  12249.61125
# 23749         NaN         1.0  12249.61125  12249.61125
# 23750         NaN         1.0  12249.61125  12249.61125
# 23752         NaN         1.0  12249.61125  12249.61125
# 23753         NaN         1.0  12249.61125  12249.61125
# 23755         NaN         1.0  12249.61125  12249.61125
# 23758         NaN         1.0  12249.61125  12249.61125
# 23759         NaN         1.0  12249.61125  12249.61125
# 23760         NaN         1.0  12249.61125  12249.61125
# 23761         NaN         1.0  12249.61125  12249.61125
# 23762         NaN         1.0  12249.61125  12249.61125
# 23765         NaN         1.0  12249.61125  12249.61125
#
#                               область сегментация_2013         класс_2013
# 23723   Западно-Казахстанская область     Внедорожники  Субкомпактные SUV
# 23724                    г.Нур-Султан     Внедорожники  Субкомпактные SUV
# 23725                    г.Нур-Султан     Внедорожники  Субкомпактные SUV
# 23726          Кызылординская область     Внедорожники  Субкомпактные SUV
# 23727          Карагандинская область     Внедорожники  Субкомпактные SUV
# 23729          Карагандинская область     Внедорожники  Субкомпактные SUV
# 23730          Карагандинская область     Внедорожники  Субкомпактные SUV
# 23731          Карагандинская область     Внедорожники  Субкомпактные SUV
# 23732          Карагандинская область     Внедорожники  Субкомпактные SUV
# 23746  Восточно-Казахстанская область     Внедорожники  Субкомпактные SUV
# 23747  Восточно-Казахстанская область     Внедорожники  Субкомпактные SUV
# 23748      Южно-Казахстанская область     Внедорожники  Субкомпактные SUV
# 23749      Южно-Казахстанская область     Внедорожники  Субкомпактные SUV
# 23750      Южно-Казахстанская область     Внедорожники  Субкомпактные SUV
# 23752                        г.Алматы     Внедорожники  Субкомпактные SUV
# 23753                        г.Алматы     Внедорожники  Субкомпактные SUV
# 23755                        г.Алматы     Внедорожники  Субкомпактные SUV
# 23758                    г.Нур-Султан     Внедорожники  Субкомпактные SUV
# 23759                    г.Нур-Султан     Внедорожники  Субкомпактные SUV
# 23760                    г.Нур-Султан     Внедорожники  Субкомпактные SUV
# 23761            Костанайская область     Внедорожники  Субкомпактные SUV
# 23762                    г.Нур-Султан     Внедорожники  Субкомпактные SUV
# 23765                    г.Нур-Султан     Внедорожники  Субкомпактные SUV

# %% [markdown]
# [Сайт](https://www.drom.ru/catalog/renault/duster/2018/#russia) сообщает нам, что этот автомобиль Renault модели Duster  оснащается (только) бензиновым двигателем.
# Внесем изменения в датафрейм

# %%
data.loc[(data['бренд'] == "Renault") & (data['модель'] == "Duster")\
        & (data['вид_топлива'] == "2"), 'вид_топлива'] = 'p'

# %% [markdown]
# #### Для значений `nan`
# - найдем марку и модель автомобиля и найдем в интернете коответствующий объем двигателя

# %% [markdown]
# <div style="border-radius: 45px;border:solid red 7px; padding: 40px">
#
# Сюда применитьь моду

# %%
data.loc[(data['вид_топлива'].isna())]#.head()
# Out:
#         год     месяц        компания    бренд          модель  \
# 861    2019      Март           СемАЗ    Foton  BJ3253DMPKB-AD
# 862    2019      Июнь           СемАЗ    Foton  BJ3253DMPKB-AD
# 863    2019      Июнь           СемАЗ    Foton  BJ3253DMPKB-AD
# 864    2019      Июль           СемАЗ    Foton  BJ3253DMPKB-AD
# 865    2019    Август           СемАЗ    Foton  BJ3253DMPKB-AD
# ...     ...       ...             ...      ...             ...
# 39943  2019  Сентябрь  Renault Россия  Renault          Arkana
# 39944  2019  Сентябрь  Renault Россия  Renault          Arkana
# 39945  2019  Сентябрь  Renault Россия  Renault          Arkana
# 39946  2019  Сентябрь  Renault Россия  Renault          Arkana
# 39947  2019  Сентябрь  Renault Россия  Renault          Arkana
#
#                                              модификация год_выпуска  \
# 861    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2019
# 862    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2018
# 863    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2018
# 864    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2018
# 865    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2018
# ...                                                  ...         ...
# 39943                                         B3P4M3TX5C        2019
# 39944                                          B32M1TX5C        2019
# 39945                                          B32M1TX5C        2019
# 39946                                          B32M1TX5C        2019
# 39947                                          B34M3TX5C        2019
#
#        страна_производитель вид_топлива объём_двиг_л коробка_передач  \
# 861    Республика Казахстан         NaN          NaN             NaN
# 862    Республика Казахстан         NaN          NaN             NaN
# 863    Республика Казахстан         NaN          NaN             NaN
# 864    Республика Казахстан         NaN          NaN             NaN
# 865    Республика Казахстан         NaN          NaN             NaN
# ...                     ...         ...          ...             ...
# 39943  Российская Федерация         NaN          NaN             NaN
# 39944  Российская Федерация         NaN          NaN             NaN
# 39945  Российская Федерация         NaN          NaN             NaN
# 39946  Российская Федерация         NaN          NaN             NaN
# 39947  Российская Федерация         NaN          NaN             NaN
#
#       тип_привода сегмент            регион наименование_дилерского_центра  \
# 861           NaN     NaN            Алматы           Меридиан АВТО Алматы
# 862           NaN     NaN  Усть-Каменогорск                          СемАЗ
# 863           NaN     NaN          Кокшетау                 Вираж Кокшетау
# 864           NaN     NaN            Алматы                   Вираж Алматы
# 865           NaN     NaN            Алматы                          СемАЗ
# ...           ...     ...               ...                            ...
# 39943         NaN     NaN        Нур-Султан           Кристалл Авто Астана
# 39944         NaN     NaN           Уральск                 Урал-Кров Авто
# 39945         NaN     NaN            Атырау                 Урал-Кров Авто
# 39946         NaN     NaN           Уральск                 Урал-Кров Авто
# 39947         NaN     NaN            Атырау                 Урал-Кров Авто
#
#       тип_клиента  количество     цена_usd   продажа_usd  \
# 861           NaN         1.0  48275.86207   48275.86207
# 862           NaN         1.0  49735.91972   49735.91972
# 863           NaN         1.0  48784.39304   48784.39304
# 864           NaN         5.0  48725.42295  243627.11480
# 865           NaN         2.0  31031.65229   62063.30457
# ...           ...         ...          ...           ...
# 39943         NaN         1.0  21327.27747   21327.27747
# 39944         NaN         1.0  20889.17526   20889.17526
# 39945         NaN         1.0  20889.17526   20889.17526
# 39946         NaN         1.0  20889.17526   20889.17526
# 39947         NaN         1.0  21275.77320   21275.77320
#
#                               область         сегментация_2013  \
# 861                          г.Алматы  Коммерческие автомобили
# 862    Восточно-Казахстанская область  Коммерческие автомобили
# 863               Акмолинская область  Коммерческие автомобили
# 864                          г.Алматы  Коммерческие автомобили
# 865                          г.Алматы  Коммерческие автомобили
# ...                               ...                      ...
# 39943                    г.Нур-Султан             Внедорожники
# 39944   Западно-Казахстанская область             Внедорожники
# 39945              Атырауская область             Внедорожники
# 39946   Западно-Казахстанская область             Внедорожники
# 39947              Атырауская область             Внедорожники
#
#                       класс_2013
# 861    Крупнотоннажные грузовики
# 862    Крупнотоннажные грузовики
# 863    Крупнотоннажные грузовики
# 864    Крупнотоннажные грузовики
# 865    Крупнотоннажные грузовики
# ...                          ...
# 39943             Компактные SUV
# 39944             Компактные SUV
# 39945             Компактные SUV
# 39946             Компактные SUV
# 39947             Компактные SUV
#
# [3106 rows x 22 columns]

# %% [markdown]
# Более 3000 записей не имеют данных о виде топлива.
# Какие марки здесь присутствуют?

# %%
data.loc[(data['вид_топлива'].isna()), 'модификация'].unique()
# Out:
# array(['Грузовой автомобиль марки "Foton BJ3253DMPKB-AD" (25 тонн)',
#        'GAZ 23107', 'GAZ 2705', 'GAZ 27055', 'GAZ 27057', 'GAZ 27527',
#        'GAZ 3221', 'GAZ 3302', 'GAZ 33025', 'GAZ 33027', 'GAZ 330202',
#        'GAZ 330232', 'GAZ 330252', 'GAZ 330253', 'GAZ 330273',
#        'GAZ 33086', 'GAZ A63R42', 'GAZ A63R45', 'GAZ A64R45',
#        'GAZ A21R22', 'GAZ A21R23', 'GAZ A21R32', 'GAZ A22R32',
#        'GAZ A22R35', 'GAZ A32R32', 'GAZ A21R33', 'GAZ A21R35',
#        'GAZ A31R23', 'GAZ A31R33', 'GAZ A32R23', 'GAZ A32R33',
#        'GAZ A65R35', 'H350 BUS', 'H350 Ambulance', 'H350 VAN 6.2', nan,
#        'HD 160', 'HD65 Euro 5', 'HD65 Euro 4 KZ', 'Euro 5', 'Euro 4',
#        'HD78 Euro 5', 'HD78/ЕХ8', 'Luxury', 'Universe Luxury', '70C15',
#        '50C15V', '45C15V (Автобус 14+1)', '50С15 (изотермический фургон)',
#        'HighRoof', '6х4', 'Intelligent', 'Luxury 1.6 MT',
#        'Intelligent 1.6 CVT', 'FL Luxury', 'FL Intelligent',
#        'Luxury 2.0 MT5', 'Intelligent 2.0T MT6', 'TGS 26.400 6x4 BLS',
#        'TGS 19.440 4x2 BLS', 'TGX 18.440 4x2 BLS', 'TGS 26.360 6x4 BB',
#        'TGS 26.400 6x4 BLSWW', 'MAZDA 3', 'MAZDA 6', 'MAZDA CX-5',
#        'Active 1.6 AT', 'Active', 'Active 1.6 МТ',
#        'Partner VU Active 1.6 МТ', 'DKGB4AGA', 'DKGB4AG', 'DKGB4JA',
#        'E2PGB4AG', 'E2PGB4AGA', 'E2GB4AGA', 'E1FB2JA', 'E1FB4AG',
#        'E2GB4AG', 'E2GB4JA', 'E0DB2JA', 'E1FB4AGA', 'E0DB4JA', 'Z1FB4AG',
#        'Z2PGB4AG', 'Z2GB4AG', 'Z2PGB4AGA', 'Z2GB4AGA', 'Z1FB4JA',
#        'E1FB4JA', 'Z2GB4JA', 'Z0DB2JA', 'Z1FB4AGA', 'ADGB4AGA', 'ADGB4AG',
#        'Z1FB4MD', 'Z0DB4JA', 'Z1FB2JA', 'ADGB4JA', 'Z2PGB4 AGA  ',
#        'Z2PGB4 AG   ', 'Z2 GB4 MD   ', 'Z2 GB4 AGA  ', 'Z2 GB4 AG   ',
#        'AD GB4 AGA  ', 'AD GB4 AG   ', 'Z2 GB4 JA   ', 'Z1 FB4 JA   ',
#        'Z1 FB4 AG   ', 'Z1 FB2 JA   ', 'Z0 DB2 JA   ', 'AD GB4 JA   ',
#        'E2 GB4 AG   ', 'Z1 FB4 AGA  ', 'ZB34AAA5C', 'ZB22JAX5C',
#        'ZB12JAX5C', 'ZB12JA5C', 'EXT4AAA5C', 'ZB24AA5C', 'ZB32JAX5C',
#        'ZB24AAA5C', 'PLY4AAA5C', 'ZB22JA5C', 'SLB4AA5C', 'EXT4AA5C',
#        'PLY2JAX5C', 'ZB34AA5C', 'EXT2JAX5C', 'MB34AAA5C', 'MB44AAA5C',
#        'MB24AAA5C', 'PLY4AA5C', 'MB32JAX5C', 'MB22JA5C', 'MB12JA5C',
#        'MB34AA5C', 'PLA2JAX5C', 'MB42JAX5C', 'MB12JAX5C', 'MB22JAX5C',
#        'MB4 4 AAA5C ', 'MB4 2 JAX5C ', 'MB1 2 JAX5C ', 'ZB2 2 JA 5C ',
#        'MB3 4 AAA5C ', 'MB3 2 JAX5C ', 'MB2 2 JAX5C ', 'MB2 4 AAA5C ',
#        'MB2 2 JA 5C ', 'GM38 N05C C4', 'ACCA16K5RB', 'SXPA16PA5RB',
#        'SXPA16M5RB', 'EXPA16PA5RB', 'EXPA16K5RB', 'AUTA16PA5RB',
#        'CXPA16MV5RB', 'AUTA16K5RB', 'AUTA16M5RB', 'CUTA16MV5RB',
#        'DYNA16PA5RB', 'SUTA16M5RB', 'DYNA16M5RB', 'SUTA16K5RB',
#        'EXPA16M5RB', 'DYNA16K5RB', 'SUTA16PA5RB', 'ACC16K5RB',
#        'SXPA 16M 5RB', 'EXPA 16PA5RB', 'DYNA 16PA5RB', 'CXPA 16MV5RB',
#        'SXPA 16PA5RB', 'SUTA 16PA5RB', 'CUTA 16MV5RB', 'AUTA 16PA5RB',
#        'SUTA 16M 5RB', 'AUTA 16K 5RB', 'ACCA 16K 5RB', 'EXPA 16K 5RB',
#        'TFGB1 223 D6', 'TFGB1 113 D6', 'TFGB1113D6', 'SUT16M5RB',
#        'STW16PA5RB', 'SMB16K5RB', 'SXP16K5RB', 'EXP16PA5RB', 'SXP16M5RB',
#        'EXP16K5RB', 'SXPA16K5RB', 'EXPA 16M 5RB', 'SXPA 16K 5RB',
#        'SUTA 16K 5RB', 'Hunter 3151', '2360', '23602', 'Caravelle',
#        'Polo PA', 'Tiguan NF', 'Шасси автомобиля Урал 4320-6151-73',
#        'Шасси автомобиля Урал 43206-6151-73',
#        'Грузовой автомобиль Урал 4320-6951-74',
#        'Автомобиль повышенной проходимости для перевозки личного состава. Урал 4320-0111-41',
#        'Грузовой автомобиль 4х4 с бортовой платформой грузоподъемностью от 3000 до 4000 кг на шасси автомоби',
#        'Автомобиль грузовой на базе шасси Урал 4320-1951-72',
#        'Грузовой автомобиль Урал 4320-1951-60',
#        'Самосвал сельхозник двухпозиционный на базе шасси автомобиля Урал 4320-1951-40',
#        'Шасси автомобиля Урал 4320-1951-60',
#        'Грузовой автомобильУрал 5557-4151-82',
#        'Автомобиль грузовой на базе шасси Урал 5557-1112-31',
#        'Mazda CX-9', 'HD35L', 'YFAMBNMVEM', 'YKAMBIMVEM', 'YFBASNMVEM',
#        'YKBASIMVEM', 'YKLAURMVEM', 'YSTEP2MVEM', 'YKLAUR MV EM',
#        'YKBASI MV EM', 'YKAMBI MV EM', 'Шасси для РФ', 'шасси', 'Comfort',
#        'Comfort 2.0 Ti 4x4', 'Comfort 2.0 TDI 4x4',
#        'Автомобиль-самосвал SHACMAN Евро5 модель SX3258DR384',
#        ' Автомобиль-самосвал SHACMAN Евро5 модель SX3258DR384',
#        'Грузовой автомобиль марки "Foton BJ1069VDJEA-F1" ',
#        'Грузовой автомобиль марки "Foton BJ1069VDJEA-F1"',
#        'Автобус Dong Feng BWC6665GA5',
#        'Автобус Dong Feng                   BWC6665GA5', 'Teramont',
#        'HSE', 'Урал 32551-0013-61', 'EX8',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500375',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500374',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500399',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500379',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500369',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500410',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500373',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500413',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500372',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500488',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500354',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500478',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500358',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500350',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500327',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500357',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500351',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500397',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500356',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500402',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500371',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500404',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500370',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500368',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500406',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500412',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500409',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500362',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500408',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500353',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500364',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500401',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500471 2019C000213  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500462 2019B000075  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500455 2019B000058  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500464 2019B000057  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500458 2019B000068  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500453 2019B000174  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500466 2019B000129  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500452 2019B000176  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500470 2019B000051  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500467 2019B000112  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500472 2019C000206  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500460 2019B000109  Белый',
#        'Городской автобус с низким входом (с одной ступенью)  ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500461 2019B000045  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500468 2019C000191  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500457 2019B000071  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500465 2019B000055  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500469 2019C000210  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500454 2019B000062  Белый',
#        'Городской автобус с низким входом (с одной ступенью) ANKAI HFF6850G  MT 5.0L  MXBTBGKD0KK500463 2019B000054  Белый',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500366',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500405',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500414',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500377',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500355',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500380',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500361',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500376',
#        'Diesel 8.5m MT', 'B3P4M3 TX 5C', 'B34 M3 TX 5C', 'B32 M3 TX 5C',
#        'B22M1TX5C', 'B32M1TX5C', 'B12M1TX5C', 'B22M3TX5C', 'B32M3TX5C',
#        'B34M3TX5C', 'B3P4M3TX5C', 'B24M1M65C', 'B3P2M3TX5C'], dtype=object)

# %%
list_of_models = data.loc[(data['вид_топлива'].isna()), 'бренд'].unique()

# %%
len(list_of_models)
# Out:
# 19

# %%
x = 0
for i in list_of_models:
    print('Бренд', i, "Модель", data.loc[(data['вид_топлива'].isna()) & (data['бренд'] == i), 'модель'].unique())

    x = x + len (data.loc[(data['вид_топлива'].isna()) & (data['бренд'] == i), 'модель'].unique())
print('Общее количество моделей без указания вида топлива', x)
# Out:
# Бренд Foton Модель ['BJ3253DMPKB-AD' 'BJ1069VDJEA-F1']
# Бренд GAZ Модель ['2310' '2705' '2752' '3221' '3302' '3308' 'Next']
# Бренд Hyundai Truck & Bus Модель ['H350' 'HD 160' 'HD 65' 'HD 78' 'Universe' 'HD 35' 'EX8']
# Бренд Iveco Модель ['Daily' 'Daily A' 'Daily V' 'Stralis' 'Tipper']
# Бренд Jac Модель ['S3' 'S5' 'N120' 'N75' 'T6' 'N56']
# Бренд Jaguar Модель ['XJ' 'E-PACE' 'I-Pace']
# Бренд Lada Модель ['ВИС']
# Бренд Land Rover Модель ['Discovery Sport' 'Range Rover' 'Range Rover Evoque' 'Range Rover Sport'
#  'Range Rover Velar']
# Бренд MAN Модель ['TG']
# Бренд Mazda Модель ['3' '6' 'CX-5' 'CX-9']
# Бренд Peugeot Модель ['301' 'Partner Panel Van']
# Бренд Renault Модель ['Duster' 'Kaptur' 'Koleos' 'Logan' 'Master' 'Sandero' 'Dokker' 'Arkana']
# Бренд UAZ Модель ['3151' 'Cargo' 'Patriot Pickup']
# Бренд Volkswagen Модель ['Amarok' 'Caravelle' 'Polo' 'Tiguan' 'Touareg' 'Transporter Kasten'
#  'Teramont']
# Бренд Volvo Модель ['XC90' 'XC60']
# Бренд Урал Модель ['4320' '4320-1951-40' '4320-1951-60' '5557' '32551']
# Бренд Shacman Модель ['SX3258DR384']
# Бренд Dong Feng Модель ['BWC6665GA5']
# Бренд ANKAI Модель ['HF-D105' 'HFF6850G']
# Общее количество моделей без указания вида топлива 72

# %%
for i in list_of_models:
    k = data.loc[(data['вид_топлива'].isna()) & (data['бренд'] == i), 'модель']
    m = data.loc[(data['вид_топлива'].isna()) & (data['бренд'] == i), 'объём_двиг_л']
    l = data.loc[(data['вид_топлива'].isna()) & (data['бренд'] == i), 'коробка_передач']
    n = data.loc[(data['вид_топлива'].isna()) & (data['бренд'] == i), 'тип_привода']
    print(k, m, l, n)
# Out:
# 861      BJ3253DMPKB-AD
# 862      BJ3253DMPKB-AD
# 863      BJ3253DMPKB-AD
# 864      BJ3253DMPKB-AD
# 865      BJ3253DMPKB-AD
# 866      BJ3253DMPKB-AD
# 867      BJ3253DMPKB-AD
# 868      BJ3253DMPKB-AD
# 869      BJ3253DMPKB-AD
# 39420    BJ1069VDJEA-F1
# 39421    BJ1069VDJEA-F1
# 39422    BJ1069VDJEA-F1
# 39423    BJ1069VDJEA-F1
# 39424    BJ1069VDJEA-F1
# 39425    BJ1069VDJEA-F1
# 39426    BJ1069VDJEA-F1
# 39427    BJ1069VDJEA-F1
# 39428    BJ1069VDJEA-F1
# 39429    BJ1069VDJEA-F1
# 39430    BJ1069VDJEA-F1
# 39431    BJ1069VDJEA-F1
# 39432    BJ1069VDJEA-F1
# 39433    BJ1069VDJEA-F1
# 39434    BJ1069VDJEA-F1
# 39435    BJ1069VDJEA-F1
# 39436    BJ1069VDJEA-F1
# 39437    BJ1069VDJEA-F1
# 39438    BJ1069VDJEA-F1
# Name: модель, dtype: object 861      NaN
# 862      NaN
# 863      NaN
# 864      NaN
# 865      NaN
# 866      NaN
# 867      NaN
# 868      NaN
# 869      NaN
# 39420    NaN
# 39421    NaN
# 39422    NaN
# 39423    NaN
# 39424    NaN
# 39425    NaN
# 39426    NaN
# 39427    NaN
# 39428    NaN
# 39429    NaN
# 39430    NaN
# 39431    NaN
# 39432    NaN
# 39433    NaN
# 39434    NaN
# 39435    NaN
# 39436    NaN
# 39437    NaN
# 39438    NaN
# Name: объём_двиг_л, dtype: object 861      NaN
# 862      NaN
# 863      NaN
# 864      NaN
# 865      NaN
# 866      NaN
# 867      NaN
# 868      NaN
# 869      NaN
# 39420    NaN
# 39421    NaN
# 39422    NaN
# 39423    NaN
# 39424    NaN
# 39425    NaN
# 39426    NaN
# 39427    NaN
# 39428    NaN
# 39429    NaN
# 39430    NaN
# 39431    NaN
# 39432    NaN
# 39433    NaN
# 39434    NaN
# 39435    NaN
# 39436    NaN
# 39437    NaN
# 39438    NaN
# Name: коробка_передач, dtype: object 861      NaN
# 862      NaN
# 863      NaN
# 864      NaN
# 865      NaN
# 866      NaN
# 867      NaN
# 868      NaN
# 869      NaN
# 39420    NaN
# 39421    NaN
# 39422    NaN
# 39423    NaN
# 39424    NaN
# 39425    NaN
# 39426    NaN
# 39427    NaN
# 39428    NaN
# 39429    NaN
# 39430    NaN
# 39431    NaN
# 39432    NaN
# 39433    NaN
# 39434    NaN
# 39435    NaN
# 39436    NaN
# 39437    NaN
# 39438    NaN
# Name: тип_привода, dtype: object
# 900     2310
# 901     2310
# 1038    2705
# 1039    2705
# 1040    2705
#         ...
# 2686    Next
# 2687    Next
# 2688    Next
# 2689    Next
# 2690    Next
# Name: модель, Length: 234, dtype: object 900     NaN
# 901     NaN
# 1038    NaN
# 1039    NaN
# 1040    NaN
#        ...
# 2686    NaN
# 2687    NaN
# 2688    NaN
# 2689    NaN
# 2690    NaN
# Name: объём_двиг_л, Length: 234, dtype: object 900     Мех.
# 901     Мех.
# 1038    Мех.
# 1039    Мех.
# 1040    Мех.
#         ...
# 2686    Мех.
# 2687    Мех.
# 2688    Мех.
# 2689    Мех.
# 2690    Мех.
# Name: коробка_передач, Length: 234, dtype: object 900     Задний
# 901     Задний
# 1038    Задний
# 1039    Задний
# 1040    Задний
#          ...
# 2686    Задний
# 2687    Задний
# 2688    Задний
# 2689    Полный
# 2690    Задний
# Name: тип_привода, Length: 234, dtype: object
# 9616     H350
# 9617     H350
# 9618     H350
# 9619     H350
# 9620     H350
#          ...
# 39555     EX8
# 39556     EX8
# 39557     EX8
# 39558     EX8
# 39559     EX8
# Name: модель, Length: 98, dtype: object 9616     NaN
# 9617     NaN
# 9618     NaN
# 9619     NaN
# 9620     NaN
#         ...
# 39555    NaN
# 39556    NaN
# 39557    NaN
# 39558    NaN
# 39559    NaN
# Name: объём_двиг_л, Length: 98, dtype: object 9616     NaN
# 9617     NaN
# 9618     NaN
# 9619     NaN
# 9620     NaN
#         ...
# 39555    NaN
# 39556    NaN
# 39557    NaN
# 39558    NaN
# 39559    NaN
# Name: коробка_передач, Length: 98, dtype: object 9616     NaN
# 9617     NaN
# 9618     NaN
# 9619     NaN
# 9620     NaN
#         ...
# 39555    NaN
# 39556    NaN
# 39557    NaN
# 39558    NaN
# 39559    NaN
# Name: тип_привода, Length: 98, dtype: object
# 13265      Daily
# 13266      Daily
# 13267      Daily
# 13268      Daily
# 13269      Daily
# 13270      Daily
# 13271      Daily
# 13272      Daily
# 13273      Daily
# 13274      Daily
# 13275      Daily
# 13276      Daily
# 13277      Daily
# 13278      Daily
# 13279      Daily
# 13281    Daily A
# 13282    Daily A
# 13283    Daily V
# 13284    Stralis
# 13285    Stralis
# 13286     Tipper
# 13287     Tipper
# 13288     Tipper
# 13289     Tipper
# Name: модель, dtype: object 13265    NaN
# 13266    NaN
# 13267    NaN
# 13268    NaN
# 13269    NaN
# 13270    NaN
# 13271    NaN
# 13272    NaN
# 13273    NaN
# 13274    NaN
# 13275    NaN
# 13276    NaN
# 13277    NaN
# 13278    NaN
# 13279    NaN
# 13281    NaN
# 13282    NaN
# 13283    NaN
# 13284    NaN
# 13285    NaN
# 13286    NaN
# 13287    NaN
# 13288    NaN
# 13289    NaN
# Name: объём_двиг_л, dtype: object 13265    NaN
# 13266    NaN
# 13267    NaN
# 13268    NaN
# 13269    NaN
# 13270    NaN
# 13271    NaN
# 13272    NaN
# 13273     MT
# 13274     MT
# 13275     MT
# 13276     MT
# 13277     MT
# 13278     MT
# 13279     MT
# 13281    NaN
# 13282    NaN
# 13283    NaN
# 13284     AT
# 13285     AT
# 13286    NaN
# 13287    NaN
# 13288    NaN
# 13289    NaN
# Name: коробка_передач, dtype: object 13265    NaN
# 13266    NaN
# 13267    NaN
# 13268    NaN
# 13269    NaN
# 13270    NaN
# 13271    NaN
# 13272    NaN
# 13273    2WD
# 13274    2WD
# 13275    2WD
# 13276    2WD
# 13277    2WD
# 13278    2WD
# 13279    2WD
# 13281    NaN
# 13282    NaN
# 13283    NaN
# 13284    2WD
# 13285    2WD
# 13286    NaN
# 13287    NaN
# 13288    NaN
# 13289    NaN
# Name: тип_привода, dtype: object
# 13301     S3
# 13302     S3
# 13303     S3
# 13304     S3
# 13305     S3
#         ...
# 39340    N56
# 39341    N56
# 39342    N56
# 39343    N56
# 39344    N56
# Name: модель, Length: 598, dtype: object 13301    NaN
# 13302    NaN
# 13303    NaN
# 13304    NaN
# 13305    NaN
#         ...
# 39340    NaN
# 39341    NaN
# 39342    NaN
# 39343    NaN
# 39344    NaN
# Name: объём_двиг_л, Length: 598, dtype: object 13301    NaN
# 13302    NaN
# 13303    NaN
# 13304    NaN
# 13305    NaN
#         ...
# 39340    NaN
# 39341    NaN
# 39342    NaN
# 39343    NaN
# 39344    NaN
# Name: коробка_передач, Length: 598, dtype: object 13301    2WD
# 13302    2WD
# 13303    2WD
# 13304    2WD
# 13305    2WD
#         ...
# 39340    2WD
# 39341    2WD
# 39342    2WD
# 39343    2WD
# 39344    NaN
# Name: тип_привода, Length: 598, dtype: object
# 15045        XJ
# 38864    E-PACE
# 39547    I-Pace
# Name: модель, dtype: object 15045    NaN
# 38864    NaN
# 39547    NaN
# Name: объём_двиг_л, dtype: object 15045    NaN
# 38864    NaN
# 39547    NaN
# Name: коробка_передач, dtype: object 15045    NaN
# 38864    NaN
# 39547    NaN
# Name: тип_привода, dtype: object
# 18701    ВИС
# 18703    ВИС
# 18708    ВИС
# Name: модель, dtype: object 18701    1.69
# 18703    1.69
# 18708    1.69
# Name: объём_двиг_л, dtype: object 18701     5МТ
# 18703    5 МТ
# 18708     5MT
# Name: коробка_передач, dtype: object 18701    Полный
# 18703    Полный
# 18708    Полный
# Name: тип_привода, dtype: object
# 18724       Discovery Sport
# 18806           Range Rover
# 18815    Range Rover Evoque
# 18827     Range Rover Sport
# 38705     Range Rover Velar
# Name: модель, dtype: object 18724    NaN
# 18806    NaN
# 18815    NaN
# 18827    NaN
# 38705    NaN
# Name: объём_двиг_л, dtype: object 18724    NaN
# 18806    NaN
# 18815    NaN
# 18827    NaN
# 38705    NaN
# Name: коробка_передач, dtype: object 18724    NaN
# 18806    NaN
# 18815    NaN
# 18827    NaN
# 38705    NaN
# Name: тип_привода, dtype: object
# 20215    TG
# 20216    TG
# 20218    TG
# 20219    TG
# 20220    TG
# Name: модель, dtype: object 20215    NaN
# 20216    NaN
# 20218    NaN
# 20219    NaN
# 20220    NaN
# Name: объём_двиг_л, dtype: object 20215    NaN
# 20216    NaN
# 20218    NaN
# 20219    NaN
# 20220    NaN
# Name: коробка_передач, dtype: object 20215    NaN
# 20216    NaN
# 20218    NaN
# 20219    NaN
# 20220    NaN
# Name: тип_привода, dtype: object
# 20223       3
# 20224       3
# 20225       3
# 20226       3
# 20227       3
#          ...
# 38658    CX-9
# 38659    CX-9
# 38660    CX-9
# 38661    CX-9
# 38662    CX-9
# Name: модель, Length: 112, dtype: object 20223    NaN
# 20224    NaN
# 20225    NaN
# 20226    NaN
# 20227    NaN
#         ...
# 38658    NaN
# 38659    NaN
# 38660    NaN
# 38661    NaN
# 38662    NaN
# Name: объём_двиг_л, Length: 112, dtype: object 20223    NaN
# 20224    NaN
# 20225    NaN
# 20226    NaN
# 20227    NaN
#         ...
# 38658    NaN
# 38659    NaN
# 38660    NaN
# 38661    NaN
# 38662    NaN
# Name: коробка_передач, Length: 112, dtype: object 20223    NaN
# 20224    NaN
# 20225    NaN
# 20226    NaN
# 20227    NaN
#         ...
# 38658    NaN
# 38659    NaN
# 38660    NaN
# 38661    NaN
# 38662    NaN
# Name: тип_привода, Length: 112, dtype: object
# 21848                  301
# 21849                  301
# 21850                  301
# 21851                  301
# 21852                  301
# 21853                  301
# 21854                  301
# 21860                  301
# 21861                  301
# 21862                  301
# 21863                  301
# 21869    Partner Panel Van
# 21870    Partner Panel Van
# Name: модель, dtype: object 21848    NaN
# 21849    NaN
# 21850    NaN
# 21851    NaN
# 21852    NaN
# 21853    NaN
# 21854    NaN
# 21860    NaN
# 21861    NaN
# 21862    NaN
# 21863    NaN
# 21869    NaN
# 21870    NaN
# Name: объём_двиг_л, dtype: object 21848    NaN
# 21849    NaN
# 21850    NaN
# 21851    NaN
# 21852    NaN
# 21853    NaN
# 21854    NaN
# 21860    NaN
# 21861    NaN
# 21862    NaN
# 21863    NaN
# 21869    NaN
# 21870    NaN
# Name: коробка_передач, dtype: object 21848    NaN
# 21849    NaN
# 21850    NaN
# 21851    NaN
# 21852    NaN
# 21853    NaN
# 21854    NaN
# 21860    NaN
# 21861    NaN
# 21862    NaN
# 21863    NaN
# 21869    NaN
# 21870    NaN
# Name: тип_привода, dtype: object
# 23737    Duster
# 23738    Duster
# 23739    Duster
# 23740    Duster
# 23741    Duster
#           ...
# 39943    Arkana
# 39944    Arkana
# 39945    Arkana
# 39946    Arkana
# 39947    Arkana
# Name: модель, Length: 1733, dtype: object 23737    NaN
# 23738    NaN
# 23739    NaN
# 23740    NaN
# 23741    NaN
#         ...
# 39943    NaN
# 39944    NaN
# 39945    NaN
# 39946    NaN
# 39947    NaN
# Name: объём_двиг_л, Length: 1733, dtype: object 23737    NaN
# 23738    NaN
# 23739    NaN
# 23740    NaN
# 23741    NaN
#         ...
# 39943    NaN
# 39944    NaN
# 39945    NaN
# 39946    NaN
# 39947    NaN
# Name: коробка_передач, Length: 1733, dtype: object 23737      0
# 23738      0
# 23739      0
# 23740      0
# 23741      0
#         ...
# 39943    NaN
# 39944    NaN
# 39945    NaN
# 39946    NaN
# 39947    NaN
# Name: тип_привода, Length: 1733, dtype: object
# 37059              3151
# 37067              3151
# 37073              3151
# 37508             Cargo
# 37511             Cargo
# 37513             Cargo
# 37514             Cargo
# 37788    Patriot Pickup
# 37789    Patriot Pickup
# 37802    Patriot Pickup
# 37819    Patriot Pickup
# 37820    Patriot Pickup
# Name: модель, dtype: object 37059    2.693
# 37067    2.693
# 37073    2.693
# 37508    2.693
# 37511    2.693
# 37513    2.693
# 37514    2.693
# 37788    2.693
# 37789    2.693
# 37802    2.693
# 37819    2.693
# 37820    2.693
# Name: объём_двиг_л, dtype: object 37059     5МТ
# 37067     5MT
# 37073     5МТ
# 37508    5 МТ
# 37511     5МТ
# 37513     5MT
# 37514     5MT
# 37788     5МТ
# 37789     5МТ
# 37802    5 МТ
# 37819     5MT
# 37820     5MT
# Name: коробка_передач, dtype: object 37059    Полный
# 37067    Полный
# 37073    Полный
# 37508    Полный
# 37511    Задний
# 37513    Задний
# 37514    Задний
# 37788    Задний
# 37789    Задний
# 37802    Задний
# 37819    Задний
# 37820    Задний
# Name: тип_привода, dtype: object
# 37855       Amarok
# 37872    Caravelle
# 37873    Caravelle
# 37874    Caravelle
# 38271         Polo
#            ...
# 39538     Teramont
# 39539     Teramont
# 39540     Teramont
# 39541     Teramont
# 39542     Teramont
# Name: модель, Length: 68, dtype: object 37855    NaN
# 37872    NaN
# 37873    NaN
# 37874    NaN
# 38271    NaN
#         ...
# 39538    NaN
# 39539    NaN
# 39540    NaN
# 39541    NaN
# 39542    NaN
# Name: объём_двиг_л, Length: 68, dtype: object 37855    NaN
# 37872    NaN
# 37873    NaN
# 37874    NaN
# 38271    NaN
#         ...
# 39538    NaN
# 39539    NaN
# 39540    NaN
# 39541    NaN
# 39542    NaN
# Name: коробка_передач, Length: 68, dtype: object 37855    NaN
# 37872    NaN
# 37873    NaN
# 37874    NaN
# 38271    NaN
#         ...
# 39538    NaN
# 39539    NaN
# 39540    NaN
# 39541    NaN
# 39542    NaN
# Name: тип_привода, Length: 68, dtype: object
# 38587    XC90
# 39209    XC60
# Name: модель, dtype: object 38587    NaN
# 39209    NaN
# Name: объём_двиг_л, dtype: object 38587    NaN
# 39209    NaN
# Name: коробка_передач, dtype: object 38587    NaN
# 39209    NaN
# Name: тип_привода, dtype: object
# 38595            4320
# 38596            4320
# 38597            4320
# 38598            4320
# 38599            4320
# 38600            4320
# 38601            4320
# 38602    4320-1951-40
# 38603    4320-1951-60
# 38604            5557
# 38605            5557
# 39552           32551
# Name: модель, dtype: object 38595    NaN
# 38596    NaN
# 38597    NaN
# 38598    NaN
# 38599    NaN
# 38600    NaN
# 38601    NaN
# 38602    NaN
# 38603    NaN
# 38604    NaN
# 38605    NaN
# 39552    NaN
# Name: объём_двиг_л, dtype: object 38595    NaN
# 38596    NaN
# 38597    NaN
# 38598    NaN
# 38599    NaN
# 38600    NaN
# 38601    NaN
# 38602    NaN
# 38603    NaN
# 38604    NaN
# 38605    NaN
# 39552    NaN
# Name: коробка_передач, dtype: object 38595    NaN
# 38596    NaN
# 38597    NaN
# 38598    NaN
# 38599    NaN
# 38600    NaN
# 38601    NaN
# 38602    NaN
# 38603    NaN
# 38604    NaN
# 38605    NaN
# 39552    NaN
# Name: тип_привода, dtype: object
# 39137    SX3258DR384
# 39138    SX3258DR384
# 39139    SX3258DR384
# 39140    SX3258DR384
# 39141    SX3258DR384
# 39142    SX3258DR384
# 39143    SX3258DR384
# 39144    SX3258DR384
# 39145    SX3258DR384
# 39146    SX3258DR384
# 39147    SX3258DR384
# 39148    SX3258DR384
# 39149    SX3258DR384
# 39150    SX3258DR384
# 39151    SX3258DR384
# 39152    SX3258DR384
# 39153    SX3258DR384
# 39154    SX3258DR384
# 39155    SX3258DR384
# 39156    SX3258DR384
# 39157    SX3258DR384
# 39158    SX3258DR384
# 39159    SX3258DR384
# 39160    SX3258DR384
# 39161    SX3258DR384
# 39162    SX3258DR384
# 39163    SX3258DR384
# 39164    SX3258DR384
# 39165    SX3258DR384
# 39166    SX3258DR384
# 39167    SX3258DR384
# 39168    SX3258DR384
# 39169    SX3258DR384
# 39170    SX3258DR384
# 39171    SX3258DR384
# 39172    SX3258DR384
# 39173    SX3258DR384
# 39174    SX3258DR384
# 39175    SX3258DR384
# 39176    SX3258DR384
# 39177    SX3258DR384
# 39178    SX3258DR384
# 39179    SX3258DR384
# Name: модель, dtype: object 39137    NaN
# 39138    NaN
# 39139    NaN
# 39140    NaN
# 39141    NaN
# 39142    NaN
# 39143    NaN
# 39144    NaN
# 39145    NaN
# 39146    NaN
# 39147    NaN
# 39148    NaN
# 39149    NaN
# 39150    NaN
# 39151    NaN
# 39152    NaN
# 39153    NaN
# 39154    NaN
# 39155    NaN
# 39156    NaN
# 39157    NaN
# 39158    NaN
# 39159    NaN
# 39160    NaN
# 39161    NaN
# 39162    NaN
# 39163    NaN
# 39164    NaN
# 39165    NaN
# 39166    NaN
# 39167    NaN
# 39168    NaN
# 39169    NaN
# 39170    NaN
# 39171    NaN
# 39172    NaN
# 39173    NaN
# 39174    NaN
# 39175    NaN
# 39176    NaN
# 39177    NaN
# 39178    NaN
# 39179    NaN
# Name: объём_двиг_л, dtype: object 39137    NaN
# 39138    NaN
# 39139    NaN
# 39140    NaN
# 39141    NaN
# 39142    NaN
# 39143    NaN
# 39144    NaN
# 39145    NaN
# 39146    NaN
# 39147    NaN
# 39148    NaN
# 39149    NaN
# 39150    NaN
# 39151    NaN
# 39152    NaN
# 39153    NaN
# 39154    NaN
# 39155    NaN
# 39156    NaN
# 39157    NaN
# 39158    NaN
# 39159    NaN
# 39160    NaN
# 39161    NaN
# 39162    NaN
# 39163    NaN
# 39164    NaN
# 39165    NaN
# 39166    NaN
# 39167    NaN
# 39168    NaN
# 39169    NaN
# 39170    NaN
# 39171    NaN
# 39172    NaN
# 39173    NaN
# 39174    NaN
# 39175    NaN
# 39176    NaN
# 39177    NaN
# 39178    NaN
# 39179    NaN
# Name: коробка_передач, dtype: object 39137    NaN
# 39138    NaN
# 39139    NaN
# 39140    NaN
# 39141    NaN
# 39142    NaN
# 39143    NaN
# 39144    NaN
# 39145    NaN
# 39146    NaN
# 39147    NaN
# 39148    NaN
# 39149    NaN
# 39150    NaN
# 39151    NaN
# 39152    NaN
# 39153    NaN
# 39154    NaN
# 39155    NaN
# 39156    NaN
# 39157    NaN
# 39158    NaN
# 39159    NaN
# 39160    NaN
# 39161    NaN
# 39162    NaN
# 39163    NaN
# 39164    NaN
# 39165    NaN
# 39166    NaN
# 39167    NaN
# 39168    NaN
# 39169    NaN
# 39170    NaN
# 39171    NaN
# 39172    NaN
# 39173    NaN
# 39174    NaN
# 39175    NaN
# 39176    NaN
# 39177    NaN
# 39178    NaN
# 39179    NaN
# Name: тип_привода, dtype: object
# 39440    BWC6665GA5
# 39441    BWC6665GA5
# 39442    BWC6665GA5
# 39443    BWC6665GA5
# 39444    BWC6665GA5
# 39445    BWC6665GA5
# 39446    BWC6665GA5
# 39447    BWC6665GA5
# 39448    BWC6665GA5
# 39449    BWC6665GA5
# Name: модель, dtype: object 39440    NaN
# 39441    NaN
# 39442    NaN
# 39443    NaN
# 39444    NaN
# 39445    NaN
# 39446    NaN
# 39447    NaN
# 39448    NaN
# 39449    NaN
# Name: объём_двиг_л, dtype: object 39440    NaN
# 39441    NaN
# 39442    NaN
# 39443    NaN
# 39444    NaN
# 39445    NaN
# 39446    NaN
# 39447    NaN
# 39448    NaN
# 39449    NaN
# Name: коробка_передач, dtype: object 39440    NaN
# 39441    NaN
# 39442    NaN
# 39443    NaN
# 39444    NaN
# 39445    NaN
# 39446    NaN
# 39447    NaN
# 39448    NaN
# 39449    NaN
# Name: тип_привода, dtype: object
# 39478     HF-D105
# 39479     HF-D105
# 39480     HF-D105
# 39481     HF-D105
# 39482     HF-D105
#            ...
# 39633    HFF6850G
# 39634    HFF6850G
# 39635    HFF6850G
# 39636    HFF6850G
# 39637    HFF6850G
# Name: модель, Length: 103, dtype: object 39478    NaN
# 39479    NaN
# 39480    NaN
# 39481    NaN
# 39482    NaN
#         ...
# 39633    NaN
# 39634    NaN
# 39635    NaN
# 39636    NaN
# 39637    NaN
# Name: объём_двиг_л, Length: 103, dtype: object 39478    NaN
# 39479    NaN
# 39480    NaN
# 39481    NaN
# 39482    NaN
#         ...
# 39633    NaN
# 39634    NaN
# 39635    NaN
# 39636    NaN
# 39637    NaN
# Name: коробка_передач, Length: 103, dtype: object 39478    NaN
# 39479    NaN
# 39480    NaN
# 39481    NaN
# 39482    NaN
#         ...
# 39633    NaN
# 39634    NaN
# 39635    NaN
# 39636    NaN
# 39637    NaN
# Name: тип_привода, Length: 103, dtype: object

# %% [markdown]
# <div style="border-radius: 45px;border:solid red 7px; padding: 40px">
#
#     Общее количество моделей без указания вида топлива составляет 72 модели.
#     Это довольно трудозатратно, чтобы выяснять в интернете для  каждой из них на вид топлива.
#     ТЗ не ставит задачу исследование рынка в зависимости от вида топлива автомобиля.
#     Отложим пока за ненадобностью заполнение данных в столбце "вид топлива"
#
#     так же отметим, что для заполнения на основе имеющихся данных нужна предобработка столбцов `объём_двиг_л`, `коробка_передач`, `тип_привода`, `сегмент`. Заполнение данных при необходимости произведем ПОСЛЕ обработки значений в этих столбцах

# %% [markdown]
# #### Приведем данные к единообразию

# %%
# приведем все значения к нижнему регистру и удалим пробелы
data.вид_топлива = data.вид_топлива.str.lower().str.replace(' ', '')

# %%
data['вид_топлива'].unique()
# Out:
# array(['бензин', 'дизель', nan, 'гибрид', 'p', 'электро', 'электричество'],
#       dtype=object)

# %%
# Вспомним, что в больших объемах данныз скорость обработки заметно увеличивается
#для более длинных значений по сравнению с короткими.
# примем короткие условные обозначения вида топлива
# Создадим словарь для замены
#dict_type = {'бензин': 'Бензин', 'дизель':'Дизель', 'электричество': 'Электро', 'электро': 'Электро', 'гибрид':'Гибрид'}

# %%
# Вспомним, что в больших объемах данныз скорость обработки заметно увеличивается
#для более длинных значений по сравнению с короткими.
# примем короткие условные обозначения вида топлива
# Создадим словарь для замены
dict_type = {'бензин': 'p', 'дизель':'d', 'электричество': 'e', 'электро': 'e', 'гибрид':'g'}

# %%
# Призведем замену
data['вид_топлива'] = data['вид_топлива'].map(dict_type)

# %%
data['вид_топлива'].unique()
# Out:
# array(['p', 'd', nan, 'g', 'e'], dtype=object)

# %% [markdown]
# ### Обработка данных в столбце `объём_двиг_л`
# Выведем на экран уникальные значения, указанные в столбце `объём_двиг_л`

# %%
sorted(data.объём_двиг_л.unique().astype(str))
# Out:
# ['#Н/Д',
#  '0',
#  '1,6',
#  '1.2',
#  '1.248',
#  '1.2T',
#  '1.33',
#  '1.4',
#  '1.485',
#  '1.4Turbo',
#  '1.5',
#  '1.591',
#  '1.596',
#  '1.598',
#  '1.6',
#  '1.69',
#  '1.6MPI',
#  '1.6T-GDI',
#  '1.7',
#  '1.774',
#  '1.8',
#  '1.998',
#  '1.999',
#  '10.5',
#  '10.7',
#  '11',
#  '11.7',
#  '12',
#  '12.3',
#  '12.7',
#  '12.8',
#  '13',
#  '13.7',
#  '14.7',
#  '15.7',
#  '16.7',
#  '17.7',
#  '18.7',
#  '19.7',
#  '2',
#  '2.0',
#  '2.0CRDI',
#  '2.0MPI',
#  '2.0h',
#  '2.2',
#  '2.359',
#  '2.4',
#  '2.4G',
#  '2.4GDI',
#  '2.4MPI',
#  '2.5',
#  '2.5CRDIVGT',
#  '2.5CRDIWGT',
#  '2.693',
#  '2.7',
#  '2.8',
#  '2.9',
#  '20.7',
#  '21.7',
#  '22.7',
#  '23.7',
#  '24.7',
#  '25.7',
#  '26.7',
#  '3',
#  '3.0L',
#  '3.342',
#  '3.47',
#  '3.5',
#  '3.6',
#  '3.7',
#  '3.8',
#  '3.9',
#  '4',
#  '4.0',
#  '4.3',
#  '4.3.',
#  '4.4',
#  '4.6',
#  '4.7',
#  '4.9',
#  '4.98',
#  '4.98L.',
#  '400Л.С.',
#  '5',
#  '5.2',
#  '5.5',
#  '5.6',
#  '5.7',
#  '6.2',
#  '6.5',
#  '6.6',
#  '6.7',
#  '6.7L',
#  '7.5',
#  '7.6',
#  '7.7',
#  '8.4L.',
#  '8.7',
#  '88KWH',
#  '9.7',
#  'nan',
#  'p']

# %% [markdown]
# "Почистим" данные:
# - '400Л.С.', '88KWH' , 'MT', 'AT', 0, 'Бензин', а также значения более 10 литров
#     - проверим строки, насколько соответствует отображение данных по столбцам
#     - найдем марку и модель автомобиля и найдем в интернете соответствующий объем двигателя
# - nan и '#Н/Д'-   найдем марку и модель автомобиля и найдем в интернете коответствующий объем двигателя
# - удалим буквенные символы после цифр

# %% [markdown]
# #### Для значений 400Л.С.' и '88KWH'
# - проверим строки, насколько соответствует отображение данных по столбцам
# - найдем марку и модель автомобиля и найдем в интернете коответствующий объем двигателя

# %%
data.query('объём_двиг_л == "400Л.С."')
# Out:
#         год    месяц               компания   бренд  модель модификация  \
# 39544  2019  Февраль  Almaty Motors Premium  Jaguar  I-Pace  ЭЛЕКТРОКАР
# 39545  2019   Апрель  Almaty Motors Premium  Jaguar  I-Pace  ЭЛЕКТРОКАР
# 39546  2019     Июнь  Almaty Motors Premium  Jaguar  I-Pace  ЭЛЕКТРОКАР
#
#       год_выпуска страна_производитель вид_топлива объём_двиг_л  \
# 39544        2019                   UK           e      400Л.С.
# 39545        2019                   UK           e      400Л.С.
# 39546        2019                   UK           e      400Л.С.
#
#       коробка_передач тип_привода сегмент  регион  \
# 39544        РЕДУКТОР         4WD    SUV   Алматы
# 39545        РЕДУКТОР         4WD    SUV   Алматы
# 39546        РЕДУКТОР         4WD    SUV   Алматы
#
#       наименование_дилерского_центра тип_клиента  количество     цена_usd  \
# 39544          Almaty Motors Premium   Физ. Лицо         1.0  117236.9729
# 39545          Almaty Motors Premium   Физ. Лицо         1.0  105388.7924
# 39546          Almaty Motors Premium    Юр. Лицо         1.0  120413.2793
#
#        продажа_usd   область сегментация_2013      класс_2013
# 39544  117236.9729  г.Алматы     Внедорожники  Компактные SUV
# 39545  105388.7924  г.Алматы     Внедорожники  Компактные SUV
# 39546  120413.2793  г.Алматы     Внедорожники  Компактные SUV

# %% [markdown]
# Согласно [Википедии](https://ru.wikipedia.org/wiki/Jaguar_I-Pace) автомобиль Jaguar модели I-Pace является электромобилем. соответственно, не имеет ДВС и не может иметь характеристили `Объем двигателя`, поскольку последняя означает объем двигателя внутреннего сгорания. К ячейке указана мощность электрического двигателя, которым оснащен автомобиль.

# %%
data.query('объём_двиг_л == "88KWH"')
# Out:
#         год месяц    компания  бренд         модель модификация год_выпуска  \
# 39818  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
# 39819  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
# 39820  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
# 39821  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
# 39822  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
# 39823  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
# 39824  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
# 39825  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
# 39826  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
# 39827  2019  Июль  Allur Auto  ANKAI  HFF6124G03EV3         Bus        2019
#
#        страна_производитель вид_топлива объём_двиг_л коробка_передач  \
# 39818  Республика Казахстан           e        88KWH             NaN
# 39819  Республика Казахстан           e        88KWH             NaN
# 39820  Республика Казахстан           e        88KWH             NaN
# 39821  Республика Казахстан           e        88KWH             NaN
# 39822  Республика Казахстан           e        88KWH             NaN
# 39823  Республика Казахстан           e        88KWH             NaN
# 39824  Республика Казахстан           e        88KWH             NaN
# 39825  Республика Казахстан           e        88KWH             NaN
# 39826  Республика Казахстан           e        88KWH             NaN
# 39827  Республика Казахстан           e        88KWH             NaN
#
#       тип_привода  сегмент    регион наименование_дилерского_центра  \
# 39818         2WD  автобус  Костанай              Allur Auto Almaty
# 39819         2WD  автобус  Костанай              Allur Auto Almaty
# 39820         2WD  автобус  Костанай              Allur Auto Almaty
# 39821         2WD  автобус  Костанай              Allur Auto Almaty
# 39822         2WD  автобус  Костанай              Allur Auto Almaty
# 39823         2WD  автобус  Костанай              Allur Auto Almaty
# 39824         2WD  автобус  Костанай              Allur Auto Almaty
# 39825         2WD  автобус  Костанай              Allur Auto Almaty
# 39826         2WD  автобус  Костанай              Allur Auto Almaty
# 39827         2WD  автобус  Костанай              Allur Auto Almaty
#
#       тип_клиента  количество     цена_usd  продажа_usd               область  \
# 39818    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
# 39819    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
# 39820    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
# 39821    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
# 39822    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
# 39823    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
# 39824    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
# 39825    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
# 39826    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
# 39827    Юр. Лицо         1.0  307986.3633  307986.3633  Костанайская область
#
#               сегментация_2013        класс_2013
# 39818  Коммерческие автомобили  Большие автобусы
# 39819  Коммерческие автомобили  Большие автобусы
# 39820  Коммерческие автомобили  Большие автобусы
# 39821  Коммерческие автомобили  Большие автобусы
# 39822  Коммерческие автомобили  Большие автобусы
# 39823  Коммерческие автомобили  Большие автобусы
# 39824  Коммерческие автомобили  Большие автобусы
# 39825  Коммерческие автомобили  Большие автобусы
# 39826  Коммерческие автомобили  Большие автобусы
# 39827  Коммерческие автомобили  Большие автобусы

# %% [markdown]
# Согласно [Сайта yomobile.ru](https://yomobile.ru/elektromobil/hff/ankai-hff6124g03ev.html) указанное транспортное средство является электрическим городским автобусом (электробусом). Соответственно, не имеет ДВС и не может иметь характеристили `Объем двигателя`, поскольку последняя означает объем двигателя внутреннего сгорания. К ячейке указана мощность электрического двигателя, которым оснащен автобус.

# %% [markdown]
# Учитывая сказанное:
# - приравняем значения в соответствующих ячейках к значению 0.
# - Укажем в столбце "вид_топлива" значение "Электро"

# %%
data.loc[(data['объём_двиг_л'] == "400Л.С."), 'вид_топлива'] = 'e'

# %%
data.loc[(data.объём_двиг_л == "88KWH"),'объём_двиг_л'] = 0
data.loc[(data.объём_двиг_л == "400Л.С."),'объём_двиг_л'] = 0

# %%
data['объём_двиг_л'].unique()
# Out:
# array(['1.4', '2', '3', '4.4', '6.6', '1.5', '1.596', '2.4', '1.7',
#        '26.7', '25.7', '24.7', '23.7', '22.7', '21.7', '20.7', '19.7',
#        '18.7', '17.7', '16.7', '15.7', '14.7', '13.7', '12.7', '11.7',
#        '10.7', '9.7', '8.7', '7.7', '6.7', '5.7', '4.7', '3.7', '2.7',
#        '6.2', '1.4Turbo', '2.5', '1.6', nan, '2.8', '4.3', '4.3.',
#        '1.6MPI', '2.0MPI', '2.4GDI', '2.4MPI', '2.5CRDIVGT', '2.5CRDIWGT',
#        '3.9', '7.5', '12.3', '1.6T-GDI', '2.0CRDI', '2.0', '3.5', '5.6',
#        '5.2', '3.0L', '5', '1.598', '1.248', '1.998', '2.359', '1.999',
#        '3.342', '1.591', '3.47', '1.69', '1.774', '4.6', '1.8', '10.5',
#        '4', '5.5', '12', '12.8', '11', '2.2', '1.2', '1.485', 'p', '0',
#        '1,6', '13', '1.33', '#Н/Д', '4.0', '2.4G', '2.693', '3.8', '1.2T',
#        '3.6', '7.6', '4.9', '2.0h', '2.9', 0, '4.98L.', '4.98', '8.4L.',
#        '6.7L', '6.5'], dtype=object)

# %% [markdown]
# #### Для значений 'MT' и  'AT'
# - проверим строки, насколько соответствует отображение данных по столбцам
# - найдем марку и модель автомобиля и найдем в интернете коответствующий объем двигателя

# %%
pd.set_option('max_columns', None)

data.query('объём_двиг_л == "MT" or объём_двиг_л == "AT"').head()
# Out:
# Empty DataFrame
# Columns: [год, месяц, компания, бренд, модель, модификация, год_выпуска, страна_производитель, вид_топлива, объём_двиг_л, коробка_передач, тип_привода, сегмент, регион, наименование_дилерского_центра, тип_клиента, количество, цена_usd, продажа_usd, область, сегментация_2013, класс_2013]
# Index: []

# %% [markdown]
# Столбцы 'объём_двиг_л' и 'коробка_передач' "съехали" влево на одну позицию - исправим это.
# Данные из столбца 'вид_топлива' потеряны.

# %%
data.loc[(data['объём_двиг_л'] == "MT") | (data['объём_двиг_л'] == "AT"), 'коробка_передач'] = \
    data.loc[(data['объём_двиг_л'] == "MT") | (data['объём_двиг_л'] == "AT"), 'объём_двиг_л']

# %%
data.loc[(data['объём_двиг_л'] == "MT") | (data['объём_двиг_л'] == "AT"), 'объём_двиг_л'] = \
    data.loc[(data['объём_двиг_л'] == "MT") | (data['объём_двиг_л'] == "AT"), 'вид_топлива']

# %%
sorted(data['объём_двиг_л'].unique().astype(str))
# Out:
# ['#Н/Д',
#  '0',
#  '0',
#  '1,6',
#  '1.2',
#  '1.248',
#  '1.2T',
#  '1.33',
#  '1.4',
#  '1.485',
#  '1.4Turbo',
#  '1.5',
#  '1.591',
#  '1.596',
#  '1.598',
#  '1.6',
#  '1.69',
#  '1.6MPI',
#  '1.6T-GDI',
#  '1.7',
#  '1.774',
#  '1.8',
#  '1.998',
#  '1.999',
#  '10.5',
#  '10.7',
#  '11',
#  '11.7',
#  '12',
#  '12.3',
#  '12.7',
#  '12.8',
#  '13',
#  '13.7',
#  '14.7',
#  '15.7',
#  '16.7',
#  '17.7',
#  '18.7',
#  '19.7',
#  '2',
#  '2.0',
#  '2.0CRDI',
#  '2.0MPI',
#  '2.0h',
#  '2.2',
#  '2.359',
#  '2.4',
#  '2.4G',
#  '2.4GDI',
#  '2.4MPI',
#  '2.5',
#  '2.5CRDIVGT',
#  '2.5CRDIWGT',
#  '2.693',
#  '2.7',
#  '2.8',
#  '2.9',
#  '20.7',
#  '21.7',
#  '22.7',
#  '23.7',
#  '24.7',
#  '25.7',
#  '26.7',
#  '3',
#  '3.0L',
#  '3.342',
#  '3.47',
#  '3.5',
#  '3.6',
#  '3.7',
#  '3.8',
#  '3.9',
#  '4',
#  '4.0',
#  '4.3',
#  '4.3.',
#  '4.4',
#  '4.6',
#  '4.7',
#  '4.9',
#  '4.98',
#  '4.98L.',
#  '5',
#  '5.2',
#  '5.5',
#  '5.6',
#  '5.7',
#  '6.2',
#  '6.5',
#  '6.6',
#  '6.7',
#  '6.7L',
#  '7.5',
#  '7.6',
#  '7.7',
#  '8.4L.',
#  '8.7',
#  '9.7',
#  'nan',
#  'p']

# %% [markdown]
# #### Для значений 'p' - Бензин
# - проверим строки, насколько соответствует отображение данных по столбцам
# - найдем марку и модель автомобиля и найдем в интернете коответствующий объем двигателя

# %%
data.query('объём_двиг_л == "p"').head()
# Out:
#         год   месяц        компания    бренд  модель модификация год_выпуска  \
# 23728  2019  Январь  Renault Россия  Renault  Duster     E1FB4JA        2018
# 23733  2019  Январь  Renault Россия  Renault  Duster     E1FB2JA        2018
# 23734  2019  Январь  Renault Россия  Renault  Duster     E0DB2JA        2018
# 23735  2019  Январь  Renault Россия  Renault  Duster     E0DB2JA        2018
# 23736  2019  Январь  Renault Россия  Renault  Duster     E0DB2JA        2018
#
#        страна_производитель вид_топлива объём_двиг_л коробка_передач  \
# 23728  Российская Федерация         NaN            p              MT
# 23733  Российская Федерация         NaN            p              MT
# 23734  Российская Федерация         NaN            p              AT
# 23735  Российская Федерация         NaN            p              AT
# 23736  Российская Федерация         NaN            p              AT
#
#       тип_привода сегмент     регион наименование_дилерского_центра  \
# 23728         4WD       0  Караганда        Кристалл Авто Караганда
# 23733         4WD       0  Караганда        Кристалл Авто Караганда
# 23734    Передний       0  Караганда        Кристалл Авто Караганда
# 23735    Передний       0  Караганда        Кристалл Авто Караганда
# 23736    Передний       0  Караганда        Кристалл Авто Караганда
#
#       тип_клиента  количество     цена_usd  продажа_usd  \
# 23728         NaN         1.0  12249.61125  12249.61125
# 23733         NaN         1.0  12249.61125  12249.61125
# 23734         NaN         1.0  12249.61125  12249.61125
# 23735         NaN         1.0  12249.61125  12249.61125
# 23736         NaN         1.0  12249.61125  12249.61125
#
#                       область сегментация_2013         класс_2013
# 23728  Карагандинская область     Внедорожники  Субкомпактные SUV
# 23733  Карагандинская область     Внедорожники  Субкомпактные SUV
# 23734  Карагандинская область     Внедорожники  Субкомпактные SUV
# 23735  Карагандинская область     Внедорожники  Субкомпактные SUV
# 23736  Карагандинская область     Внедорожники  Субкомпактные SUV

# %% [markdown]
# Столбец 'вид_топлива' "съехал" вправо на одну позицию - исправим это.
# Данные из столбца 'объём_двиг_л' потеряны.

# %%
data.loc[(data['объём_двиг_л'] == "p"), 'вид_топлива'] = \
    data.loc[(data['объём_двиг_л'] == "p"), 'объём_двиг_л']

# %% [markdown]
# Очистим данные в столбце 'объём_двиг_л'

# %%
data.loc[(data['объём_двиг_л'] == "p"), 'объём_двиг_л'] = ''

# %% [markdown]
# #### Для значений '#Н/Д'
# - проверим строки, насколько соответствует отображение данных по столбцам
# - найдем марку и модель автомобиля и найдем в интернете коответствующий объем двигателя

# %%
data.query('объём_двиг_л == "#Н/Д"')
# Out:
#         год    месяц                 компания   бренд    модель модификация  \
# 31148  2019  Февраль  Toyota Motor Kazakhstan  Toyota   Corolla           7
# 31149  2019  Февраль  Toyota Motor Kazakhstan  Toyota   Corolla           7
# 32670  2019   Апрель  Toyota Motor Kazakhstan  Toyota  HILUX DC          JT
# 33070  2019     Июль  Toyota Motor Kazakhstan  Toyota  HILUX DC          NX
#
#       год_выпуска страна_производитель вид_топлива объём_двиг_л  \
# 31148        2019               Турция           p         #Н/Д
# 31149        2019               Турция           p         #Н/Д
# 32670        2019              Таиланд           p         #Н/Д
# 33070        2019              Таиланд           p         #Н/Д
#
#       коробка_передач тип_привода   сегмент      регион  \
# 31148            #Н/Д        #Н/Д  C класс   Нур-Султан
# 31149            #Н/Д        #Н/Д  C класс   Нур-Султан
# 32670            #Н/Д        #Н/Д   Пикапы       Алматы
# 33070            #Н/Д        #Н/Д   Пикапы       Атырау
#
#       наименование_дилерского_центра тип_клиента  количество     цена_usd  \
# 31148            Тойота Центр Астана   Физ. Лицо         1.0  42316.46043
# 31149            Тойота Центр Астана   Физ. Лицо         1.0  42316.46043
# 32670                    Toyota City    Юр. Лицо         1.0  30870.28194
# 33070            Тойота Центр Атырау   Физ. Лицо         1.0  27012.45730
#
#        продажа_usd             область     сегментация_2013 класс_2013
# 31148  42316.46043        г.Нур-Султан  Легковые автомобили    C класс
# 31149  42316.46043        г.Нур-Султан  Легковые автомобили    C класс
# 32670  30870.28194            г.Алматы               Пикапы   Pick-ups
# 33070  27012.45730  Атырауская область               Пикапы   Pick-ups

# %% [markdown]
# Данные отсутствуют. Мы удалим их чуть позже, при обработке нечисловых значений в столбце

# %% [markdown]
# #### Для значений '0'
# - проверим строки, насколько соответствует отображение данных по столбцам
# - найдем марку и модель автомобиля и найдем в интернете коответствующий объем двигателя

# %%
data.query('объём_двиг_л == "0"')
# Out:
#         год   месяц        компания    бренд   модель модификация год_выпуска  \
# 24997  2019  Январь  Renault Россия  Renault  Sandero  SXP16PA5RB        2018
# 25002  2019  Январь  Renault Россия  Renault  Sandero  SUT16PA5RB        2018
# 25023  2019  Январь  Renault Россия  Renault  Sandero  SXP16PA5RB        2018
#
#        страна_производитель вид_топлива объём_двиг_л коробка_передач  \
# 24997  Российская Федерация           p            0               0
# 25002  Российская Федерация           p            0               0
# 25023  Российская Федерация           p            0               0
#
#       тип_привода сегмент      регион наименование_дилерского_центра  \
# 24997           0       0      Атырау                 Урал-Кров Авто
# 25002           0       0      Атырау                 Урал-Кров Авто
# 25023           0       0  Нур-Султан                Автоцентр Астэк
#
#       тип_клиента  количество     цена_usd  продажа_usd             область  \
# 24997         NaN         1.0  12476.89637  12476.89637  Атырауская область
# 25002         NaN         1.0  12476.89637  12476.89637  Атырауская область
# 25023         NaN         1.0  12476.89637  12476.89637        г.Нур-Султан
#
#           сегментация_2013 класс_2013
# 24997  Легковые автомобили    B класс
# 25002  Легковые автомобили    B класс
# 25023  Легковые автомобили    B класс

# %% [markdown]
# Согласно [Сайта](https://www.drom.ru/catalog/renault/sandero/specs/transmission/) Рено Sandero 2018 г.в. комплектовался несколькими видами бензиновыз двигателей с одинаковым объемом - 1.6 литров и передним приводом. КПП могла быть автоматической и механической.

# %%
data.loc[(data['модель'] == 'Sandero'), 'вид_топлива'] = "p"
data.loc[(data['модель'] == 'Sandero'), 'объём_двиг_л'] = 1.6
data.loc[(data['модель'] == 'Sandero'), 'тип_привода'] = "FWD"

# %%
#data.loc[(data['объём_двиг_л'] == "0"), 'объём_двиг_л'] = ''

# %% [markdown]
# #### Удалим буквенные символы после цифр
# ~Результат запишем в новый столбец `объём_двиг_л_next`~

# %%
for i in tqdm(range(data.shape[0])):
    try:
        data.loc[(data.index == i), 'объём_двиг_л'] = re.sub("[^0-9.]", "", data.loc[(data.index == i), 'объём_двиг_л'][i])
    except:
        pass
# Out:
# 100%|██████████| 39966/39966 [00:48<00:00, 831.54it/s]

# %%
for i in tqdm(range(data.shape[0])):
    try:
        data.loc[(data.index == i), 'объём_двиг_л'] = re.sub("\.{2,}", "", data.loc[(data.index == i), 'объём_двиг_л'][i])
    except:
        pass
# Out:
# 100%|██████████| 39966/39966 [00:46<00:00, 861.82it/s]

# %%
data['объём_двиг_л'].unique()
# Out:
# array(['1.4', '2', '3', '4.4', '6.6', '1.5', '1.596', '2.4', '1.7',
#        '26.7', '25.7', '24.7', '23.7', '22.7', '21.7', '20.7', '19.7',
#        '18.7', '17.7', '16.7', '15.7', '14.7', '13.7', '12.7', '11.7',
#        '10.7', '9.7', '8.7', '7.7', '6.7', '5.7', '4.7', '3.7', '2.7',
#        '6.2', '2.5', '1.6', nan, '2.8', '4.3', '4.3.', '2.0', '3.9',
#        '7.5', '12.3', '3.5', '5.6', '5.2', '3.0', '5', '1.598', '1.248',
#        '1.998', '2.359', '1.999', '3.342', '1.591', '3.47', '1.69',
#        '1.774', '4.6', '1.8', '10.5', '4', '5.5', '12', '12.8', '11',
#        '2.2', '1.2', '1.485', '', 1.6, '13', '1.33', '4.0', '2.693',
#        '3.8', '3.6', '7.6', '4.9', '2.9', 0, '4.98.', '4.98', '8.4.',
#        '6.5'], dtype=object)

# %%
data.query('объём_двиг_л == 0')
# Out:
#         год    месяц               компания   бренд         модель  \
# 39544  2019  Февраль  Almaty Motors Premium  Jaguar         I-Pace
# 39545  2019   Апрель  Almaty Motors Premium  Jaguar         I-Pace
# 39546  2019     Июнь  Almaty Motors Premium  Jaguar         I-Pace
# 39818  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
# 39819  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
# 39820  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
# 39821  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
# 39822  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
# 39823  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
# 39824  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
# 39825  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
# 39826  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
# 39827  2019     Июль             Allur Auto   ANKAI  HFF6124G03EV3
#
#       модификация год_выпуска  страна_производитель вид_топлива объём_двиг_л  \
# 39544  ЭЛЕКТРОКАР        2019                    UK           e            0
# 39545  ЭЛЕКТРОКАР        2019                    UK           e            0
# 39546  ЭЛЕКТРОКАР        2019                    UK           e            0
# 39818         Bus        2019  Республика Казахстан           e            0
# 39819         Bus        2019  Республика Казахстан           e            0
# 39820         Bus        2019  Республика Казахстан           e            0
# 39821         Bus        2019  Республика Казахстан           e            0
# 39822         Bus        2019  Республика Казахстан           e            0
# 39823         Bus        2019  Республика Казахстан           e            0
# 39824         Bus        2019  Республика Казахстан           e            0
# 39825         Bus        2019  Республика Казахстан           e            0
# 39826         Bus        2019  Республика Казахстан           e            0
# 39827         Bus        2019  Республика Казахстан           e            0
#
#       коробка_передач тип_привода  сегмент    регион  \
# 39544        РЕДУКТОР         4WD     SUV     Алматы
# 39545        РЕДУКТОР         4WD     SUV     Алматы
# 39546        РЕДУКТОР         4WD     SUV     Алматы
# 39818             NaN         2WD  автобус  Костанай
# 39819             NaN         2WD  автобус  Костанай
# 39820             NaN         2WD  автобус  Костанай
# 39821             NaN         2WD  автобус  Костанай
# 39822             NaN         2WD  автобус  Костанай
# 39823             NaN         2WD  автобус  Костанай
# 39824             NaN         2WD  автобус  Костанай
# 39825             NaN         2WD  автобус  Костанай
# 39826             NaN         2WD  автобус  Костанай
# 39827             NaN         2WD  автобус  Костанай
#
#       наименование_дилерского_центра тип_клиента  количество     цена_usd  \
# 39544          Almaty Motors Premium   Физ. Лицо         1.0  117236.9729
# 39545          Almaty Motors Premium   Физ. Лицо         1.0  105388.7924
# 39546          Almaty Motors Premium    Юр. Лицо         1.0  120413.2793
# 39818              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
# 39819              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
# 39820              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
# 39821              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
# 39822              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
# 39823              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
# 39824              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
# 39825              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
# 39826              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
# 39827              Allur Auto Almaty    Юр. Лицо         1.0  307986.3633
#
#        продажа_usd               область         сегментация_2013  \
# 39544  117236.9729              г.Алматы             Внедорожники
# 39545  105388.7924              г.Алматы             Внедорожники
# 39546  120413.2793              г.Алматы             Внедорожники
# 39818  307986.3633  Костанайская область  Коммерческие автомобили
# 39819  307986.3633  Костанайская область  Коммерческие автомобили
# 39820  307986.3633  Костанайская область  Коммерческие автомобили
# 39821  307986.3633  Костанайская область  Коммерческие автомобили
# 39822  307986.3633  Костанайская область  Коммерческие автомобили
# 39823  307986.3633  Костанайская область  Коммерческие автомобили
# 39824  307986.3633  Костанайская область  Коммерческие автомобили
# 39825  307986.3633  Костанайская область  Коммерческие автомобили
# 39826  307986.3633  Костанайская область  Коммерческие автомобили
# 39827  307986.3633  Костанайская область  Коммерческие автомобили
#
#              класс_2013
# 39544    Компактные SUV
# 39545    Компактные SUV
# 39546    Компактные SUV
# 39818  Большие автобусы
# 39819  Большие автобусы
# 39820  Большие автобусы
# 39821  Большие автобусы
# 39822  Большие автобусы
# 39823  Большие автобусы
# 39824  Большие автобусы
# 39825  Большие автобусы
# 39826  Большие автобусы
# 39827  Большие автобусы

# %% [markdown]
# Это электромобиль и электроавтобус

# %% [markdown]
# <div style="border-radius: 45px;border:solid red 7px; padding: 40px">
#
# Сюда нужно вернуться - в нижеследующий код
#
#     засада в виде топлива до этой строки и после 2.6.3

# %%
display(round(data.isna().mean() * 100).astype(int))
# Out:
# год                                0
# месяц                              0
# компания                           0
# бренд                              0
# модель                             0
# модификация                        9
# год_выпуска                        1
# страна_производитель               0
# вид_топлива                        7
# объём_двиг_л                      10
# коробка_передач                    8
# тип_привода                       10
# сегмент                           17
# регион                             0
# наименование_дилерского_центра     0
# тип_клиента                       18
# количество                         0
# цена_usd                           0
# продажа_usd                        0
# область                            0
# сегментация_2013                   0
# класс_2013                         0
# dtype: int64

# %%
#print(data.loc[(data.объём_двиг_л == "4.9"),'объём_двиг_л'].astype(str).str.split('').str[0])

# %% [markdown]
# значения с двумя точками - избавимся от второй точки

# %%
data.loc[(data.объём_двиг_л == "4.3."),'объём_двиг_л'] = 4.3
data.loc[(data.объём_двиг_л == "4.98."),'объём_двиг_л'] = 4.98
data.loc[(data.объём_двиг_л == "8.4."),'объём_двиг_л'] = 8.4

# %%
#data['объём_двиг_л_next'].unique()

# %%
data['объём_двиг_л'].unique()
# Out:
# array(['1.4', '2', '3', '4.4', '6.6', '1.5', '1.596', '2.4', '1.7',
#        '26.7', '25.7', '24.7', '23.7', '22.7', '21.7', '20.7', '19.7',
#        '18.7', '17.7', '16.7', '15.7', '14.7', '13.7', '12.7', '11.7',
#        '10.7', '9.7', '8.7', '7.7', '6.7', '5.7', '4.7', '3.7', '2.7',
#        '6.2', '2.5', '1.6', nan, '2.8', '4.3', 4.3, '2.0', '3.9', '7.5',
#        '12.3', '3.5', '5.6', '5.2', '3.0', '5', '1.598', '1.248', '1.998',
#        '2.359', '1.999', '3.342', '1.591', '3.47', '1.69', '1.774', '4.6',
#        '1.8', '10.5', '4', '5.5', '12', '12.8', '11', '2.2', '1.2',
#        '1.485', '', 1.6, '13', '1.33', '4.0', '2.693', '3.8', '3.6',
#        '7.6', '4.9', '2.9', 0, 4.98, '4.98', 8.4, '6.5'], dtype=object)

# %% [markdown]
# ##### Приведем к числовому формату столбец   `объём_двиг_л`

# %%
# зададим список столбцов
col_list_capacity = ['объём_двиг_л']

# %%
int_cols = ['объём_двиг_л']
for col in int_cols:
    # downcast='signed' приводит данные к минимально возможному типу числовых данных
    data[col] = pd.to_numeric(data[col], downcast='signed')
print(data[int_cols].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39966 entries, 0 to 39965
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   объём_двиг_л  36130 non-null  float64
# dtypes: float64(1)
# memory usage: 312.4 KB
# None

# %%
data['объём_двиг_л'].unique()
# Out:
# array([ 1.4  ,  2.   ,  3.   ,  4.4  ,  6.6  ,  1.5  ,  1.596,  2.4  ,
#         1.7  , 26.7  , 25.7  , 24.7  , 23.7  , 22.7  , 21.7  , 20.7  ,
#        19.7  , 18.7  , 17.7  , 16.7  , 15.7  , 14.7  , 13.7  , 12.7  ,
#        11.7  , 10.7  ,  9.7  ,  8.7  ,  7.7  ,  6.7  ,  5.7  ,  4.7  ,
#         3.7  ,  2.7  ,  6.2  ,  2.5  ,  1.6  ,    nan,  2.8  ,  4.3  ,
#         3.9  ,  7.5  , 12.3  ,  3.5  ,  5.6  ,  5.2  ,  5.   ,  1.598,
#         1.248,  1.998,  2.359,  1.999,  3.342,  1.591,  3.47 ,  1.69 ,
#         1.774,  4.6  ,  1.8  , 10.5  ,  4.   ,  5.5  , 12.   , 12.8  ,
#        11.   ,  2.2  ,  1.2  ,  1.485, 13.   ,  1.33 ,  2.693,  3.8  ,
#         3.6  ,  7.6  ,  4.9  ,  2.9  ,  0.   ,  4.98 ,  8.4  ,  6.5  ])

# %% [markdown]
# #### Для значений более 10 литров
# - найдем марку и модель автомобиля и оценим cоответствие объема двигателя

# %%
for i in data.query('объём_двиг_л >= 10')['модель'].unique():
    print(data.query('объём_двиг_л >= 10 and модель == @i')[['бренд', 'модель', 'объём_двиг_л', 'сегмент']].head(2))
# Out:
#          бренд модель  объём_двиг_л        сегмент
# 399  Chevrolet   Niva          26.7  Внедорожники
# 400  Chevrolet   Niva          25.7  Внедорожники
#                     бренд    модель  объём_двиг_л        сегмент
# 9699  Hyundai Truck & Bus  Universe          12.3  туристический
# 9700  Hyundai Truck & Bus  Universe          12.3  туристический
#       бренд модель  объём_двиг_л сегмент
# 20212   MAN     TG          10.5     NaN
# 20213   MAN     TG          10.5     NaN
#                       бренд  модель  объём_двиг_л                    сегмент
# 20386  Mercedes-Benz Trucks  Actros          12.0    Коммерческие автомобили
# 20387  Mercedes-Benz Trucks  Actros          12.8  Крупнотоннажные грузовики
#                       бренд    модель  объём_двиг_л           сегмент
# 20402  Mercedes-Benz Trucks  Tourismo          12.0  Большие автобусы
# 20403  Mercedes-Benz Trucks  Tourismo          12.0  Большие автобусы
#         бренд    модель  объём_двиг_л                  сегмент
# 25430  Scania  G-Series          13.0  магистральные перевозки
#         бренд    модель  объём_двиг_л                  сегмент
# 25431  Scania  P-Series          13.0  магистральные перевозки
# 25432  Scania  P-Series          13.0  магистральные перевозки
#         бренд    модель  объём_двиг_л                  сегмент
# 25433  Scania  R-Series          13.0  магистральные перевозки
# 25434  Scania  R-Series          13.0  магистральные перевозки
#         бренд    модель  объём_двиг_л                  сегмент
# 39181  Scania  S-Series          13.0  магистральные перевозки
# 39182  Scania  S-Series          13.0  магистральные перевозки

# %% [markdown]
# Итак, у нас но моделей автомобилей различных брендов с объемом двигателя более 10 литров.
# - Из них две модели - это Chevrolet Niva и Renault Sandero представляют собой легковой автомобиль. Будет весьма вероятным, что настолько большой объем двигателя, приписанный им, возник вследствие ошибки - десятичная точка поставлена неправильно. Исправим ситуацию.
# - Остальные автомобили в выборке - грузовики, траки, автобусы и вполне могут иметь двигатель с объемом, превышающим 10 литров.

# %%
list_for_division = ['Niva', 'Sandero']

# %%
for i in list_for_division:
    data.loc[((data['объём_двиг_л'] >= 10) & (data['модель'] == i)), 'объём_двиг_л']  = \
        data.loc[(data['объём_двиг_л'] >= 10) & (data['модель'] == i), 'объём_двиг_л'] / 10

   # data.query('объём_двиг_л >= 10 and модель == @i')['объём_двиг_л'] = \
    #    data.query('объём_двиг_л >= 10 and модель == @i')['объём_двиг_л'] / 10
    print(data.query('модель == @i')[['бренд', 'модель', 'год_выпуска', 'объём_двиг_л', 'сегмент']].head(2))
# Out:
#          бренд модель год_выпуска  объём_двиг_л        сегмент
# 264  Chevrolet   Niva        2017           1.7  Внедорожники
# 265  Chevrolet   Niva        2018           1.7  Внедорожники
#          бренд   модель год_выпуска  объём_двиг_л сегмент
# 24989  Renault  Sandero        2018           1.6       0
# 24990  Renault  Sandero        2018           1.6       0

# %% [markdown]
# Проверим, тем не менее - какие для указанных автомобилей еще занедены данные об объеме двигателя.

# %% [markdown]
# Проверим для Sandero

# %%
data.loc[((data['модель'] == "Sandero")), 'объём_двиг_л'].unique()
# Out:
# array([1.6])

# %% [markdown]
# Здесь все нормально - указан один литраж - это 1,6 литров

# %% [markdown]
# Проверим для Niva

# %%
data.loc[( (data['модель'] == "Niva")), 'объём_двиг_л'].unique()
# Out:
# array([1.7 , 2.67, 2.57, 2.47, 2.37, 2.27, 2.17, 2.07, 1.97, 1.87, 1.77,
#        1.67, 1.57, 1.47, 1.37, 1.27, 1.17, 1.07, 9.7 , 8.7 , 7.7 , 6.7 ,
#        5.7 , 4.7 , 3.7 , 2.7 ])

# %% [markdown]
# Здерь разброс огромный.
# Уточним имеющиеся в базе года выпуска автомобилей и заглянем в интернет

# %%
data.loc[( (data['модель'] == "Niva")), 'год_выпуска'].unique()
# Out:
# array(['2017', '2018', '2019'], dtype=object)

# %% [markdown]
# [Сайт auto.ru](https://auto.ru/catalog/cars/chevrolet/niva/specifications/harakteristiki-dvigatelya/) подсказывает нам , что на автомобили Niva с 2002 по 2020 годы устанавливался единственно возможный бензиновый джвигатель объемом 1,69 литров.
# Не откладывая внесем изменения.

# %%
data.loc[(data['модель'] == "Niva") & (data['бренд'] == "Chevrolet"), 'объём_двиг_л'] = 1.69

# %%
data.loc[( (data['модель'] == "Niva")), 'объём_двиг_л'].unique()
# Out:
# array([1.69])

# %% [markdown]
# Округлим до одного знака после запятой значения в столбце `объём_двиг_л`

# %%
data['объём_двиг_л'] = round(data['объём_двиг_л'],1)

# %%
data['объём_двиг_л'].unique()
# Out:
# array([ 1.4,  2. ,  3. ,  4.4,  6.6,  1.5,  1.6,  2.4,  1.7,  6.2,  2.5,
#         nan,  2.7,  2.8,  4.3,  3.9,  7.5, 12.3,  3.5,  5.6,  8.7,  5.2,
#         5. ,  1.2,  3.3,  1.8,  4.6,  5.7, 10.5,  4. ,  5.5, 12. , 12.8,
#        11. ,  2.2, 13. ,  1.3,  3.8,  3.6,  7.6,  4.9,  2.9,  0. ,  8.4,
#         6.7,  6.5])

# %% [markdown]
# #### Для значений `nan`
# - найдем марку и модель автомобиля и найдем в интернете cоответствующий объем двигателя

# %%
data.loc[(data['объём_двиг_л'].isna()), 'бренд'].unique()
# Out:
# array(['Foton', 'GAZ', 'Hyundai Truck & Bus', 'Isuzu', 'Iveco', 'Jac',
#        'Jaguar', 'KAMAZ', 'Land Rover', 'MAN', 'Mazda',
#        'Mercedes-Benz Trucks', 'Peugeot', 'Ravon', 'Renault', 'Toyota',
#        'Volkswagen', 'Volvo', 'Урал', 'Shacman', 'Dong Feng', 'ANKAI',
#        'Nefaz'], dtype=object)

# %%
data.loc[(data['объём_двиг_л'].isna()), 'модель'].unique()
# Out:
# array(['BJ3253DMPKB-AD', '2310', '2705', '2752', '3221', '3302', '3308',
#        'Next', 'H350', 'HD 160', 'HD 65', 'HD 78', 'Universe', 'D-MAX',
#        'NMR', 'NPR', 'Daily', 'Daily A', 'Daily V', 'Stralis', 'Tipper',
#        'S3', 'S5', 'XJ', '4308', '4311', '43118', '43253', '43502',
#        '44108', '45142', '45143', '53215', '53504', '53605', '54115',
#        '5490', '65111', '65115', '65116', '65117', '6520', '65206',
#        '65225', '66052', '6606', 'Discovery Sport', 'Range Rover',
#        'Range Rover Evoque', 'Range Rover Sport', 'TG', '3', '6', 'CX-5',
#        'Actros', '301', 'Partner Panel Van', 'Nexia R3', 'R4', 'Duster',
#        'Kaptur', 'Koleos', 'Logan', 'Master', 'Corolla', 'HILUX DC',
#        'Amarok', 'Caravelle', 'Polo', 'Tiguan', 'Touareg',
#        'Transporter Kasten', 'XC90', '4320', '4320-1951-40',
#        '4320-1951-60', '5557', 'CX-9', 'HD 35', 'Range Rover Velar',
#        'X200', 'E-PACE', 'Dokker', 'N120', 'N75', 'T6', 'SX3258DR384',
#        'iev', 'NQR', 'XC60', 'N56', 'NMS85', 'BJ1069VDJEA-F1',
#        'BWC6665GA5', 'HF-D105', 'NPS', 'Teramont', '5299', 'I-Pace',
#        '45141', '32551', 'EX8', 'HFF6850G', 'Setra', 'Arkana', '58815Z'],
#       dtype=object)

# %%
data.loc[(data['объём_двиг_л'].isna()), 'модификация'].unique()
# Out:
# array(['Грузовой автомобиль марки "Foton BJ3253DMPKB-AD" (25 тонн)',
#        'GAZ 23107', 'GAZ 2705', 'GAZ 27055', 'GAZ 27057', 'GAZ 27527',
#        'GAZ 3221', 'GAZ 3302', 'GAZ 33025', 'GAZ 33027', 'GAZ 330202',
#        'GAZ 330232', 'GAZ 330252', 'GAZ 330253', 'GAZ 330273',
#        'GAZ 33086', 'GAZ A63R42', 'GAZ A63R45', 'GAZ A64R45',
#        'GAZ A21R22', 'GAZ A21R23', 'GAZ A21R32', 'GAZ A22R32',
#        'GAZ A22R35', 'GAZ A32R32', 'GAZ A21R33', 'GAZ A21R35',
#        'GAZ A31R23', 'GAZ A31R33', 'GAZ A32R23', 'GAZ A32R33',
#        'GAZ A65R35', 'H350 BUS', 'H350 VAN 6.2', 'H350 Ambulance', nan,
#        'HD 160', 'HD65 Euro 4 KZ', 'HD65 Euro 5', 'Euro 5', 'Euro 4',
#        'HD78 Euro 5', 'HD78/ЕХ8', 'Luxury', 'Universe Luxury', 'D-MAX',
#        'Isuzu NMR85', 'Isuzu NPR75', '70C15', '50C15V',
#        '45C15V (Автобус 14+1)', '50С15 (изотермический фургон)',
#        'HighRoof', '6х4', 'Luxury 1.6 MT', 'Intelligent 1.6 CVT',
#        'Intelligent', 'FL Luxury', 'FL Intelligent', 'Luxury 2.0 MT5',
#        'Intelligent 2.0T MT6', 'KAMAZ 4308', '43119 с КМУ Palfinger',
#        '43118', '43118 с КМУ Palfinger', 'KAMAZ 43118', '43253',
#        'KAMAZ 43253', '43502', 'KAMAZ 43502', '44108', '44108 с ГБО',
#        'KAMAZ 44108', 'KAMAZ 45142', '45143', 'KAMAZ 45143', '53215',
#        'KAMAZ 53215', 'KAMAZ 53504', 'KAMAZ 53605', '54115',
#        '54115-010-15 G', 'KAMAZ 54115', '5490', 'KAMAZ 5490',
#        'KAMAZ 65111', '65115', 'KAMAZ 65115', '65116', 'KAMAZ 65116',
#        '65117', 'KAMAZ 65117', '6520', 'KAMAZ 6520', 'KAMAZ 65207',
#        'KAMAZ 65201', '65206', 'KAMAZ 65206', '65225', 'KAMAZ 65225',
#        'KAMAZ АТЗ 66052', 'KAMAZ 66052', 'KAMAZ 6606',
#        'TGS 26.400 6x4 BLS', 'TGS 19.440 4x2 BLS', 'TGX 18.440 4x2 BLS',
#        'TGS 26.360 6x4 BB', 'TGS 26.400 6x4 BLSWW', 'MAZDA 3', 'MAZDA 6',
#        'MAZDA CX-5', 'Actros 1845 LS 4x2', 'Active 1.6 AT', 'Active',
#        'Active 1.6 МТ', 'Partner VU Active 1.6 МТ', 'Elegant МТ',
#        'ELEGANT AT', 'Elegant АT', 'Optimum MT', 'Comfort Plus МТ',
#        'CDX 1.5 AT', 'Optimum AT', 'R3 Optimum  М/T', 'Elegant R3 A/T',
#        'Comfort Plus MT', 'Elegant MT', 'Elegant МT', 'Comfort MT',
#        'Optimum МT', 'Optimum АТ', 'Optimum АT', 'Elegant AТ', 'E1FB4JA',
#        'E1FB2JA', 'E0DB2JA', 'DKGB4AGA', 'DKGB4AG', 'DKGB4JA', 'E2PGB4AG',
#        'E2PGB4AGA', 'E2GB4AGA', 'E1FB4AG', 'E2GB4AG', 'E2GB4JA',
#        'E1FB4AGA', 'E0DB4JA', 'Z1FB4AG', 'Z2PGB4AG', 'Z2GB4AG',
#        'Z2PGB4AGA', 'Z2GB4AGA', 'Z1FB4JA', 'Z2GB4JA', 'Z0DB2JA',
#        'Z1FB4AGA', 'ADGB4AGA', 'ADGB4AG', 'Z1FB4MD', 'Z0DB4JA', 'Z1FB2JA',
#        'ADGB4JA', 'Z2PGB4 AGA  ', 'Z2PGB4 AG   ', 'Z2 GB4 MD   ',
#        'Z2 GB4 AGA  ', 'Z2 GB4 AG   ', 'AD GB4 AGA  ', 'AD GB4 AG   ',
#        'Z2 GB4 JA   ', 'Z1 FB4 JA   ', 'Z1 FB4 AG   ', 'Z1 FB2 JA   ',
#        'Z0 DB2 JA   ', 'AD GB4 JA   ', 'E2 GB4 AG   ', 'Z1 FB4 AGA  ',
#        'ZB34AAA5C', 'ZB22JAX5C', 'ZB12JAX5C', 'ZB12JA5C', 'EXT4AAA5C',
#        'ZB24AA5C', 'ZB32JAX5C', 'ZB24AAA5C', 'PLY4AAA5C', 'ZB22JA5C',
#        'SLB4AA5C', 'EXT4AA5C', 'PLY2JAX5C', 'ZB34AA5C', 'EXT2JAX5C',
#        'MB34AAA5C', 'MB44AAA5C', 'MB24AAA5C', 'PLY4AA5C', 'MB32JAX5C',
#        'MB22JA5C', 'MB12JA5C', 'MB34AA5C', 'PLA2JAX5C', 'MB42JAX5C',
#        'MB12JAX5C', 'MB22JAX5C', 'MB4 4 AAA5C ', 'MB4 2 JAX5C ',
#        'MB1 2 JAX5C ', 'ZB2 2 JA 5C ', 'MB3 4 AAA5C ', 'MB3 2 JAX5C ',
#        'MB2 2 JAX5C ', 'MB2 4 AAA5C ', 'MB2 2 JA 5C ', 'GM38 N05C C4',
#        'ACCA16K5RB', 'SXPA16PA5RB', 'SXPA16M5RB', 'EXPA16PA5RB',
#        'EXPA16K5RB', 'AUTA16PA5RB', 'CXPA16MV5RB', 'AUTA16K5RB',
#        'AUTA16M5RB', 'CUTA16MV5RB', 'DYNA16PA5RB', 'SUTA16M5RB',
#        'DYNA16M5RB', 'SUTA16K5RB', 'EXPA16M5RB', 'DYNA16K5RB',
#        'SUTA16PA5RB', 'ACC16K5RB', 'SXPA 16M 5RB', 'EXPA 16PA5RB',
#        'DYNA 16PA5RB', 'CXPA 16MV5RB', 'SXPA 16PA5RB', 'SUTA 16PA5RB',
#        'CUTA 16MV5RB', 'AUTA 16PA5RB', 'SUTA 16M 5RB', 'AUTA 16K 5RB',
#        'ACCA 16K 5RB', 'EXPA 16K 5RB', 'TFGB1 223 D6', 'TFGB1 113 D6',
#        'TFGB1113D6', '7', 'JT', 'NX', 'Caravelle',
#        'Polo sedan Drive MPI 81 кВт (110 л.с.), 5-МКП', 'Polo PA',
#        'Tiguan NF', 'Шасси автомобиля Урал 4320-6151-73',
#        'Шасси автомобиля Урал 43206-6151-73',
#        'Грузовой автомобиль Урал 4320-6951-74',
#        'Автомобиль повышенной проходимости для перевозки личного состава. Урал 4320-0111-41',
#        'Грузовой автомобиль 4х4 с бортовой платформой грузоподъемностью от 3000 до 4000 кг на шасси автомоби',
#        'Автомобиль грузовой на базе шасси Урал 4320-1951-72',
#        'Грузовой автомобиль Урал 4320-1951-60',
#        'Самосвал сельхозник двухпозиционный на базе шасси автомобиля Урал 4320-1951-40',
#        'Шасси автомобиля Урал 4320-1951-60',
#        'Грузовой автомобильУрал 5557-4151-82',
#        'Автомобиль грузовой на базе шасси Урал 5557-1112-31',
#        'Mazda CX-9', 'HD35L', 'YFAMBNMVEM', 'YKAMBIMVEM', 'YFBASNMVEM',
#        'YKBASIMVEM', 'YKLAURMVEM', 'YSTEP2MVEM', 'YKLAUR MV EM',
#        'YKBASI MV EM', 'YKAMBI MV EM', 'Шасси для РФ', 'шасси', 'Comfort',
#        'Comfort 2.0 Ti 4x4', 'Comfort 2.0 TDI 4x4',
#        'Автомобиль-самосвал SHACMAN Евро5 модель SX3258DR384',
#        ' Автомобиль-самосвал SHACMAN Евро5 модель SX3258DR384', 'iev7s',
#        'Isuzu NQR90', 'Isuzu NMS85',
#        'Грузовой автомобиль марки "Foton BJ1069VDJEA-F1" ',
#        'Грузовой автомобиль марки "Foton BJ1069VDJEA-F1"',
#        'Автобус Dong Feng BWC6665GA5',
#        'Автобус Dong Feng                   BWC6665GA5', 'Isuzu NPS75',
#        'Teramont', '5299', 'HSE', 'KAMAZ 45141', 'Урал 32551-0013-61',
#        'EX8',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500375',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500374',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500399',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500379',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500369',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500410',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500373',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500413',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500372',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500488',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500354',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500478',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500358',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500350',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500327',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500357',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500351',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500397',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500356',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500402',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500371',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500404',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500370',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500368',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500406',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500412',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500409',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500362',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500408',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500353',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500364',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500401',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500366',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500405',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500414',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500377',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500355',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500380',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500361',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500376',
#        'Diesel 8.5m MT', 'Setra S 511 HD', 'B3P4M3 TX 5C', 'B34 M3 TX 5C',
#        'B32 M3 TX 5C', 'B22M1TX5C', 'B32M1TX5C', 'B12M1TX5C', 'B22M3TX5C',
#        'B32M3TX5C', 'B34M3TX5C', 'B3P4M3TX5C', 'B24M1M65C', 'B3P2M3TX5C',
#        'KAMAZ 58815Z'], dtype=object)

# %%
data.loc[(data['объём_двиг_л'].isna()), 'вид_топлива'].unique()
# Out:
# array([nan, 'd', 'p'], dtype=object)

# %%
len(data.loc[(data['объём_двиг_л'].isna()), 'модель'].unique())
# Out:
# 106

# %% [markdown]
# <div style="border-radius: 45px;border:solid red 7px; padding: 40px">
# Для 107 моделей автомобилей не внесен объем двигателя.
#
# Это очень трудоемко - заполнять данные из интернета для стольких значений
#
# Отложим заполнение этих значений

# %% [markdown]
# ### Обработка данных в столбце `коробка_передач`
# Выведем на экран уникальные значения, указанные в столбце `коробка_передач`

# %%
sorted(data.коробка_передач.unique().astype(str))
# Out:
# [' 7 АКП',
#  '#Н/Д',
#  '0',
#  '12AT',
#  '12АТ',
#  '4 АТ',
#  '4AT',
#  '4АТ',
#  '5 AT',
#  '5 МТ',
#  '5AT',
#  '5M',
#  '5MT',
#  '5АТ',
#  '5М',
#  '5МТ',
#  '6 AT',
#  '6 DSG',
#  '6 MT',
#  '6 АТ',
#  '6 МТ',
#  '6A',
#  '6AT',
#  '6DSG',
#  '6M/T',
#  '6MT',
#  '6А',
#  '6АТ',
#  '6МТ',
#  '7 DCT',
#  '7 DSG',
#  '7 АКПП (PDK)',
#  '7 АКПП PDK',
#  '7AT',
#  '7DCT',
#  '7DSG',
#  '7G-TRONIC',
#  '7АКП',
#  '7АТ',
#  '8',
#  '8 AT',
#  '8 АКПП (PDK)',
#  '8 АКПП Tiptronic S',
#  '8 АТ',
#  '8-ступ АКПП',
#  '8A',
#  '8AT',
#  '8АКПП',
#  '8АТ',
#  '9AT',
#  '9G-TRONIC',
#  'A/T',
#  'AMT',
#  'AT',
#  'CVT',
#  'CVT (вариATор)',
#  'CVT (вариатор)',
#  'CVT(вAриATор)',
#  'DCT',
#  'DSG',
#  'M/T',
#  'MT',
#  'PDK',
#  'Powershift S6',
#  'S-Tronic',
#  'S-tronic',
#  'Steptronic',
#  'TDI',
#  'Tiptronic',
#  'nan',
#  'А/T',
#  'АT',
#  'АКП',
#  'АКПП',
#  'АТ',
#  'М/T',
#  'МT',
#  'МКП',
#  'МКПП',
#  'МТ',
#  'Мех.',
#  'РЕДУКТОР']

# %% [markdown]
# "Почистим" данные:
#
# - обработаем исключения - их проверим вручную: '8', '0', 'TDI', 'РЕДУКТОР'
#     - проверим строки, насколько соответствует отображение данных по столбцам
#     - найдем марку и модель автомобиля и найдем в интернете соответствующий объем двигателя
# - обработаем исключение - 'AMT'
# - приведем все значения к нижнему регистру
# - всё, что содержит букву `м` на кириллице или `m` на латинице - что соответствует механической коробке передач - обозначим как `МКПП`
# - всё остальное будет соответствовать автоматической или автоматизированной, роботизированной коробке передач - обозначим как `АКПП`
# - nan и '#Н/Д'-   найдем марку и модель автомобиля и найдем в интернете соответствующий объем двигателя

# %% [markdown]
# #### Oбработаем значение '8'

# %%
data.query('коробка_передач == "8"')['модель'].unique()
# Out:
# array(['Cayenne'], dtype=object)

# %% [markdown]
# Без дополнительной проверки примем, что у Cayenne автоматическая коробка передач

# %% [markdown]
# #### Oбработаем значение '0'

# %%
data.query('коробка_передач == "0"')['модель'].unique()
# Out:
# array(['Sandero'], dtype=object)

# %%
data.query('коробка_передач == "0"')
# Out:
#         год   месяц        компания    бренд   модель модификация год_выпуска  \
# 24997  2019  Январь  Renault Россия  Renault  Sandero  SXP16PA5RB        2018
# 25002  2019  Январь  Renault Россия  Renault  Sandero  SUT16PA5RB        2018
# 25023  2019  Январь  Renault Россия  Renault  Sandero  SXP16PA5RB        2018
#
#        страна_производитель вид_топлива  объём_двиг_л коробка_передач  \
# 24997  Российская Федерация           p           1.6               0
# 25002  Российская Федерация           p           1.6               0
# 25023  Российская Федерация           p           1.6               0
#
#       тип_привода сегмент      регион наименование_дилерского_центра  \
# 24997         FWD       0      Атырау                 Урал-Кров Авто
# 25002         FWD       0      Атырау                 Урал-Кров Авто
# 25023         FWD       0  Нур-Султан                Автоцентр Астэк
#
#       тип_клиента  количество     цена_usd  продажа_usd             область  \
# 24997         NaN         1.0  12476.89637  12476.89637  Атырауская область
# 25002         NaN         1.0  12476.89637  12476.89637  Атырауская область
# 25023         NaN         1.0  12476.89637  12476.89637        г.Нур-Султан
#
#           сегментация_2013 класс_2013
# 24997  Легковые автомобили    B класс
# 25002  Легковые автомобили    B класс
# 25023  Легковые автомобили    B класс

# %% [markdown]
# Согласно [Сайта](https://www.drom.ru/catalog/renault/sandero/specs/transmission/) Рено Sandero комплектовался и механической и автоматической коробкой передач. У нас отсутствуют какие-либо данные для дополнительной идентификации.
#
# Какие значения мы имеем для этого автомобиля сейчас?

# %%
data.query('модель == "Sandero"').groupby('коробка_передач').agg({'коробка_передач':'count'})
# Out:
#                  коробка_передач
# коробка_передач
# 0                              3
# MT                             3

# %% [markdown]
# Всего 6 значений, половина из которых - Механическая каробка, а вторая половина - не определена.
#
# А сколько всего таких автомобилей в датафрейме?

# %%
len(data.query('модель == "Sandero"'))
# Out:
# 441

# %% [markdown]
# 441 автомобиль.
# Какие значения принимает показатель коробки передач?

# %%
data.query('модель == "Sandero"').коробка_передач.unique()
# Out:
# array([nan, '0', 'MT'], dtype=object)

# %% [markdown]
# Получается, что все остальные - то есть основная масса значений - не имеет указания на тип КПП.
# Учитывая данные [Сайта](https://www.drom.ru/catalog/renault/sandero/specs/transmission/) , из которых виидно, что преимущественно автомобиль комплектуется механической коробкой, примем для этого автомобиля и заполним данные о типе коробки передач значением МКПП

# %%
data.loc[(data.модель == "Sandero"),'коробка_передач'] = "МКПП"

# %% [markdown]
# #### Oбработаем значение 'TDI'

# %%
data.query('коробка_передач == "TDI"')['бренд'].unique()
# Out:
# array(['Jac'], dtype=object)

# %%
data.query('коробка_передач == "TDI"')['модель'].unique()
# Out:
# array(['T6'], dtype=object)

# %%
#data.query('коробка_передач == "TDI"')['модель'].unique()
data.query('коробка_передач == "TDI"').head()
# Out:
#         год   месяц    компания бренд модель модификация год_выпуска  \
# 39077  2019  Апрель  Allur Auto   Jac     T6     Comfort        2019
# 39078  2019  Апрель  Allur Auto   Jac     T6     Comfort        2019
# 39079  2019  Апрель  Allur Auto   Jac     T6     Comfort        2019
# 39080  2019  Апрель  Allur Auto   Jac     T6     Comfort        2019
# 39081  2019  Апрель  Allur Auto   Jac     T6     Comfort        2019
#
#        страна_производитель вид_топлива  объём_двиг_л коробка_передач  \
# 39077  Республика Казахстан           d           2.0             TDI
# 39078  Республика Казахстан           d           2.0             TDI
# 39079  Республика Казахстан           d           2.0             TDI
# 39080  Республика Казахстан           d           2.0             TDI
# 39081  Республика Казахстан           d           2.0             TDI
#
#       тип_привода сегмент  регион наименование_дилерского_центра тип_клиента  \
# 39077         4WD  PICKUP  Атырау                     Рус-Моторс    Юр. Лицо
# 39078         4WD  PICKUP  Алматы              Allur Auto Almaty    Юр. Лицо
# 39079         4WD  PICKUP  Алматы              Allur Auto Almaty    Юр. Лицо
# 39080         4WD  PICKUP  Алматы              Allur Auto Almaty    Юр. Лицо
# 39081         4WD  PICKUP  Алматы              Allur Auto Almaty    Юр. Лицо
#
#        количество     цена_usd  продажа_usd             область  \
# 39077         1.0  21791.24061  21791.24061  Атырауская область
# 39078         1.0  23686.13110  23686.13110            г.Алматы
# 39079         1.0  23686.13110  23686.13110            г.Алматы
# 39080         1.0  23686.13110  23686.13110            г.Алматы
# 39081         1.0  23686.13110  23686.13110            г.Алматы
#
#       сегментация_2013      класс_2013
# 39077     Внедорожники  Компактные SUV
# 39078     Внедорожники  Компактные SUV
# 39079     Внедорожники  Компактные SUV
# 39080     Внедорожники  Компактные SUV
# 39081     Внедорожники  Компактные SUV

# %% [markdown]
# Согласно [Официального сайта](https://jaccar.ru/auto/t6.html) Автомобиль комплектуется как бензиновым, так и дизельным двигателями. Оба вида двигателей имеют равный объем - 2 литра.
# В характеристиках производитель указывает единственно возможный тип коробки передач - механическую
#
# Согласно [Википедии](https://en.wikipedia.org/wiki/TDI_(engine)) TDI (непосредственный впрыск с турбонаддувом) - это термин, которым Volkswagen Group обозначают текущую линейку турбодизельных непосредственным впрыском Common Rail, оснащенных промежуточным охладителем в дополнение к турбокомпрессору.
# То есть мы вправе предположить, что при заполнении таблицы по этому автомобилю сотрудник аббревиатурой TDI обозначил тип двигателя (вид топлива) - и это дизельный двигатель.
#
# Заполним значения и коробки передач и вида топлива

# %%
data.loc[(data['коробка_передач'] == "TDI"), 'вид_топлива'] = "d"
data.loc[(data['коробка_передач'] == "TDI"), 'коробка_передач'] = "МКПП"

# %% [markdown]
# #### Oбработаем значение 'РЕДУКТОР'

# %%
data.query('коробка_передач == "РЕДУКТОР"')['модель'].unique()
#data.query('коробка_передач == "редуктор"')['модель'].unique()
# Out:
# array(['I-Pace'], dtype=object)

# %%
data.query('коробка_передач == "РЕДУКТОР"')
# Out:
#         год    месяц               компания   бренд  модель модификация  \
# 39544  2019  Февраль  Almaty Motors Premium  Jaguar  I-Pace  ЭЛЕКТРОКАР
# 39545  2019   Апрель  Almaty Motors Premium  Jaguar  I-Pace  ЭЛЕКТРОКАР
# 39546  2019     Июнь  Almaty Motors Premium  Jaguar  I-Pace  ЭЛЕКТРОКАР
#
#       год_выпуска страна_производитель вид_топлива  объём_двиг_л  \
# 39544        2019                   UK           e           0.0
# 39545        2019                   UK           e           0.0
# 39546        2019                   UK           e           0.0
#
#       коробка_передач тип_привода сегмент  регион  \
# 39544        РЕДУКТОР         4WD    SUV   Алматы
# 39545        РЕДУКТОР         4WD    SUV   Алматы
# 39546        РЕДУКТОР         4WD    SUV   Алматы
#
#       наименование_дилерского_центра тип_клиента  количество     цена_usd  \
# 39544          Almaty Motors Premium   Физ. Лицо         1.0  117236.9729
# 39545          Almaty Motors Premium   Физ. Лицо         1.0  105388.7924
# 39546          Almaty Motors Premium    Юр. Лицо         1.0  120413.2793
#
#        продажа_usd   область сегментация_2013      класс_2013
# 39544  117236.9729  г.Алматы     Внедорожники  Компактные SUV
# 39545  105388.7924  г.Алматы     Внедорожники  Компактные SUV
# 39546  120413.2793  г.Алматы     Внедорожники  Компактные SUV

# %% [markdown]
# Примем, что у электрического Jaguar автоматическая коробка передач

# %% [markdown]
# #### Oбработаем значение 'AMT'

# %%
data.loc[(data['коробка_передач'] == 'AMT')]
# Out:
#         год     месяц    компания бренд  модель модификация год_выпуска  \
# 17031  2019    Январь  БИПЭК АВТО  Lada  Granta      Granta        2018
# 17102  2019   Февраль  БИПЭК АВТО  Lada  Granta         NaN        2018
# 17112  2019   Февраль  БИПЭК АВТО  Lada  Granta         NaN        2019
# 17213  2019    Апрель  БИПЭК АВТО  Lada  Granta         NaN        2018
# 17228  2019       Май  БИПЭК АВТО  Lada  Granta         NaN        2019
# ...     ...       ...         ...   ...     ...         ...         ...
# 18673  2019    Август  БИПЭК АВТО  Lada    XRAY         NaN        2018
# 18695  2019  Сентябрь  БИПЭК АВТО  Lada    XRAY         NaN        2019
# 18696  2019  Сентябрь  БИПЭК АВТО  Lada    XRAY         NaN        2019
# 18697  2019  Сентябрь  БИПЭК АВТО  Lada    XRAY         NaN        2019
# 18698  2019  Сентябрь  БИПЭК АВТО  Lada    XRAY         NaN        2019
#
#        страна_производитель вид_топлива  объём_двиг_л коробка_передач  \
# 17031  Республика Казахстан           p           1.6             AMT
# 17102  Республика Казахстан           p           1.6             AMT
# 17112  Республика Казахстан           p           1.6             AMT
# 17213  Республика Казахстан           p           1.6             AMT
# 17228  Республика Казахстан           p           1.6             AMT
# ...                     ...         ...           ...             ...
# 18673  Республика Казахстан           p           1.8             AMT
# 18695  Республика Казахстан           p           1.8             AMT
# 18696  Республика Казахстан           p           1.8             AMT
# 18697  Республика Казахстан           p           1.8             AMT
# 18698  Республика Казахстан           p           1.8             AMT
#
#       тип_привода   сегмент            регион наименование_дилерского_центра  \
# 17031    Передний  B класс             Алматы              БИПЭК АВТО Алматы
# 17102    Передний  B класс             Алматы              БИПЭК АВТО Алматы
# 17112    Передний  B класс              Актау               БИПЭК АВТО Актау
# 17213    Передний  B класс   Усть-Каменогорск    БИПЭК АВТО Усть-Каменогорск
# 17228    Передний  B класс            Уральск             БИПЭК АВТО Уральск
# ...           ...       ...               ...                            ...
# 18673    Передний  B класс             Алматы              БИПЭК АВТО Алматы
# 18695    Передний   B класс            Актобе              БИПЭК АВТО Актобе
# 18696    Передний   B класс            Атырау              БИПЭК АВТО Атырау
# 18697    Передний   B класс     Петропавловск       БИПЭК АВТО Петропавловск
# 18698    Передний   B класс  Усть-Каменогорск    БИПЭК АВТО Усть-Каменогорск
#
#       тип_клиента  количество  цена_usd  продажа_usd  \
# 17031         NaN        50.0    8700.0     435000.0
# 17102         NaN        50.0    7100.0     355000.0
# 17112         NaN         1.0    7100.0       7100.0
# 17213         NaN         1.0    7100.0       7100.0
# 17228         NaN         1.0    7100.0       7100.0
# ...           ...         ...       ...          ...
# 18673         NaN         2.0   13800.0      27600.0
# 18695         NaN         1.0   13800.0      13800.0
# 18696         NaN         2.0   13800.0      27600.0
# 18697         NaN         3.0   13800.0      41400.0
# 18698         NaN         1.0   13800.0      13800.0
#
#                               область     сегментация_2013 класс_2013
# 17031                        г.Алматы  Легковые автомобили    B класс
# 17102                        г.Алматы  Легковые автомобили    B класс
# 17112           Мангистауская область  Легковые автомобили    B класс
# 17213  Восточно-Казахстанская область  Легковые автомобили    B класс
# 17228   Западно-Казахстанская область  Легковые автомобили    B класс
# ...                               ...                  ...        ...
# 18673                        г.Алматы  Легковые автомобили    B класс
# 18695             Актюбинская область  Легковые автомобили    B класс
# 18696              Атырауская область  Легковые автомобили    B класс
# 18697    Северо-Казахстанская область  Легковые автомобили    B класс
# 18698  Восточно-Казахстанская область  Легковые автомобили    B класс
#
# [397 rows x 22 columns]

# %%
data.loc[(data['коробка_передач'] == "AMT"), 'коробка_передач'] = "АКПП"

# %% [markdown]
# #### Oбработаем значение '#Н/Д'

# %%
data.loc[(data['коробка_передач'] == '#Н/Д')]
#data.loc[(data['коробка_передач'] == '#н/д')]
# Out:
#         год    месяц                 компания   бренд    модель модификация  \
# 31148  2019  Февраль  Toyota Motor Kazakhstan  Toyota   Corolla           7
# 31149  2019  Февраль  Toyota Motor Kazakhstan  Toyota   Corolla           7
# 32670  2019   Апрель  Toyota Motor Kazakhstan  Toyota  HILUX DC          JT
# 33070  2019     Июль  Toyota Motor Kazakhstan  Toyota  HILUX DC          NX
#
#       год_выпуска страна_производитель вид_топлива  объём_двиг_л  \
# 31148        2019               Турция           p           NaN
# 31149        2019               Турция           p           NaN
# 32670        2019              Таиланд           p           NaN
# 33070        2019              Таиланд           p           NaN
#
#       коробка_передач тип_привода   сегмент      регион  \
# 31148            #Н/Д        #Н/Д  C класс   Нур-Султан
# 31149            #Н/Д        #Н/Д  C класс   Нур-Султан
# 32670            #Н/Д        #Н/Д   Пикапы       Алматы
# 33070            #Н/Д        #Н/Д   Пикапы       Атырау
#
#       наименование_дилерского_центра тип_клиента  количество     цена_usd  \
# 31148            Тойота Центр Астана   Физ. Лицо         1.0  42316.46043
# 31149            Тойота Центр Астана   Физ. Лицо         1.0  42316.46043
# 32670                    Toyota City    Юр. Лицо         1.0  30870.28194
# 33070            Тойота Центр Атырау   Физ. Лицо         1.0  27012.45730
#
#        продажа_usd             область     сегментация_2013 класс_2013
# 31148  42316.46043        г.Нур-Султан  Легковые автомобили    C класс
# 31149  42316.46043        г.Нур-Султан  Легковые автомобили    C класс
# 32670  30870.28194            г.Алматы               Пикапы   Pick-ups
# 33070  27012.45730  Атырауская область               Пикапы   Pick-ups

# %% [markdown]
# [Сайт DROM](https://www.drom.ru/catalog/toyota/corolla/g_2018_9402/) сообщает нам, что автомобиль Toyota Corolla оснащался двумя видами бензиновых двигателей, имел МКПП и вариатор и выпускался только на переднем приводе.
# Внесем изменения в датасет.

# %%
data.loc[(data['модель'] == 'Corolla'), 'вид_топлива'] = "p"

data.loc[(data['модель'] == 'Corolla'), 'тип_привода'] = "FWD"

# %% [markdown]
# [Сайт DROM](https://www.drom.ru/catalog/toyota/hilux_pick_up/2019/) сообщает нам, что автомобиль Toyota HILUX DC оснащался только дизельным двигателем, имел только АКПП и только полный привод.
# Внесем изменения в датасет.

# %%
data.loc[(data['модель'] == 'HILUX DC'), "бренд"].unique()
# Out:
# array(['Toyota'], dtype=object)

# %%
data.loc[(data['модель'] == 'HILUX DC'), 'вид_топлива'] = "d"
data.loc[(data['модель'] == 'HILUX DC'), 'коробка_передач'] = "АКПП"
data.loc[(data['модель'] == 'HILUX DC'), 'тип_привода'] = "4WD"

# %% [markdown]
# #### Oбработаем значение nan

# %%
data.loc[(data['коробка_передач'].isna())]
# Out:
#         год     месяц        компания    бренд          модель  \
# 861    2019      Март           СемАЗ    Foton  BJ3253DMPKB-AD
# 862    2019      Июнь           СемАЗ    Foton  BJ3253DMPKB-AD
# 863    2019      Июнь           СемАЗ    Foton  BJ3253DMPKB-AD
# 864    2019      Июль           СемАЗ    Foton  BJ3253DMPKB-AD
# 865    2019    Август           СемАЗ    Foton  BJ3253DMPKB-AD
# ...     ...       ...             ...      ...             ...
# 39943  2019  Сентябрь  Renault Россия  Renault          Arkana
# 39944  2019  Сентябрь  Renault Россия  Renault          Arkana
# 39945  2019  Сентябрь  Renault Россия  Renault          Arkana
# 39946  2019  Сентябрь  Renault Россия  Renault          Arkana
# 39947  2019  Сентябрь  Renault Россия  Renault          Arkana
#
#                                              модификация год_выпуска  \
# 861    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2019
# 862    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2018
# 863    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2018
# 864    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2018
# 865    Грузовой автомобиль марки "Foton BJ3253DMPKB-A...        2018
# ...                                                  ...         ...
# 39943                                         B3P4M3TX5C        2019
# 39944                                          B32M1TX5C        2019
# 39945                                          B32M1TX5C        2019
# 39946                                          B32M1TX5C        2019
# 39947                                          B34M3TX5C        2019
#
#        страна_производитель вид_топлива  объём_двиг_л коробка_передач  \
# 861    Республика Казахстан         NaN           NaN             NaN
# 862    Республика Казахстан         NaN           NaN             NaN
# 863    Республика Казахстан         NaN           NaN             NaN
# 864    Республика Казахстан         NaN           NaN             NaN
# 865    Республика Казахстан         NaN           NaN             NaN
# ...                     ...         ...           ...             ...
# 39943  Российская Федерация         NaN           NaN             NaN
# 39944  Российская Федерация         NaN           NaN             NaN
# 39945  Российская Федерация         NaN           NaN             NaN
# 39946  Российская Федерация         NaN           NaN             NaN
# 39947  Российская Федерация         NaN           NaN             NaN
#
#       тип_привода сегмент            регион наименование_дилерского_центра  \
# 861           NaN     NaN            Алматы           Меридиан АВТО Алматы
# 862           NaN     NaN  Усть-Каменогорск                          СемАЗ
# 863           NaN     NaN          Кокшетау                 Вираж Кокшетау
# 864           NaN     NaN            Алматы                   Вираж Алматы
# 865           NaN     NaN            Алматы                          СемАЗ
# ...           ...     ...               ...                            ...
# 39943         NaN     NaN        Нур-Султан           Кристалл Авто Астана
# 39944         NaN     NaN           Уральск                 Урал-Кров Авто
# 39945         NaN     NaN            Атырау                 Урал-Кров Авто
# 39946         NaN     NaN           Уральск                 Урал-Кров Авто
# 39947         NaN     NaN            Атырау                 Урал-Кров Авто
#
#       тип_клиента  количество     цена_usd   продажа_usd  \
# 861           NaN         1.0  48275.86207   48275.86207
# 862           NaN         1.0  49735.91972   49735.91972
# 863           NaN         1.0  48784.39304   48784.39304
# 864           NaN         5.0  48725.42295  243627.11480
# 865           NaN         2.0  31031.65229   62063.30457
# ...           ...         ...          ...           ...
# 39943         NaN         1.0  21327.27747   21327.27747
# 39944         NaN         1.0  20889.17526   20889.17526
# 39945         NaN         1.0  20889.17526   20889.17526
# 39946         NaN         1.0  20889.17526   20889.17526
# 39947         NaN         1.0  21275.77320   21275.77320
#
#                               область         сегментация_2013  \
# 861                          г.Алматы  Коммерческие автомобили
# 862    Восточно-Казахстанская область  Коммерческие автомобили
# 863               Акмолинская область  Коммерческие автомобили
# 864                          г.Алматы  Коммерческие автомобили
# 865                          г.Алматы  Коммерческие автомобили
# ...                               ...                      ...
# 39943                    г.Нур-Султан             Внедорожники
# 39944   Западно-Казахстанская область             Внедорожники
# 39945              Атырауская область             Внедорожники
# 39946   Западно-Казахстанская область             Внедорожники
# 39947              Атырауская область             Внедорожники
#
#                       класс_2013
# 861    Крупнотоннажные грузовики
# 862    Крупнотоннажные грузовики
# 863    Крупнотоннажные грузовики
# 864    Крупнотоннажные грузовики
# 865    Крупнотоннажные грузовики
# ...                          ...
# 39943             Компактные SUV
# 39944             Компактные SUV
# 39945             Компактные SUV
# 39946             Компактные SUV
# 39947             Компактные SUV
#
# [2820 rows x 22 columns]

# %%
data.loc[(data['коробка_передач'].isna()), "модификация"].unique()
# Out:
# array(['Грузовой автомобиль марки "Foton BJ3253DMPKB-AD" (25 тонн)',
#        'H350 BUS', 'H350 VAN 6.2', 'H350 Ambulance', nan, 'HD 160',
#        'HD65 Euro 4 KZ', 'HD65 Euro 5', 'Euro 5', 'Euro 4', 'HD78 Euro 5',
#        'HD78/ЕХ8', 'Luxury', 'Universe Luxury', 'D-MAX', 'Isuzu D-MAX',
#        'Isuzu NMR85', 'Isuzu NPR75', '70C15', '50C15V',
#        '45C15V (Автобус 14+1)', '50С15 (изотермический фургон)', '6х4',
#        'Luxury 1.6 MT', 'Intelligent 1.6 CVT', 'Intelligent',
#        'FL Luxury 2.0 MT5', 'FL Intelligent 2.0T MT6', 'FL Luxury',
#        'FL Intelligent', 'Luxury 2.0 MT5', 'Intelligent 2.0T MT6',
#        'TGS 19.440 4x2 BLS', 'TGS 26.400 6x4 BLS', 'TGS 26.360 6x4 BL',
#        'TGX 18.440 4x2 BLS', 'TGS 26.360 6x4 BB', 'TGS 26.400 6x4 BLSWW',
#        'MAZDA 3', 'MAZDA 6', 'MAZDA CX-5', 'Actros 1845 LS 4x2', 'V 250',
#        'Active 1.6 AT', 'Active', 'Active 1.6 МТ',
#        'Partner VU Active 1.6 МТ', 'Elegant МТ', 'ELEGANT AT',
#        'Elegant АT', 'Optimum MT', 'Comfort Plus МТ', 'CDX 1.5 AT',
#        'Optimum AT', 'R3 Optimum  М/T', 'Elegant R3 A/T',
#        'Comfort Plus MT', 'Elegant MT', 'Elegant МT', 'Comfort MT',
#        'Optimum МT', 'Optimum АТ', 'Optimum АT', 'Elegant AТ', 'DKGB4AGA',
#        'DKGB4AG', 'DKGB4JA', 'E2PGB4AG', 'E2PGB4AGA', 'E2GB4AGA',
#        'E1FB2JA', 'E1FB4AG', 'E2GB4AG', 'E2GB4JA', 'E0DB2JA', 'E1FB4AGA',
#        'E0DB4JA', 'Z1FB4AG', 'Z2PGB4AG', 'Z2GB4AG', 'Z2PGB4AGA',
#        'Z2GB4AGA', 'Z1FB4JA', 'E1FB4JA', 'Z2GB4JA', 'Z0DB2JA', 'Z1FB4AGA',
#        'ADGB4AGA', 'ADGB4AG', 'Z1FB4MD', 'Z0DB4JA', 'Z1FB2JA', 'ADGB4JA',
#        'Z2PGB4 AGA  ', 'Z2PGB4 AG   ', 'Z2 GB4 MD   ', 'Z2 GB4 AGA  ',
#        'Z2 GB4 AG   ', 'AD GB4 AGA  ', 'AD GB4 AG   ', 'Z2 GB4 JA   ',
#        'Z1 FB4 JA   ', 'Z1 FB4 AG   ', 'Z1 FB2 JA   ', 'Z0 DB2 JA   ',
#        'AD GB4 JA   ', 'E2 GB4 AG   ', 'Z1 FB4 AGA  ', 'ZB34AAA5C',
#        'ZB22JAX5C', 'ZB12JAX5C', 'ZB12JA5C', 'EXT4AAA5C', 'ZB24AA5C',
#        'ZB32JAX5C', 'ZB24AAA5C', 'PLY4AAA5C', 'ZB22JA5C', 'SLB4AA5C',
#        'EXT4AA5C', 'PLY2JAX5C', 'ZB34AA5C', 'EXT2JAX5C', 'MB34AAA5C',
#        'MB44AAA5C', 'MB24AAA5C', 'PLY4AA5C', 'MB32JAX5C', 'MB22JA5C',
#        'MB12JA5C', 'MB34AA5C', 'PLA2JAX5C', 'MB42JAX5C', 'MB12JAX5C',
#        'MB22JAX5C', 'MB4 4 AAA5C ', 'MB4 2 JAX5C ', 'MB1 2 JAX5C ',
#        'ZB2 2 JA 5C ', 'MB3 4 AAA5C ', 'MB3 2 JAX5C ', 'MB2 2 JAX5C ',
#        'MB2 4 AAA5C ', 'MB2 2 JA 5C ', 'GM38 N05C C4', 'ACCA16K5RB',
#        'SXPA16PA5RB', 'SXPA16M5RB', 'EXPA16PA5RB', 'EXPA16K5RB',
#        'AUTA16PA5RB', 'CXPA16MV5RB', 'AUTA16K5RB', 'AUTA16M5RB',
#        'CUTA16MV5RB', 'DYNA16PA5RB', 'SUTA16M5RB', 'DYNA16M5RB',
#        'SUTA16K5RB', 'EXPA16M5RB', 'DYNA16K5RB', 'SUTA16PA5RB',
#        'ACC16K5RB', 'SXPA 16M 5RB', 'EXPA 16PA5RB', 'DYNA 16PA5RB',
#        'CXPA 16MV5RB', 'SXPA 16PA5RB', 'SUTA 16PA5RB', 'CUTA 16MV5RB',
#        'AUTA 16PA5RB', 'SUTA 16M 5RB', 'AUTA 16K 5RB', 'ACCA 16K 5RB',
#        'EXPA 16K 5RB', 'TFGB1 223 D6', 'TFGB1 113 D6', 'TFGB1113D6',
#        'крупнотоннажные грузовики G440A6x4',
#        'крупнотоннажные грузовики P440A6x4',
#        'Scania P-Series крупнотоннажные грузовики P440A6x4',
#        'Scania R-Series крупнотоннажные грузовики R440A4x2',
#        'Scania R-Series крупнотоннажные грузовики R440B6x2',
#        'Scania R-Series крупнотоннажные грузовики R500A6x4',
#        'крупнотоннажные грузовики R440A4x2',
#        'крупнотоннажные грузовики R440B6x2LB',
#        'крупнотоннажные грузовики R440A4x2NA', 'Caravelle',
#        'Polo sedan Drive MPI 81 кВт (110 л.с.), 5-МКП', 'Polo PA',
#        'Tiguan NF', 'Шасси автомобиля Урал 4320-6151-73',
#        'Шасси автомобиля Урал 43206-6151-73',
#        'Грузовой автомобиль Урал 4320-6951-74',
#        'Автомобиль повышенной проходимости для перевозки личного состава. Урал 4320-0111-41',
#        'Грузовой автомобиль 4х4 с бортовой платформой грузоподъемностью от 3000 до 4000 кг на шасси автомоби',
#        'Автомобиль грузовой на базе шасси Урал 4320-1951-72',
#        'Грузовой автомобиль Урал 4320-1951-60',
#        'Самосвал сельхозник двухпозиционный на базе шасси автомобиля Урал 4320-1951-40',
#        'Шасси автомобиля Урал 4320-1951-60',
#        'Грузовой автомобильУрал 5557-4151-82',
#        'Автомобиль грузовой на базе шасси Урал 5557-1112-31',
#        'Mazda CX-9', 'HD35L', 'YFAMBNMVEM', 'YKAMBIMVEM', 'YFBASNMVEM',
#        'YKBASIMVEM', 'YKLAURMVEM', 'YSTEP2MVEM', 'YKLAUR MV EM',
#        'YKBASI MV EM', 'YKAMBI MV EM', 'Шасси для РФ', 'шасси', 'Comfort',
#        'Comfort 2.0 Ti 4x4', 'Comfort 2.0 TDI 4x4',
#        'Автомобиль-самосвал SHACMAN Евро5 модель SX3258DR384',
#        ' Автомобиль-самосвал SHACMAN Евро5 модель SX3258DR384', 'iev7s',
#        'крупнотоннажные грузовики S440A6x2',
#        'крупнотоннажные грузовики S440A4x2', 'Isuzu NQR90', 'Isuzu NMS85',
#        'Грузовой автомобиль марки "Foton BJ1069VDJEA-F1" ',
#        'Грузовой автомобиль марки "Foton BJ1069VDJEA-F1"',
#        'Автобус Dong Feng BWC6665GA5',
#        'Автобус Dong Feng                   BWC6665GA5', 'Isuzu NPS75',
#        'Teramont', 'HSE', 'Урал 32551-0013-61', 'EX8',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500375',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500374',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500399',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500379',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500369',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500410',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500373',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500413',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500372',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500488',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500354',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500478',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500358',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500350',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500327',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500357',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500351',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500397',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500356',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500402',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500371',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500404',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500370',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500368',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500406',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500412',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500409',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500362',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500408',
#        'Городской автобус ANKAI модели HFF6850G MXBTBGKD0KK500353',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500364',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500401',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500366',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500405',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500414',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500377',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500355',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500380',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500361',
#        'Городской автобус ANKAI модели HFF6850G  MXBTBGKD0KK500376',
#        'Diesel 8.5m MT', 'Bus', 'Setra S 511 HD', 'B3P4M3 TX 5C',
#        'B34 M3 TX 5C', 'B32 M3 TX 5C', 'B22M1TX5C', 'B32M1TX5C',
#        'B12M1TX5C', 'B22M3TX5C', 'B32M3TX5C', 'B34M3TX5C', 'B3P4M3TX5C',
#        'B24M1M65C', 'B3P2M3TX5C'], dtype=object)

# %%
len(data.loc[(data['коробка_передач'].isna()), 'модель'].unique())
# Out:
# 76

# %% [markdown]
# <div style="border-radius: 45px;border:solid red 7px; padding: 40px">
#
#     Общее количество моделей без указания вида коробки передач составляет 76 моделей.
#     Это довольно трудозатратно, чтобы выяснять в интернете для  каждой из них вид коробки передач.
#     Отложим пока заполнение данных в столбце "коробка_передач"

# %% [markdown]
# #### приведем все значения к нижнему регистру

# %%
# приведем все значения к нижнему регистру
data.коробка_передач = data.коробка_передач.str.lower()

# %% [markdown]
# ####  Категоризируем тип коробки передач - разделим на `МКПП` и `АКПП`
# - Всё, что содержит букву `м` на кириллице или `m` на латинице - что соответствует механической коробке передач - обозначим как `МКПП`
# - всё остальное будет соответствовать автоматической или автоматизированной, роботизированной коробке передач - обозначим как `АКПП`

# %% [markdown]
# ##### "Вытащим" при возможности тип коробки передач из столбца `модификация`.
# В некоторых записях отсутствует значение короки передач в столбце `коробка_передач`. Но при этом есть указание на коробку передач в столбце `модификация`.
#
# "Вытащим" при возможности тип коробки передач из столбца `модификация`.
# Новые значения запишем во временный столбец `purpose_category`
# Применим функцию `categorize_purpose_second`

# %%
MT = ['MT', 'M/T', 'МКП']
AT = ['AT', 'A/T']
ex = ['SEAT']
def categorize_purpose_second(total_income):
    #if data.loc[(data['коробка_передач'].isna()), 'коробка_передач'].isna():
        MT = ['MT', 'M/T', 'МКП']
        AT = ['AT', 'A/T']
        ex = ['SEAT']
        for t in MT:
            try:
                if t in total_income:
                    return 'МКПП'
            except:
                pass
        for v in AT:
            try:
                if v in ex:
                    #print (v)
                    pass
                elif v in total_income:
                    return 'AКПП'
            except:
                pass
        return

# %%
data['purpose_category'] = ''
data['purpose_category'] = tqdm(data['модификация'].apply(categorize_purpose_second))
print (data['purpose_category'].isna().sum())
# Out:
# 100%|██████████| 39966/39966 [00:00<00:00, 3623560.96it/s]
# 38038

# %%
#data.loc[~(data['purpose_category'].isna()), 'модификация'].unique()

# %%
#data.loc[~(data['purpose_category'].isna()) & (data['коробка_передач'].isna()), 'модификация'].unique()

# %% [markdown]
# ##### Унифицируем значения из столбца `коробка_передач`.
# Новые значения также запишем во временный столбец `purpose_category`
# Применим функцию `categorize_purpose`

# %%
def categorize_purpose(total_income):
    try:
        if 'м' in total_income:
            return 'МКПП'
        elif 'm' in total_income:
            return 'МКПП'
        return 'AКПП'
    except:
        pass

# %%
data['purpose_category'] = tqdm(data['коробка_передач'].apply(categorize_purpose))
print (data['purpose_category'].isna().sum())
# Out:
# 100%|██████████| 39966/39966 [00:00<00:00, 3472748.16it/s]
# 2820

# %%
data.query('purpose_category == "МКПП"')['коробка_передач'].unique()
# Out:
# array(['5 мт', 'mt', '5мт', 'мех.', '6 mt', '6mt', 'мкпп', 'мт', '6 мт',
#        '6мт', '5mt', '6m/t', 'мt', '5m', 'm/t', 'мкп', '5м', 'м/t'],
#       dtype=object)

# %%
data.query('purpose_category == "AКПП"')['коробка_передач'].unique()
# Out:
# array(['s-tronic', 'tiptronic', 'акпп', 'акп', 'steptronic', 'at', '6 ат',
#        '6ат', '8at', 'powershift s6', '6at', '6 at', '5 at', '5at',
#        '7 dct', '7dct', '8 at', 'cvt', 'dct', '4 ат', '4ат', '4at', '8ат',
#        '8 ат', 'cvt (вариатор)', 'cvt (вариatор)', 'cvt(вaриatор)',
#        '7g-tronic', '9g-tronic', '12at', '12ат', '5ат', '7ат', '7at',
#        'pdk', '8-ступ акпп', '8', '8акпп', '8 акпп tiptronic s',
#        '7 акпп (pdk)', '7 акпп pdk', '8 акпп (pdk)', 'ат', 'аt', '7 dsg',
#        '7dsg', '6 dsg', '6dsg', '#н/д', 'dsg', '6a', '6а', 'a/t',
#        ' 7 акп', '7акп', 'а/t', '8a', '9at', 'редуктор'], dtype=object)

# %%
data.query('purpose_category.isna()')['коробка_передач'].unique()
# Out:
# array([nan], dtype=object)

# %%
data.query('коробка_передач == "#н/д"')['модель']
# Out:
# 31148    Corolla
# 31149    Corolla
# Name: модель, dtype: object

# %% [markdown]
# ##### Обновим значения в столбце `коробка_передач`.
# Перенесем значения из временного столбца `purpose_category` в столбец `коробка_передач`.

# %%
data['коробка_передач'] = data['purpose_category']

# %%
len(data.loc[(data['коробка_передач'].isna())])
# Out:
# 2820

# %% [markdown]
# <div style="border-radius: 45px;border:solid red 7px; padding: 40px">
#
# У нас осталось 2820 пустых значений в столбце `коробка передач`.
# Обработаем их чуть позже

# %% [markdown]
# ### Обработка данных в столбце `тип_привода`
# Выведем на экран уникальные значения, указанные в столбце `тип_привода`

# %%
sorted(data.тип_привода.unique().astype(str))
# Out:
# ['0',
#  '2 WD',
#  '2WD',
#  '4 WD',
#  '4Motion',
#  '4WD',
#  '4X2',
#  '4X4',
#  '4x2',
#  '4x4',
#  '4х2',
#  '4х2.2',
#  '4х4',
#  'AWD',
#  'FF',
#  'FWD',
#  'RWD',
#  'nan',
#  'quattro',
#  'Астана',
#  'Задний',
#  'Передний',
#  'Передний (FF)',
#  'Полный',
#  'передний',
#  'полный']

# %% [markdown]
# "Почистим" данные:
#
# - обработаем исключения - их проверим вручную: '0', 'Астана'
#     - проверим строки, насколько соответствует отображение данных по столбцам
#     - найдем марку и модель автомобиля и найдем в интернете соответствующий объем двигателя
# - nan - найдем марку и модель автомобиля и найдем в интернете соответствующий объем двигателя
# - составим словарь для замены и приведения к единообразию. Обозначим:
#  - FWD - передний привод
#  - RWD - задний привод
#  - AWD - полный привод
#  - 2WD - привод на одну ось - но не известно, на какую

# %% [markdown]
# #### Oбработаем значение '0'

# %%
data.query('тип_привода == "0"')['модель'].unique()
# Out:
# array(['Duster', 'Kaptur', 'Logan'], dtype=object)

# %% [markdown]
# Согласно [Сайта](https://www.drom.ru/catalog/renault/kaptur/specs/drive_type/) Рено Kaptur комплектовался и передним и полным приводом. Аналогиная ситуация с Рено Duster. У нас отсутствуют какие-либо данные для дополнительной идентификации.
#
# Рено Logan при этом выпускался только на переднем приводе. Приведем значения в соответствие.

# %%
data.loc[(data.модель == "Logan"),'тип_привода'] = "FWD"

# %% [markdown]
# #### Oбработаем значение 'Астана'

# %%
data.query('тип_привода == "Астана"')
# Out:
#         год месяц  компания  бренд модель  модификация год_выпуска  \
# 15771  2019   Май  ТК КАМАЗ  KAMAZ  65116  KAMAZ 65116        2019
# 39549  2019   Май  ТК КАМАЗ  KAMAZ  45141  KAMAZ 45141        2019
#
#        страна_производитель вид_топлива  объём_двиг_л коробка_передач  \
# 15771  Республика Казахстан           d           NaN            МКПП
# 39549  Республика Казахстан           d           NaN            МКПП
#
#       тип_привода              сегмент      регион  \
# 15771      Астана  Грузовой автомобиль  Нур-Султан
# 39549      Астана  Грузовой автомобиль  Нур-Султан
#
#       наименование_дилерского_центра тип_клиента  количество     цена_usd  \
# 15771    Акмолинский Автоцентр КАМАЗ    Юр. Лицо         1.0  55655.86316
# 39549    Акмолинский Автоцентр КАМАЗ    Юр. Лицо         1.0  53963.81966
#
#        продажа_usd       область         сегментация_2013  \
# 15771  55655.86316  г.Нур-Султан  Коммерческие автомобили
# 39549  53963.81966  г.Нур-Султан  Коммерческие автомобили
#
#                       класс_2013 purpose_category
# 15771  Крупнотоннажные грузовики             МКПП
# 39549  Крупнотоннажные грузовики             МКПП

# %% [markdown]
# Согласно [Сайта](https://kamautocentr.ru/catalogue/Sedelnyetygachievro5/65116-7010-48-a5-163.html?utm_source=yandex&utm_medium=cpc&utm_campaign=ПОИСК%2FСпецпредложение%2F&utm_content=54901-70014-94&utm_term=---autotargeting&yclid=4598577166838661119) Официального дилера KAMAZ 65116	производится с колесной формулой 6х4 и является заднеприводным автомобилем.
#
# Согласно [Сайта "Грузовик"](https://gruzovik.biz/articles/kamaz-45141-tekhnicheskie-kharakteristiki) KAMAZ 45141 обладает колесной формулой 6х6 и является полноприводным автомобилем.
#
# Приведем значения в соответствие для всех имеющихся в датафрейме соответствующих значений.

# %%
data.loc[(data.модификация == "KAMAZ 65116"),'тип_привода'] = "RWD"
data.loc[(data.модификация == "KAMAZ 45141"),'тип_привода'] = "AWD"

# %% [markdown]
# #### Oбработаем значение nan

# %%
#data.loc[(data['тип_привода'].isna())]

# %%
#data.loc[(data['тип_привода'].isna()), "модификация"].unique()

# %%
len(data.loc[(data['тип_привода'].isna()), 'модель'].unique())
# Out:
# 94

# %%
len(data.loc[(data['тип_привода'].isna())])
# Out:
# 3549

# %% [markdown]
# <div style="border-radius: 45px;border:solid red 7px; padding: 40px">
#
# Общее количество моделей без указания типа привода составляет 94 моделей.
# Общее количество записей без указания типа привода - 3549 записей.
# Это довольно трудозатратно, чтобы выяснять в интернете для  каждой из них вид коробки передач.
# Отложим пока заполнение данных в столбце "коробка_передач"

# %% [markdown]
# ####  Категоризируем тип привода - разделим на
#  - FWD - передний привод
#  - RWD - задний привод
#  - AWD - полный привод
#  - 2WD - привод на одну ось - но не известно, на какую`

# %% [markdown]
# ##### "Вытащим" при возможности тип привода из столбца `модификация`.
# В некоторых записях отсутствует значение короки передач в столбце `тип_привода`. Но при этом есть указание на тип привода в столбце `модификация`.
#
# "Вытащим" при возможности тип привода из столбца `модификация`.
# Идентифицируемые указания на тип привода: '4Motion', '4x4', '4MOTION', '4x2', '6x4'
# Новые значения запишем во временный столбец `drive_category`
# Применим функцию `categorize_drive_per_modif`

# %%
#FWD = [] # - передний привод
RWD_per_modif = ['4x2', '6x4'] # - задний привод
AWD_per_modif = ['4Motion', '4x4', '4MOTION'] # - полный привод
#2WD = [] # - привод на одну ось - но не известно, на какую

# %%
def categorize_drive_per_modif(total_income):
    #if data.loc[(data['коробка_передач'].isna()), 'коробка_передач'].isna():
        MT = ['MT', 'M/T', 'МКП']
        AT = ['AT', 'A/T']
        ex = ['SEAT']
        for t in RWD_per_modif:
            try:
                if t in total_income:
                    return 'RWD'
            except:
                pass
        for v in AWD_per_modif:
            try:
                if v in total_income:
                    return 'AWD'
            except:
                pass
        return

# %%
data['drive_category'] = ''
data['drive_category'] = tqdm(data['модификация'].apply(categorize_drive_per_modif))
print (data['drive_category'].isna().sum())
# Out:
# 100%|██████████| 39966/39966 [00:00<00:00, 3538578.77it/s]
# 39799

# %%
len(data.query('~drive_category.isna() and тип_привода.isna()')[['модификация', 'тип_привода', 'drive_category']])
# Out:
# 74

# %% [markdown]
# <div style="border-radius: 45px;border:solid blue 7px; padding: 40px">
# Мы заполнили 74 строки (из 3549 строк) значениями, содержащими тип привода - из тех, у которых в столбце `тип_привода` отсуствует значение!

# %% [markdown]
# ##### Унифицируем значения из столбца `тип_привода`.
# Новые значения также запишем во временный столбец `drive_category`
# Применим функцию `categorize_drive`

# %% [markdown]
# Создадим переменную `type_drive`, в которую сохраним перечень уникальных значений, присутствующих в столбце `тип_привода`

# %%
type_drive = sorted(data.тип_привода.unique().astype(str))

# %% [markdown]
# Сформируем переменные для каждого типа привода, куда запишем соответствующие значения из столбца `тип_привода`

# %%
# Номера элементов для переднего привода
drive_FWD = [14, 15, 20, 21, -2]
# формируем переменную с идентификаторами переднего привода
type_drive_FWD = []
for i in drive_FWD:
    type_drive_FWD.append(type_drive[i])

type_drive_FWD
# Out:
# ['FF', 'FWD', 'Передний', 'Передний (FF)', 'передний']

# %%
# Номера элементов для заднего привода
drive_RWD = [6, 8, 10, 11, 16, 19]
# формируем переменную с идентификаторами заднего привода
type_drive_RWD = []
for i in drive_RWD:
    type_drive_RWD.append(type_drive[i])

type_drive_RWD
# Out:
# ['4X2', '4x2', '4х2', '4х2.2', 'RWD', 'Задний']

# %%
# Номера элементов для полного привода
drive_AWD = [3, 4, 5, 7, 9, 12, 13, 18, 22, 24]
# формируем переменную с идентификаторами полного привода
type_drive_AWD = []
for i in drive_AWD:
    type_drive_AWD.append(type_drive[i])

type_drive_AWD
# Out:
# ['4 WD',
#  '4Motion',
#  '4WD',
#  '4X4',
#  '4x4',
#  '4х4',
#  'AWD',
#  'quattro',
#  'Полный',
#  'полный']

# %%
# Номера элементов для привод на одну ось - но не известно, на какую
drive_2WD = [1, 2]
# формируем переменную с идентификаторами привод на одну ось - но не известно, на какую
type_drive_2WD = []
for i in drive_2WD:
    type_drive_2WD.append(type_drive[i])

type_drive_2WD
# Out:
# ['2 WD', '2WD']

# %% [markdown]
# Произведем категоризацию данных о типе привода.
# Применим функцию `categorize_drive`
# Результат сохраним в столбец `drive_category`

# %%
def categorize_drive(total_income):
    #if data.loc[(data['коробка_передач'].isna()), 'коробка_передач'].isna():

        for t in type_drive_FWD:
            try:
                if t in total_income:
                    return 'FWD'
            except:
                pass
        for s in type_drive_RWD:
            try:
                if s in total_income:
                    return 'RWD'
            except:
                pass
        for v in type_drive_AWD:
            try:
                if v in total_income:
                    return 'AWD'
            except:
                pass
        for w in type_drive_2WD:
            try:
                if w in total_income:
                    return '2WD'
            except:
                pass
        return

# %%
data['drive_category'] = ''
data['drive_category'] = tqdm(data['тип_привода'].apply(categorize_drive))
print (data['drive_category'].isna().sum())
# Out:
# 100%|██████████| 39966/39966 [00:00<00:00, 3478224.54it/s]
# 3609

# %% [markdown]
# ##### Обновим значения в столбце `тип_привода`.
# Перенесем значения из временного столбца `drive_category` в столбец `тип_привода`.

# %%
data['тип_привода'] = data['drive_category']

# %%
len(data.loc[(data['тип_привода'].isna())])
# Out:
# 3609

# %% [markdown]
# <div style="border-radius: 45px;border:solid blue 7px; padding: 40px">
#
# У нас осталось 3609 пустых значений в столбце `тип_привода`.
# Обработаем их чуть позже

# %% [markdown]
# <div style="border-radius: 45px;border:solid blue 7px; padding: 40px">
#
# Подведем промежуточный итог и посмотрим, какая доля ячеек осталась незаполненными

# %%
display(round(data.isna().mean() * 100).astype(int))
# Out:
# год                                0
# месяц                              0
# компания                           0
# бренд                              0
# модель                             0
# модификация                        9
# год_выпуска                        1
# страна_производитель               0
# вид_топлива                        7
# объём_двиг_л                      10
# коробка_передач                    7
# тип_привода                        9
# сегмент                           17
# регион                             0
# наименование_дилерского_центра     0
# тип_клиента                       18
# количество                         0
# цена_usd                           0
# продажа_usd                        0
# область                            0
# сегментация_2013                   0
# класс_2013                         0
# purpose_category                   7
# drive_category                     9
# dtype: int64

# %% [markdown]
# ### Заполним модой значения в столбцах
# - 'вид_топлива',
# - 'объём_двиг_л',
# - 'коробка_передач',
# - 'тип_привода'
#
# Заполним на основе значений в столбце `модель`.
#
# Используем функцию `fill_gaps`

# %%
def fill_gaps(columb_name, support_col):
    variable_name = data.loc[(data[columb_name].isna()), support_col].unique().tolist()
    print("\033[94m""\033[1m""На входе отсутствуют данные для вычисления моды у моделей:""\033[0m")
    print(variable_name)

    x_temp = []
    for i in variable_name:
        try:
            data.loc[(data[support_col] == i) & (data[columb_name].isna()), columb_name] = \
                data.loc[(data[support_col] == i), columb_name].mode()[0]

        except:
            x_temp.append(i)

    print("\033[94m""\033[1m""После заполнения отсутствуют данные для вычисления моды у моделей:""\033[0m")
    print(x_temp)
    print("\033[94m""\033[1m""Заполнили", len(variable_name) - len(x_temp),
          "моделей, что составило", (1-len(x_temp)/len(variable_name))*100, '%' "\033[0m")

# %%
cols_names_4 = ['вид_топлива', 'объём_двиг_л','коробка_передач', 'тип_привода']

# %%
for i in cols_names_4:
    fill_gaps(i, 'модель')
# Out:
# На входе отсутствуют данные для вычисления моды у моделей:
# ['BJ3253DMPKB-AD', '2310', '2705', '2752', '3221', '3302', '3308', 'Next', 'H350', 'HD 160', 'HD 65', 'HD 78', 'Universe', 'Daily', 'Daily A', 'Daily V', 'Stralis', 'Tipper', 'S3', 'S5', 'XJ', 'ВИС', 'Discovery Sport', 'Range Rover', 'Range Rover Evoque', 'Range Rover Sport', 'TG', '3', '6', 'CX-5', '301', 'Partner Panel Van', 'Duster', 'Kaptur', 'Koleos', 'Logan', 'Master', '3151', '3741', 'Cargo', 'Patriot Pickup', 'Amarok', 'Caravelle', 'Polo', 'Tiguan', 'Touareg', 'Transporter Kasten', 'XC90', '4320', '4320-1951-40', '4320-1951-60', '5557', 'CX-9', 'HD 35', 'Range Rover Velar', 'E-PACE', 'Dokker', 'N120', 'N75', 'T6', 'SX3258DR384', 'XC60', 'N56', 'BJ1069VDJEA-F1', 'BWC6665GA5', 'HF-D105', 'Teramont', 'I-Pace', '32551', 'EX8', 'HFF6850G', 'Arkana']
# После заполнения отсутствуют данные для вычисления моды у моделей:
# ['BJ3253DMPKB-AD', 'HD 160', 'Daily A', 'Daily V', 'Stralis', 'Tipper', '3', '6', 'CX-5', 'Kaptur', 'Koleos', 'Logan', 'Master', '3741', '4320', '4320-1951-40', '4320-1951-60', '5557', 'CX-9', 'Dokker', 'SX3258DR384', 'BJ1069VDJEA-F1', 'BWC6665GA5', 'HF-D105', '32551', 'EX8', 'Arkana']
# Заполнили 45 моделей, что составило 62.5 %
# На входе отсутствуют данные для вычисления моды у моделей:
# ['BJ3253DMPKB-AD', '2310', '2705', '2752', '3221', '3302', '3308', 'Next', 'H350', 'HD 160', 'HD 65', 'HD 78', 'Universe', 'D-MAX', 'NMR', 'NPR', 'Daily', 'Daily A', 'Daily V', 'Stralis', 'Tipper', 'S3', 'S5', 'XJ', '4308', '4311', '43118', '43253', '43502', '44108', '45142', '45143', '53215', '53504', '53605', '54115', '5490', '65111', '65115', '65116', '65117', '6520', '65206', '65225', '66052', '6606', 'Discovery Sport', 'Range Rover', 'Range Rover Evoque', 'Range Rover Sport', 'TG', '3', '6', 'CX-5', 'Actros', '301', 'Partner Panel Van', 'Nexia R3', 'R4', 'Duster', 'Kaptur', 'Koleos', 'Logan', 'Master', 'Corolla', 'HILUX DC', 'Amarok', 'Caravelle', 'Polo', 'Tiguan', 'Touareg', 'Transporter Kasten', 'XC90', '4320', '4320-1951-40', '4320-1951-60', '5557', 'CX-9', 'HD 35', 'Range Rover Velar', 'X200', 'E-PACE', 'Dokker', 'N120', 'N75', 'T6', 'SX3258DR384', 'iev', 'NQR', 'XC60', 'N56', 'NMS85', 'BJ1069VDJEA-F1', 'BWC6665GA5', 'HF-D105', 'NPS', 'Teramont', '5299', 'I-Pace', '45141', '32551', 'EX8', 'HFF6850G', 'Setra', 'Arkana', '58815Z']
# После заполнения отсутствуют данные для вычисления моды у моделей:
# ['BJ3253DMPKB-AD', 'HD 160', 'Daily A', 'Daily V', 'Stralis', 'Tipper', '4308', '4311', '43118', '43253', '43502', '44108', '45142', '45143', '53215', '53504', '53605', '54115', '5490', '65111', '65115', '65116', '65117', '6520', '65206', '65225', '66052', '6606', '3', '6', 'CX-5', 'Kaptur', 'Koleos', 'Logan', 'Master', '4320', '4320-1951-40', '4320-1951-60', '5557', 'CX-9', 'X200', 'Dokker', 'N75', 'SX3258DR384', 'iev', 'NMS85', 'BJ1069VDJEA-F1', 'BWC6665GA5', 'HF-D105', '5299', '45141', '32551', 'EX8', 'Setra', 'Arkana', '58815Z']
# Заполнили 50 моделей, что составило 47.16981132075472 %
# На входе отсутствуют данные для вычисления моды у моделей:
# ['BJ3253DMPKB-AD', 'H350', 'HD 160', 'HD 65', 'HD 78', 'Universe', 'D-MAX', 'NMR', 'NPR', 'Daily', 'Daily A', 'Daily V', 'Tipper', 'S3', 'S5', 'XJ', 'Discovery Sport', 'Range Rover', 'Range Rover Evoque', 'Range Rover Sport', 'TG', '3', '6', 'CX-5', 'Actros', 'V-Class', '301', 'Partner Panel Van', 'Nexia R3', 'R4', 'Duster', 'Kaptur', 'Koleos', 'Logan', 'Master', 'G-Series', 'P-Series', 'R-Series', 'Amarok', 'Caravelle', 'Polo', 'Tiguan', 'Touareg', 'Transporter Kasten', 'XC90', '4320', '4320-1951-40', '4320-1951-60', '5557', 'CX-9', 'HD 35', 'Range Rover Velar', 'E-PACE', 'Dokker', 'N120', 'N75', 'T6', 'SX3258DR384', 'iev', 'S-Series', 'NQR', 'XC60', 'N56', 'NMS85', 'BJ1069VDJEA-F1', 'BWC6665GA5', 'HF-D105', 'NPS', 'Teramont', 'I-Pace', '32551', 'EX8', 'HFF6850G', 'HFF6124G03EV3', 'Setra', 'Arkana']
# После заполнения отсутствуют данные для вычисления моды у моделей:
# ['BJ3253DMPKB-AD', 'HD 160', 'D-MAX', 'NMR', 'NPR', 'Daily A', 'Daily V', 'Tipper', 'TG', '3', '6', 'CX-5', 'Kaptur', 'Koleos', 'Logan', 'Master', 'G-Series', 'P-Series', 'R-Series', '4320', '4320-1951-40', '4320-1951-60', '5557', 'CX-9', 'Dokker', 'SX3258DR384', 'iev', 'S-Series', 'NQR', 'NMS85', 'BJ1069VDJEA-F1', 'BWC6665GA5', 'HF-D105', 'NPS', '32551', 'EX8', 'HFF6124G03EV3', 'Setra', 'Arkana']
# Заполнили 37 моделей, что составило 48.68421052631579 %
# На входе отсутствуют данные для вычисления моды у моделей:
# ['BJ3253DMPKB-AD', 'H350', 'HD 160', 'HD 65', 'HD 78', 'Universe', 'NMR', 'NPR', 'Daily', 'Daily A', 'Daily V', 'Tipper', 'S3', 'S5', 'XJ', '4308', '4311', '43118', '43253', '43502', '44108', '45142', '45143', '53215', '53504', '53605', '54115', '5490', '65111', '65115', '65116', '65117', '6520', '65206', '65225', '66052', '6606', 'Discovery Sport', 'Range Rover', 'Range Rover Evoque', 'Range Rover Sport', 'TG', '3', '6', 'CX-5', 'Actros', 'V-Class', '301', 'Partner Panel Van', 'Nexia R3', 'R4', 'Duster', 'Kaptur', 'Koleos', 'Master', 'G-Series', 'P-Series', 'R-Series', 'Amarok', 'Caravelle', 'Polo', 'Tiguan', 'Touareg', 'Transporter Kasten', 'XC90', '4320', '4320-1951-40', '4320-1951-60', '5557', 'CX-9', 'HD 35', 'Range Rover Velar', 'E-PACE', 'Dokker', 'N120', 'N75', 'T6', 'SX3258DR384', 'iev', 'S-Series', 'XC60', 'N56', 'BJ1069VDJEA-F1', 'BWC6665GA5', 'HF-D105', 'Teramont', '5299', 'I-Pace', '32551', 'EX8', 'HFF6850G', 'Setra', 'Arkana', '58815Z']
# После заполнения отсутствуют данные для вычисления моды у моделей:
# ['BJ3253DMPKB-AD', 'HD 160', 'Daily A', 'Daily V', 'Tipper', '4308', '4311', '43118', '43253', '43502', '44108', '45142', '45143', '53215', '53504', '53605', '54115', '5490', '65111', '65115', '65117', '6520', '65206', '65225', '66052', '6606', 'TG', '3', '6', 'CX-5', 'Kaptur', 'Koleos', 'Master', 'G-Series', 'P-Series', 'R-Series', '4320', '4320-1951-40', '4320-1951-60', '5557', 'CX-9', 'Dokker', 'SX3258DR384', 'iev', 'S-Series', 'BJ1069VDJEA-F1', 'BWC6665GA5', 'HF-D105', '5299', '32551', 'EX8', 'Setra', 'Arkana', '58815Z']
# Заполнили 40 моделей, что составило 42.553191489361694 %

# %% [markdown]
# <div style="border-radius: 45px;border:solid blue 7px; padding: 40px">
# Как видим, остались незаполненные значения

# %% [markdown]
# ### Еще раз заполним модой значения в столбцах
# - 'вид_топлива',
# - 'объём_двиг_л',
# - 'коробка_передач',
# - 'тип_привода'
#
# На этот раз либо заполним на основе значений в столбце `класс_2013`.
#
# Используем функцию `fill_gaps_per_class`

# %%
for i in cols_names_4:
    fill_gaps(i, 'класс_2013')
# Out:
# На входе отсутствуют данные для вычисления моды у моделей:
# ['Крупнотоннажные грузовики', 'Среднетоннажные грузовики', 'Микроавтобусы', 'Развозные автомобили', 'Малотоннажные грузовики', 'C класс', 'D класс', 'Компактные SUV', 'Субкомпактные SUV', 'B класс', 'Полноразмерные SUV', 'Компактвэн', 'Средние автобусы', 'Большие автобусы']
# После заполнения отсутствуют данные для вычисления моды у моделей:
# []
# Заполнили 14 моделей, что составило 100.0 %
# На входе отсутствуют данные для вычисления моды у моделей:
# ['Крупнотоннажные грузовики', 'Среднетоннажные грузовики', 'Микроавтобусы', 'Развозные автомобили', 'Малотоннажные грузовики', 'C класс', 'D класс', 'Компактные SUV', 'Субкомпактные SUV', 'B класс', 'Полноразмерные SUV', 'Компактвэн', 'Средние автобусы', 'Большие автобусы']
# После заполнения отсутствуют данные для вычисления моды у моделей:
# []
# Заполнили 14 моделей, что составило 100.0 %
# На входе отсутствуют данные для вычисления моды у моделей:
# ['Крупнотоннажные грузовики', 'Среднетоннажные грузовики', 'Pick-ups', 'Малотоннажные грузовики', 'Микроавтобусы', 'Развозные автомобили', 'C класс', 'D класс', 'Компактные SUV', 'Субкомпактные SUV', 'B класс', 'Полноразмерные SUV', 'Компактвэн', 'Средние автобусы', 'Большие автобусы']
# После заполнения отсутствуют данные для вычисления моды у моделей:
# []
# Заполнили 15 моделей, что составило 100.0 %
# На входе отсутствуют данные для вычисления моды у моделей:
# ['Крупнотоннажные грузовики', 'Среднетоннажные грузовики', 'Микроавтобусы', 'Развозные автомобили', 'Малотоннажные грузовики', 'C класс', 'D класс', 'Компактные SUV', 'Субкомпактные SUV', 'Полноразмерные SUV', 'Компактвэн', 'Средние автобусы', 'Большие автобусы']
# После заполнения отсутствуют данные для вычисления моды у моделей:
# []
# Заполнили 13 моделей, что составило 100.0 %

# %% [markdown]
# Удостоверимся, что в столбцах 'вид_топлива', 'объём_двиг_л','коробка_передач', 'тип_привода' заполнены все значения:

# %%
display(round(data.isna().mean() * 100).astype(int))
# Out:
# год                                0
# месяц                              0
# компания                           0
# бренд                              0
# модель                             0
# модификация                        9
# год_выпуска                        1
# страна_производитель               0
# вид_топлива                        0
# объём_двиг_л                       0
# коробка_передач                    0
# тип_привода                        0
# сегмент                           17
# регион                             0
# наименование_дилерского_центра     0
# тип_клиента                       18
# количество                         0
# цена_usd                           0
# продажа_usd                        0
# область                            0
# сегментация_2013                   0
# класс_2013                         0
# purpose_category                   7
# drive_category                     9
# dtype: int64

# %% [markdown]
# #### категоризируем данные в столбце `тип_клиента` и `количество`
# Выведем на экран уникальные значения, указанные в столбце `тип_клиента`

# %% [markdown]
# ### Обработка данных в столбцах `тип_клиента` и `количество`
# Выведем на экран уникальные значения, указанные в столбце `тип_клиента`

# %%
sorted(data.тип_клиента.unique().astype(str))
# Out:
# ['nan',
#  'Корп. клиент',
#  'Физ. Лицо',
#  'ФизЛицо',
#  'Юр. Лицо',
#  'Юр.Лицо',
#  'ЮрЛицо',
#  'физ.лицо',
#  'физическое',
#  'юридическое']

# %%
# приведем все значения к нижнему регистру
data.тип_клиента = data.тип_клиента.str.lower()

# %% [markdown]
# #### Унифицируем значения из столбца `тип_клиента`.
# Применим функцию `categorize_client_type`

# %%
def categorize_client_type(total_income):
    try:
        if 'физ' in total_income:
            return 'Физлицо'
        elif 'юр' in total_income:
            return 'Юрлицо'
        elif 'корп' in total_income:
            return 'Юрлицо'

    except:
        pass

# %%
data['тип_клиента'] = data['тип_клиента'].apply(categorize_client_type)
print (data['тип_клиента'].isna().sum())
# Out:
# 7047

# %%
sorted(data.тип_клиента.unique().astype(str))
# Out:
# ['None', 'Физлицо', 'Юрлицо']

# %% [markdown]
# #### Oбработаем значение nan

# %%
#data.loc[(data['тип_клиента'].isna())]

# %%
data.loc[(data['тип_клиента'].isna()), "количество"].unique()
# Out:
# array([  2.,   1.,   4.,   3.,   7.,   5.,   8.,  10.,   6.,   9.,  11.,
#         19.,  12.,  18.,  37.,  17.,  15.,  24.,  29.,  14.,  13.,  25.,
#         63.,  23.,  30.,  21.,  60.,  nan,  22.,  16.,  35.,  28.,  32.,
#         54., 115.,  46.,  33.,  47.,  20.,  66.,  27.,  50.,  36.,  26.,
#         31.,  34.,  40.,  43.,  51.,  42.,  38.,  41., 100.,  -1.,  79.,
#         62.])

# %%
len(data.loc[(data['тип_клиента'].isna()), "количество"].unique())
# Out:
# 56

# %%
len(data.loc[(data['тип_клиента'].isna())])
# Out:
# 7047

# %% [markdown]
# - Не заполнено 7047 записей.
# - Клиенты покупали от 1 до 115 единиц автомобилей.
# - Данные представлены в числовом виде.
# - Исключения - -1 (минус 1) и nan - их рассмотрим в первую очередь.
# - Примем для категшоризации, что если клиент приорел один или 2 автомобиля в одной сделке - это физлицо, если более двух - автомобилей в одной сделке - это юрлицо.

# %%
data.loc[(data['тип_клиента'].isna()) & (data['количество'] == -1)]
# Out:
#         год   месяц    компания  бренд  модель модификация год_выпуска  \
# 25728  2019  Август  БИПЭК АВТО  Skoda  Superb         NaN        2019
#
#        страна_производитель вид_топлива  объём_двиг_л коробка_передач  \
# 25728  Республика Казахстан           p           2.0            AКПП
#
#       тип_привода   сегмент регион наименование_дилерского_центра тип_клиента  \
# 25728         AWD  E класс   Тараз               БИПЭК АВТО Тараз        None
#
#        количество  цена_usd  продажа_usd             область  \
# 25728        -1.0  35588.25    -35588.25  Жамбылская область
#
#           сегментация_2013 класс_2013 purpose_category drive_category
# 25728  Легковые автомобили    D класс             AКПП            AWD

# %% [markdown]
# Вероятно, это ошибка при заполнении и клиент приобрел 1 автомобиль. Исправим ошибку

# %%
data.loc[(data['тип_клиента'].isna()) & (data['количество'] == -1), 'количество'] = 1

# %%
data.loc[(data['тип_клиента'].isna()) & (data['количество'].isna())]
# Out:
#         год   месяц    компания  бренд    модель модификация год_выпуска  \
# 16741  2019  Август  БИПЭК АВТО    Kia  Sportage         NaN        2019
# 17368  2019  Август  БИПЭК АВТО   Lada    Granta         NaN        2019
# 18676  2019  Август  БИПЭК АВТО   Lada      XRAY         NaN        2018
# 37416  2019  Август  БИПЭК АВТО    UAZ      3909         NaN        2018
# 37727  2019  Август  БИПЭК АВТО    UAZ   Patriot         NaN        2018
# 38775  2019  Август  БИПЭК АВТО  Skoda    Kodiaq         NaN        2019
#
#        страна_производитель вид_топлива  объём_двиг_л коробка_передач  \
# 16741  Республика Казахстан           p           2.0            AКПП
# 17368  Республика Казахстан           p           1.6            AКПП
# 18676  Республика Казахстан           p           1.6            МКПП
# 37416  Республика Казахстан           p           2.7            МКПП
# 37727  Республика Казахстан           p           2.7            МКПП
# 38775  Республика Казахстан           p           2.0            AКПП
#
#       тип_привода                сегмент      регион  \
# 16741         AWD        Компактные SUV    Караганда
# 17368         FWD               B класс       Алматы
# 18676         FWD               B класс    Экибастуз
# 37416         AWD  Развозные автомобили       Алматы
# 37727         AWD    Полноразмерные SUV        Семей
# 38775         AWD       Стандартные SUV   Нур-Султан
#
#       наименование_дилерского_центра тип_клиента  количество  цена_usd  \
# 16741           БИПЭК АВТО Караганда        None         NaN   20700.0
# 17368              БИПЭК АВТО Алматы        None         NaN    7100.0
# 18676           БИПЭК АВТО Экибастуз        None         NaN   13800.0
# 37416              БИПЭК АВТО Алматы        None         NaN   11200.0
# 37727               БИПЭК АВТО Семей        None         NaN   13800.0
# 38775              БИПЭК АВТО Астана        None         NaN   40000.0
#
#        продажа_usd                         область         сегментация_2013  \
# 16741          0.0          Карагандинская область             Внедорожники
# 17368          0.0                        г.Алматы      Легковые автомобили
# 18676          0.0            Павлодарская область      Легковые автомобили
# 37416          0.0                        г.Алматы  Коммерческие автомобили
# 37727          0.0  Восточно-Казахстанская область             Внедорожники
# 38775          0.0                    г.Нур-Султан             Внедорожники
#
#                  класс_2013 purpose_category drive_category
# 16741        Компактные SUV             AКПП            AWD
# 17368               B класс             AКПП            FWD
# 18676               B класс             МКПП            FWD
# 37416  Развозные автомобили             МКПП            AWD
# 37727   Среднеразмерные SUV             МКПП            AWD
# 38775    Полноразмерные SUV             AКПП            AWD

# %% [markdown]
# - 6 различных автомобилей
# - проданы в разных регионах
# - проданы одной компанией
# - для решения обратимся к цене: сравним цену конкретной сделки со средней ценой на автомобиль этой марки

# %%
# создадим список моделей
roll_models = data.loc[(data['тип_клиента'].isna()) & (data['количество'].isna()), 'модель'].tolist()

# %%
# список индексов для последующей проверки
roll_index = data.loc[(data['тип_клиента'].isna()) & (data['количество'].isna())].index.tolist()
roll_index
# Out:
# [16741, 17368, 18676, 37416, 37727, 38775]

# %%
for i in data.loc[(data['тип_клиента'].isna()) & (data['количество'].isna()), 'модель'].tolist():

    # определим переменную t как отношение стоимости продажи в сделке к модальной величине цены данной модели
    # Округлим t в меньшую сторону
    t = math.floor((data.loc[(data['модель'] == i) , 'продажа_usd'].mean() / \
        data.loc[(data['тип_клиента'].isna()) & (data['количество'].isna()) & (data['модель'] == i), 'цена_usd']\
        .mode()[0]))#.astype(int)
    print(t)
    # подставим значение t в пропущенные ячейки количества проданных автомашин
    data.loc[(data['тип_клиента'].isna()) & (data['количество'].isna()) & (data['модель'] == i), 'количество'] = t
    '''if  t < 2:
        print("\033[94m""Автомобиль", i, 'продан в 1 экземпляре,'"\033[1m" ' клиент - физлицо'"\033[0m’")
    elif t < 3:
        print("\033[94m""Автомобиль", i, 'продан в 2 экземплярах,'"\033[1m" ' клиент - физлицо'"\033[0m’")
    else:
        print("\033[93m""Автомобиль", i, 'продан БОЛЕЕ, чем в 2-х экземпляре,'"\033[1m"' клиент - юрлицо' '\033[0m')
        '''
# Out:
# 2
# 8
# 1
# 1
# 1
# 1

# %% [markdown]
# Проверим

# %%
for i in roll_index:
    #display(data.query('index == @i')['количество'][0])
    display(data.loc[(data.index == i),'количество'])
# Out:
# 16741    2.0
# Name: количество, dtype: float64
# 17368    8.0
# Name: количество, dtype: float64
# 18676    1.0
# Name: количество, dtype: float64
# 37416    1.0
# Name: количество, dtype: float64
# 37727    1.0
# Name: количество, dtype: float64
# 38775    1.0
# Name: количество, dtype: float64

# %% [markdown]
# #### Обработаем пропущенные значения в столбце `тип_клиента`
# Для пропущенных значений установим `тип_клиента`:
# - если в строке `количество` равно 1 или 2 -присвоим `тип_клиента` - Физлицо
# - если в строке `количество` более 2 -присвоим `тип_клиента` - Юрлицо

# %%
data.loc[(data['тип_клиента'].isna()) & (data['количество'] <= 2), 'тип_клиента'] = 'Физлицо'
data.loc[(data['тип_клиента'].isna()) & (data['количество'] > 2), 'тип_клиента'] = 'Юрлицо'

# %% [markdown]
# ### Обработка данных в столбце `наименование_дилерского_центра`
# Выведем на экран уникальные значения, указанные в столбце `наименование_дилерского_центра`

# %%
(data.наименование_дилерского_центра.unique().astype(str))
# Out:
# array(['Mercur Auto Алматы', 'Mercur Auto Астана',
#        'Автоцентр-Бавария Астана', 'Автоцентр-Бавария Алматы',
#        'Автоцентр Бавария Восток', 'ЖАЙЫК HYUNDAI MOTORS',
#        'Hyundai Auto Kostanai', 'БИПЭК АВТО Костанай',
#        'БИПЭК АВТО Астана', 'БИПЭК АВТО Павлодар', 'БИПЭК АВТО Алматы',
#        'БИПЭК АВТО Семей', 'БИПЭК АВТО Шымкент', 'БИПЭК АВТО Актау',
#        'БИПЭК АВТО Усть-Каменогорск', 'БИПЭК АВТО Атырау',
#        'БИПЭК АВТО Актобе', 'БИПЭК АВТО Уральск', 'БИПЭК АВТО Караганда',
#        'БИПЭК АВТО Петропавловск', 'Вираж Алматы', 'Вираж Кокшетау',
#        'Вираж Уральск', 'Вираж Петропавловск', 'Вираж Павлодар',
#        'Вираж Караганда', 'Вираж Астана', 'Вираж Костанай', 'Вираж Актау',
#        'Вираж Усть-Каменогорск', 'Вираж Актобе', 'Вираж Атырау',
#        'Вираж Шымкент', 'Вираж Семей', 'Вираж Рудный', 'Вираж Кызылорда',
#        'Вираж Тараз', 'Cadillac Almaty', 'Daewoo Bus Kazakhstan',
#        'Авто Сити', 'Ford Атырау', 'Меридиан АВТО Алматы', 'СемАЗ',
#        'Меридиан АВТО Актау', 'Вираж Талдыкорган', 'Hyundai Auto Almaty',
#        'Hyundai Premium Almaty', 'Hyundai Premium Astana',
#        'Aktobe Hyundai Motors', 'HYUNDAI AUTO ASTANA',
#        'Astana Motor Aktau', 'Hyundai Center Pavlodar', 'Best-Avto',
#        'Hyundai Center Shimkent', 'Caspi Auto Атырау',
#        'Hyundai Center Kokshetau', 'Автомир-Центр Караганда',
#        'Hyundai Center Petropavlovsk', 'Hyundai Центр Жетысу',
#        'Тенгри-Авто', 'Hyundai Center Taraz', 'Кол Авто',
#        'Eurasia Motor Шымкент', 'Eurasia Motor Павлодар', 'Semey Motors',
#        'Astana Motors', 'Автомир-Центр Алматы', 'Терра Моторс',
#        'CBC Алматы', 'Allur Auto Almaty', 'Автоцентр Бахус',
#        'Allur Auto Astana', 'КазБелЛизинг', 'Костанай КазБелАз',
#        'Автодом Костанай', 'Рус-Моторс', 'Камкор-Авто Павлодар',
#        'ВИВАГА ЛАДА', 'Allur Auto Кызылорда', 'Автокомплекс Тарлан',
#        'Автогранд Актау', 'Auto trader', 'Sky-Авто', 'Nord MMC',
#        'Тенке Капитал', 'AST-commerce', 'Allur Auto Shymkent ',
#        'Allur Auto Костанай', 'Allur Auto Kokshetau',
#        'Allur Auto Petropavlovsk ', 'Allur Auto Pavlodar ',
#        'Allur Auto Karaganda', 'Allur Auto Atyrau ',
#        'Allur Auto Ust-Kamenogorsk ', 'Allur Auto Актобе',
#        'Allur Auto Taraz', 'Allur Auto Rus', 'Eurasia Motor Атырау',
#        'ЭКСПОРТ', 'Almaty Motors Premium', 'Алматинский Автоцентр КАМАЗ',
#        'ЗапКазКАМАЗ -Актобе', 'Российские Грузовики Астана',
#        'Актауский Автоцентр КАМАЗ', 'Акмолинский Автоцентр КАМАЗ',
#        'Уральский АЦ КАМАЗ', 'CBC Астана', 'Вис Петропавловск',
#        'Камаз Евро Сервис ', 'Автотрейд К', 'Карагандинский АЦ КАМАЗ ',
#        'Атырауский АЦ КАМАЗ', 'Костанайский АЦ КАМАЗ',
#        'БИПЭК АВТО Кызылорда', 'БИПЭК АВТО Кокшетау', 'БИПЭК АВТО Тараз',
#        'БИПЭК АВТО Талдыкорган', 'БИПЭК АВТО Каскелен',
#        'БИПЭК АВТО Экибастуз', 'БИПЭК АВТО Риддер', 'Лексус Астана',
#        'Лексус Алматы', 'Лексус Актобе', 'Лексус Шымкент',
#        'Лексус Бишкек', 'Toyota Motor Kazakhstan', 'Урал-Кров Авто',
#        'AutoGood Караганда', 'ABS-INVEST', 'Shym Auto',
#        'Автомир-Центр Астана', 'Blue Star of Kazakhstan',
#        'Gold Star Motors', 'West Star Motors', 'Митсубиши Центр Астана',
#        'Nissan Centr Уральск', 'А-Моторс Авто', 'ASTER AUTO Алматы',
#        'ASTER AUTO Шымкент', 'Сары Арка Павлодар', 'Сары Арка',
#        'Eurasia Motor Актау', 'Автоцентр Астэк', 'Nissan Center Уральск',
#        'Lion AutoCenter Almaty', 'Porsche Centre Almaty',
#        'Mitsubishi Centr Костанай', 'Автоцентр Tosa', 'Жана SUZUKI',
#        'ALAN MOTORS', 'Арыстан Моторс', 'Eurasia Motors Uralsk',
#        'Alan Motors Trade', 'Фаворит Моторс', 'Лекс-Авто',
#        'ALAN MOTORS\xa0Усть-Каменогорск', 'Lex Auto',
#        'Eurasia Motor Zhaik', 'Auto Trader ', 'AutoAmir ',
#        'Toyota City Астана', 'Avenue Motors', 'Равон Моторс',
#        'Равон Моторс Алматы', 'Кристалл Авто Кызылорда',
#        'Равон Моторс Сарыагаш', 'Равон Моторс Костанай',
#        'СарыаркаАвтоПром', 'Кристалл Авто Астана',
#        'Кристалл Авто Караганда', 'Scania Central Asia Алматы',
#        'Subaru Motor Karagandy', 'Subaru Motor Astana',
#        'Subaru Motor Almaty', 'ASTER AUTO CЕМЕЙ', 'Das Auto',
#        'Тойота Центр Шымкент', 'Тойота Центр Шыгыс', 'Тойота Центр Орал',
#        'Тойота Центр Павлодар', 'Тойота Центр Костанай',
#        'Тойота Центр Караганды', 'Тойота Центр Жетысу',
#        'Тойота Центр Атырау', 'Тойота Центр Астана',
#        'Тойота Центр Алматы', 'Тойота Центр Актобе', 'Тойота Центр Актау',
#        'Toyota City', 'Toyota City Алматы', 'Тойота Центр Бишкек',
#        'Mercur Auto Атырау', 'VOLVO CAR ALMATY', 'Hino Motors Kazakhstan',
#        'КВЦ-Авто Костанай', 'КВЦ-АВТО Астана', 'КазАгроФинанс',
#        'КВЦ-АВТО Алматы', 'КВЦ-АВТО Караганда', 'КВЦ-Авто Тараз',
#        'Меридиан АВТО Астана', 'Меридиан АВТО Караганда',
#        'Меридиан АВТО Шымкент', 'СемАЗ Тараз', 'СемАЗ Кызылорда'],
#       dtype='<U28')

# %% [markdown]
# Дублируются названия двух дилерских центров:
#
# - 'Nissan Center Уральск' и  'Nissan Centr Уральск'
# - 'Auto Trader ' и  'Auto trader'
#
# Исправим

# %%
data.loc[(data['наименование_дилерского_центра'] == "Nissan Centr Уральск"), 'наименование_дилерского_центра'] = \
    "Nissan Center Уральск"
data.loc[(data['наименование_дилерского_центра'] == "Auto trader"), 'наименование_дилерского_центра'] = \
    "Auto Trader "
data.loc[(data['наименование_дилерского_центра'] == "Auto Trader "), 'наименование_дилерского_центра'] = \
    "Auto Trader"

# %% [markdown]
# ### Проверка по итогу обработки данных

# %% [markdown]
# Удалим созданные ранее временные столбцы:

# %%
colms_1 = data.columns
# Номера столбцов под удаление
colms_to_delete = [-2,-1]

# %%
for i in colms_to_delete:
    data = data.drop(colms_1[i], axis=1)
#data.columns

# %%
data.columns
# Out:
# Index(['год', 'месяц', 'компания', 'бренд', 'модель', 'модификация',
#        'год_выпуска', 'страна_производитель', 'вид_топлива', 'объём_двиг_л',
#        'коробка_передач', 'тип_привода', 'сегмент', 'регион',
#        'наименование_дилерского_центра', 'тип_клиента', 'количество',
#        'цена_usd', 'продажа_usd', 'область', 'сегментация_2013', 'класс_2013'],
#       dtype='object')

# %% [markdown]
# Проверим долю пустых значений

# %%
display(round(data.isna().mean() * 100).astype(int))
# Out:
# год                                0
# месяц                              0
# компания                           0
# бренд                              0
# модель                             0
# модификация                        9
# год_выпуска                        1
# страна_производитель               0
# вид_топлива                        0
# объём_двиг_л                       0
# коробка_передач                    0
# тип_привода                        0
# сегмент                           17
# регион                             0
# наименование_дилерского_центра     0
# тип_клиента                        0
# количество                         0
# цена_usd                           0
# продажа_usd                        0
# область                            0
# сегментация_2013                   0
# класс_2013                         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['год', 'месяц', 'компания', 'бренд', 'модель', 'модификация',
#        'год_выпуска', 'страна_производитель', 'вид_топлива', 'объём_двиг_л',
#        'коробка_передач', 'тип_привода', 'сегмент', 'регион',
#        'наименование_дилерского_центра', 'тип_клиента', 'количество',
#        'цена_usd', 'продажа_usd', 'область', 'сегментация_2013', 'класс_2013'],
#       dtype='object')

# %% [markdown]
# Пустые (пропушенные) значения остались в столбцах 'модификация', 'год_выпуска', 'сегмент'.
# - из столбца 'модификация' мы уже получили возможные данные по типу привода и коробке передач и модем удалить этот столбец
# - столбец 'сегмент' содержит очень много уникальных значений. Информация в столбце 'класс_2013' менее подробная, но содержит достаточно значений для категоризации. Можем удалить столбец 'сегмент'
# - столбец 'год_выпуска' содержит 1% пропущенных значений У нас нет осеований для его заполнения Оставим значения в нем как есть

# %% [markdown]
# Удалим столбцы 'модификация', 'сегмент'

# %%
colms_1
# Out:
# Index(['год', 'месяц', 'компания', 'бренд', 'модель', 'модификация',
#        'год_выпуска', 'страна_производитель', 'вид_топлива', 'объём_двиг_л',
#        'коробка_передач', 'тип_привода', 'сегмент', 'регион',
#        'наименование_дилерского_центра', 'тип_клиента', 'количество',
#        'цена_usd', 'продажа_usd', 'область', 'сегментация_2013', 'класс_2013',
#        'purpose_category', 'drive_category'],
#       dtype='object')

# %%
# Номера столбцов под удаление
colms_to_delete_2 = [5, 12]

# %%
for i in colms_to_delete_2:
    data = data.drop(colms_1[i], axis=1)
#data.columns

# %% [markdown]
# ### Сегментация по объему двигателя

# %% [markdown]
# Согласно [Большой российской энциклопедии](https://old.bigenc.ru/technology_and_technique/text/2136799) в России существует классификация легковых автомобилей в зависимости от объема двигателя.  Выглядит она нижеследующим образом. К таблице для экономии места добавим столбец со значениями от 1 до 4, соответствующие классу двигателя:
#
# |Класс	|Объём двигателя, дм3 (литров)|Цифровое обозначение|
# |:---|:---:|:---:|
# Малый	|До 1,2 |1
# Средний |От 1,2 до 1,8 |2
# Большой |От 1,8 до 3,5 |3
# Высший	|Свыше 3,5 |4
#
#  В исследуемом датафрейме отнесем к легковым автомобилям все уникальные значения столбца `сегментация_2013` за исключение значения 'Коммерческие автомобили'

# %% [markdown]
# Для грузового транспорта интернет не выдает данные по заппросу о классификации по объему двигателя. Произведем такую классификацию самостоятельно и разобьем данные на три пропорциональные категории:
#
# |Класс	|Объём двигателя, дм3 (литров)|Цифровое обозначение|
# |:---|:---:|:---:|
# Мал_груз	|До 2,5 | 11
# Сред_груз |От 2,5 до 4| 12
# Бол_груз |От 4 до 6 | 13
# Выс_груз |От 6 | 14

# %%
data.loc[(data['сегментация_2013'] != "Коммерческие автомобили") &\
            (data['объём_двиг_л'] > 0) & (data['объём_двиг_л'] < 1.2), 'класс_двигателя'] = 1
data.loc[(data['сегментация_2013'] != "Коммерческие автомобили") &\
            (data['объём_двиг_л'] >= 1.2) & (data['объём_двиг_л'] < 1.8), 'класс_двигателя'] = 2
data.loc[(data['сегментация_2013'] != "Коммерческие автомобили") &\
            (data['объём_двиг_л'] >= 1.8) & (data['объём_двиг_л'] < 3.5), 'класс_двигателя'] = 3
data.loc[(data['сегментация_2013'] != "Коммерческие автомобили") &\
            (data['объём_двиг_л'] >= 3.5), 'класс_двигателя'] = 4

# %%
data.loc[(data['сегментация_2013'] == "Коммерческие автомобили") &\
            (data['объём_двиг_л'] > 0) & (data['объём_двиг_л'] < 2.5), 'класс_двигателя'] = 11
data.loc[(data['сегментация_2013'] == "Коммерческие автомобили") &\
            (data['объём_двиг_л'] >= 2.5) & (data['объём_двиг_л'] < 4), 'класс_двигателя'] = 12
data.loc[(data['сегментация_2013'] == "Коммерческие автомобили") &\
            (data['объём_двиг_л'] >= 4) & (data['объём_двиг_л'] < 6), 'класс_двигателя'] = 13
data.loc[(data['сегментация_2013'] == "Коммерческие автомобили") &\
            (data['объём_двиг_л'] >= 6), 'класс_двигателя'] = 14

# %%
data.вид_топлива.unique()
# Out:
# array(['p', 'd', 'g', 'e'], dtype=object)

# %% [markdown]
# ### Приведем названия стран к буквенному коду
# Для повышения скорости обработки данных приведем названия стран к буквенному коду [Общероссийского классификатора стран мира](https://classifikators.ru/oksm#download)

# %%
#oksm = pd.read_excel('oksm.xlsx', header = [6])

# %%
oksm = pd.read_html('https://classifikators.ru/oksm#download', header = 1)[0]

# %%
oksm.head(10)
# Out:
#     №  Код             Краткое                                         Полное  \
# 0   1    4          АФГАНИСТАН    Переходное Исламское Государство Афганистан
# 1   2    8             АЛБАНИЯ                             Республика Албания
# 2   3   10          АНТАРКТИДА                                            NaN
# 3   4   12               АЛЖИР  Алжирская Народная Демократическая Республика
# 4   5   16  АМЕРИКАНСКОЕ САМОА                                            NaN
# 5   6   20             АНДОРРА                              Княжество Андорра
# 6   7   24              АНГОЛА                              Республика Ангола
# 7   8   28   АНТИГУА И БАРБУДА                                            NaN
# 8   9   31         АЗЕРБАЙДЖАН                         Республика Азербайджан
# 9  10   32           АРГЕНТИНА                        Аргентинская Республика
#
#   Альфа-2 Альфа-3
# 0      AF     AFG
# 1      AL     ALB
# 2      AQ     ATA
# 3      DZ     DZA
# 4      AS     ASM
# 5      AD     AND
# 6      AO     AGO
# 7      AG     ATG
# 8      AZ     AZE
# 9      AR     ARG

# %%
oksm['Краткое'] = oksm['Краткое'].str.lower()
oksm['Полное'] = oksm['Полное'].str.lower()

# %%
data['страна_производитель'].unique()
# Out:
# array(['Германия', 'США', 'Австрия', 'Республика Казахстан',
#        'Российская Федерация', 'Корея', 'Япония', 'Таиланд', 'Китай',
#        'UK', 'Узбекистан', 'Венгрия', 'Турция', 'Испания', 'Нидерланды',
#        'Польша', 'Швеция', 'Белоруссия', 'Бельгия'], dtype=object)

# %% [markdown]
# Зададим списки для сопоставления.
# kod_roll - список названий стран, приведенных к нижнему регистру, из столбца 'Краткое название' датафрейма `oksm`.
#
# old_roll - список названий стран, приведенных к нижнему регистру и с исключением слова `республика`, из столбца 'страна_производитель' датафрейма `data`

# %%
kod_roll = oksm['Краткое'].str.lower().tolist()
old_roll = data.страна_производитель.str.lower().str.replace('республика ', '').unique()

len(old_roll)
# Out:
# 19

# %% [markdown]
# Для сохранения кодового обозначения страны создадим столбец `код_страны`. Занесем в него значения из столбца `страна_производитель`

# %%
data['код_страны'] = data['страна_производитель']

# %% [markdown]
# Для удобства сравнения приведем названия стран в столбце `страна_производитель` к нижнему регистру. Также удалим из названий стран слово `республика`

# %%
data.страна_производитель = data.страна_производитель.str.lower().str.replace('республика ', '')

# %%
data.код_страны.unique()
# Out:
# array(['Германия', 'США', 'Австрия', 'Республика Казахстан',
#        'Российская Федерация', 'Корея', 'Япония', 'Таиланд', 'Китай',
#        'UK', 'Узбекистан', 'Венгрия', 'Турция', 'Испания', 'Нидерланды',
#        'Польша', 'Швеция', 'Белоруссия', 'Бельгия'], dtype=object)

# %% [markdown]
# Обратим внимание, что в списке кодов стран уже пристуствует один код  - это `UK`.

# %% [markdown]
# Сопоставим названия в списках  `old_roll` и `kod_roll`.
# При выявлении совпадения присвоим символьное обозначение для страны в колонку `код_страны` датафрейма `data`

# %%
sec_roll =[]

for i in old_roll:
    if i in kod_roll:
        n = oksm.loc[(oksm['Краткое'] == i), 'Альфа-2'].tolist()[0]
        data.loc[(data['страна_производитель'] == i), 'код_страны'] = n
        sec_roll.append(n)
    elif i in oksm['Полное'].str.lower().tolist():
        m = oksm.loc[(oksm['Полное'] == i), 'Альфа-2'].tolist()[0]
        data.loc[(data['страна_производитель'] == i), 'код_страны'] = m
        sec_roll.append(m)
print(sec_roll)
print(len(sec_roll))
# Out:
# ['DE', 'AT', 'KZ', 'RU', 'JP', 'TH', 'CN', 'UZ', 'HU', 'TR', 'ES', 'PL', 'SE', 'BE']
# 14

# %%
data['страна_производитель'].unique()
# Out:
# array(['германия', 'сша', 'австрия', 'казахстан', 'российская федерация',
#        'корея', 'япония', 'таиланд', 'китай', 'uk', 'узбекистан',
#        'венгрия', 'турция', 'испания', 'нидерланды', 'польша', 'швеция',
#        'белоруссия', 'бельгия'], dtype=object)

# %%
data.код_страны.unique()
# Out:
# array(['DE', 'США', 'AT', 'KZ', 'RU', 'Корея', 'JP', 'TH', 'CN', 'UK',
#        'UZ', 'HU', 'TR', 'ES', 'Нидерланды', 'PL', 'SE', 'Белоруссия',
#        'BE'], dtype=object)

# %% [markdown]
# Составим список `fogotten_contr` - страны, код которых не был идентифицирован.

# %%
fogotten_contr = []
for i in data.код_страны.unique():
    if i not in sec_roll:
        print(i)
        fogotten_contr.append(i)
fogotten_contr
# Out:
# США
# Корея
# UK
# Нидерланды
# Белоруссия
# ['США', 'Корея', 'UK', 'Нидерланды', 'Белоруссия']

# %% [markdown]
# Исключим из списка `UK` - этот код был изначально, его не нужно идентифицировать дополнительно.

# %%
fogotten_contr.pop(2)
# Out:
# 'UK'

# %% [markdown]
# (Вновь) приведем к нижнему регистру элементы списка `fogotten_contr`

# %%
fogotten_contr = list(map(str.lower,fogotten_contr))

# %%
fogotten_contr
# Out:
# ['сша', 'корея', 'нидерланды', 'белоруссия']

# %% [markdown]
# Найдем элементы в колонке 'Краткое название' датафрейма `oksm`, содержащие символы `кор` (от слова `Корея`) и  `нид` ( от слова `Нидерланды`

# %%
roll_4 = []
for i in range(len(oksm['Краткое'].tolist())):
    if "кор" in oksm['Краткое'].tolist()[i]:
    #n = oksm.loc[(oksm['Краткое название'] == i), 'Альфа-2'].tolist()[0]
    #print(data.loc[(data['страна_производитель'] == i), 'код_страны'])
    #data.loc[(data['страна_производитель'] == i), 'код_страны'] = n
        #print(oksm['Краткое название'].tolist()[i])
        roll_4.append(oksm['Краткое'].tolist()[i])
roll_4
# Out:
# ['корея, народно-демократическая республика',
#  'корея, республика',
#  'нидерланды, королевство',
#  'соединенное королевство великобритании и северной ирландии']

# %% [markdown]
# Составим словарь для замены названий стран , состоящих в списке `fogotten_contr`

# %%
fogotten_contr_dic = {'сша':'соединенные штаты',  'корея': roll_4[1], 'нидерланды': roll_4[2], 'белоруссия': 'беларусь'}
fogotten_contr_dic
# Out:
# {'сша': 'соединенные штаты',
#  'корея': 'корея, республика',
#  'нидерланды': 'нидерланды, королевство',
#  'белоруссия': 'беларусь'}

# %%
data['страна_производитель'].unique()
# Out:
# array(['германия', 'сша', 'австрия', 'казахстан', 'российская федерация',
#        'корея', 'япония', 'таиланд', 'китай', 'uk', 'узбекистан',
#        'венгрия', 'турция', 'испания', 'нидерланды', 'польша', 'швеция',
#        'белоруссия', 'бельгия'], dtype=object)

# %%
# Призведем замену названий оставшихся стран согласно словаря fogotten_contr_dic
for i in fogotten_contr:
    print(i)
    data.loc[(data['страна_производитель'] == i), 'страна_производитель'] = data['страна_производитель'].map(fogotten_contr_dic)
    #data['страна_производитель'] = data['страна_производитель'].map(fogotten_contr_dic)
# Out:
# сша
# корея
# нидерланды
# белоруссия

# %%
rolling = ['соединенные штаты', roll_4[1], roll_4[2], 'беларусь']

# %%
for i in data.страна_производитель.unique():
    if i in kod_roll:
        n = oksm.loc[(oksm['Краткое'] == i), 'Альфа-2'].tolist()[0]
        data.loc[(data['страна_производитель'] == i), 'код_страны'] = n
        #sec_roll.append(n)
print(sorted(sec_roll) )
# Out:
# 100%|██████████| 19/19 [00:00<00:00, 330.13it/s]
# ['AT', 'BE', 'CN', 'DE', 'ES', 'HU', 'JP', 'KZ', 'PL', 'RU', 'SE', 'TH', 'TR', 'UZ']

# %% [markdown]
# Проверим полноту символов в клонке и количество уникальных символов

# %%
data.код_страны.unique()
# Out:
# array(['DE', 'US', 'AT', 'KZ', 'RU', 'KR', 'JP', 'TH', 'CN', 'UK', 'UZ',
#        'HU', 'TR', 'ES', 'NL', 'PL', 'SE', 'BY', 'BE'], dtype=object)

# %%
len(data.код_страны.unique())
# Out:
# 19

# %% [markdown]
# Пропущенные значения отсутствуют. Количество символов соответствует количеству стран

# %% [markdown]
# <div style="border-radius: 45px;border:solid blue 7px; padding: 40px">
#
# На этом приведение названий стран к буквенному коду завершено

# %% [markdown]
# ### Создадим столбец, объединяющую номер месяца и год

# %% [markdown]
# Создадим словарь `dict_monthes`

# %%
dict_monthes = {
    'Январь':1,
'Февраль':2,
'Март':3,
'Апрель':4,
'Май':5,
'Июнь':6,
'Июль':7,
'Август':8,
'Сентябрь':9,
'Октябрь':10,
'Ноябрь':11,
'Декабрь':12
}

# %% [markdown]
# Произведем замену

# %%
data['месяц'] = data['месяц'].map(dict_monthes)

# %% [markdown]
# Объединим месяц и год в новом столбце `дата` и преобразуем его в формат дата-время `datetime`

# %%
data['дата'] = data['месяц'].map(str) + '-' + data['год'].map(str)
data['дата'] = pd.to_datetime(data['дата'])

# %% [markdown]
# ### Устраним дубликаты в названиях компаний

# %% [markdown]
# Посмотрим названия компаний и увидим ряд дубликатов.
# Сведем дубликаты в список `duplicated_comp`.
# Для заменя дубликатов создадим словарь `dict_comp_names`

# %%
(data.компания.unique())
# Out:
# array(['Mercur Auto', 'Автоцентр-Бавария', 'БИПЭК АВТО', 'Вираж',
#        'Eurasia Motor Premium', 'Daewoo Bus Kazakhstan', 'Caspian Motors',
#        'Каспиан Моторс', 'СемАЗ', 'Astana Motors', 'Astana Motors ',
#        'Hyundai Com Trans Kazakhstan ', 'Nissan Manufacturing RUS',
#        'СВС-ТРАНС', 'Allur Auto', 'Almaty Motors Premium', 'TERRA MOTORS',
#        'ТК КАМАЗ', 'Toyota Motor Kazakhstan', 'Лифан Моторс Рус',
#        'MAN Truck & Bus Kazakhstan', 'Автомир ГК', 'Autokapital',
#        'Автокапитал', 'ММС Рус', 'MMC RUS', 'Mercur Autos',
#        'УзАвто-Казахстан', 'Равон Моторс Казахстан',
#        'Ravon Motors Kazakstan', 'Renault Россия', 'Scania Central Asia',
#        'Subaru Kazakhstan', 'Volkswagen Group Rus', 'Автодом Motors KST',
#        'Автомир-Центр', 'ТОО "Eurasia Motor Zhaik"',
#        'Scandinavian Motors', 'Хино Моторс Казахстан', 'Hino Motors '],
#       dtype=object)

# %%
duplicated_comp = [
        'Astana Motors ','Hino Motors ','Mercur Autos','Каспиан Моторс','ММС Рус','Autokapital','Равон Моторс Казахстан'
]

# %%
dict_comp_names = {
    'Astana Motors ': 'Astana Motors',
'Hino Motors ':'Хино Моторс Казахстан',
'Mercur Autos':'Mercur Auto',
'Каспиан Моторс':'Caspian Motors',
'ММС Рус': 'MMC RUS',
'Autokapital':'Автокапитал',
'Равон Моторс Казахстан':'Ravon Motors Kazakstan'
}

# %%
# Призведем замену дубликатов компаний
for i in duplicated_comp:
    #print(i)
    data.loc[(data['компания'] == i), 'компания'] = \
        data['компания'].map(dict_comp_names)

# %%
data
# Out:
#         год  месяц     компания  бренд  модель год_выпуска  \
# 0      2019      5  Mercur Auto   Audi      A3        2018
# 1      2019      8  Mercur Auto   Audi      A3        2018
# 2      2019      4  Mercur Auto   Audi      A4        2018
# 3      2019      7  Mercur Auto   Audi      A4        2018
# 4      2019      7  Mercur Auto   Audi      A4        2018
# ...     ...    ...          ...    ...     ...         ...
# 39961  2019      9     ТК КАМАЗ  KAMAZ  58815Z        2019
# 39962  2019      9     ТК КАМАЗ  KAMAZ  58815Z        2019
# 39963  2019      9     ТК КАМАЗ  KAMAZ  58815Z        2019
# 39964  2019      9     ТК КАМАЗ  KAMAZ  58815Z        2019
# 39965  2019      9     ТК КАМАЗ  KAMAZ  58815Z        2019
#
#       страна_производитель вид_топлива  объём_двиг_л коробка_передач  \
# 0                 германия           p           1.4            AКПП
# 1                 германия           p           1.4            AКПП
# 2                 германия           p           1.4            AКПП
# 3                 германия           p           1.4            AКПП
# 4                 германия           p           1.4            AКПП
# ...                    ...         ...           ...             ...
# 39961            казахстан           d           2.5            МКПП
# 39962            казахстан           d           2.5            МКПП
# 39963            казахстан           d           2.5            МКПП
# 39964            казахстан           d           2.5            МКПП
# 39965            казахстан           d           2.5            МКПП
#
#       тип_привода  регион наименование_дилерского_центра тип_клиента  \
# 0             FWD  Алматы             Mercur Auto Алматы     Физлицо
# 1             FWD  Алматы             Mercur Auto Алматы      Юрлицо
# 2             FWD  Алматы             Mercur Auto Алматы     Физлицо
# 3             FWD  Алматы             Mercur Auto Алматы      Юрлицо
# 4             FWD  Алматы             Mercur Auto Алматы     Физлицо
# ...           ...     ...                            ...         ...
# 39961         RWD  Актобе            ЗапКазКАМАЗ -Актобе      Юрлицо
# 39962         RWD  Актобе            ЗапКазКАМАЗ -Актобе      Юрлицо
# 39963         RWD  Актобе            ЗапКазКАМАЗ -Актобе      Юрлицо
# 39964         RWD  Актобе            ЗапКазКАМАЗ -Актобе      Юрлицо
# 39965         RWD  Актобе            ЗапКазКАМАЗ -Актобе      Юрлицо
#
#        количество     цена_usd  продажа_usd              область  \
# 0             1.0  28115.00000  28115.00000             г.Алматы
# 1             1.0  32246.99000  32246.99000             г.Алматы
# 2             1.0  32000.00000  32000.00000             г.Алматы
# 3             1.0  31929.00000  31929.00000             г.Алматы
# 4             1.0  31929.00000  31929.00000             г.Алматы
# ...           ...          ...          ...                  ...
# 39961         1.0  48756.92071  48756.92071  Актюбинская область
# 39962         1.0  48756.92071  48756.92071  Актюбинская область
# 39963         1.0  48756.92071  48756.92071  Актюбинская область
# 39964         1.0  48756.92071  48756.92071  Актюбинская область
# 39965         1.0  48756.92071  48756.92071  Актюбинская область
#
#               сегментация_2013                 класс_2013  класс_двигателя  \
# 0          Легковые автомобили                    C класс              2.0
# 1          Легковые автомобили                    C класс              2.0
# 2          Легковые автомобили                    D класс              2.0
# 3          Легковые автомобили                    D класс              2.0
# 4          Легковые автомобили                    D класс              2.0
# ...                        ...                        ...              ...
# 39961  Коммерческие автомобили  Крупнотоннажные грузовики             12.0
# 39962  Коммерческие автомобили  Крупнотоннажные грузовики             12.0
# 39963  Коммерческие автомобили  Крупнотоннажные грузовики             12.0
# 39964  Коммерческие автомобили  Крупнотоннажные грузовики             12.0
# 39965  Коммерческие автомобили  Крупнотоннажные грузовики             12.0
#
#       код_страны       дата
# 0             DE 2019-05-01
# 1             DE 2019-08-01
# 2             DE 2019-04-01
# 3             DE 2019-07-01
# 4             DE 2019-07-01
# ...          ...        ...
# 39961         KZ 2019-09-01
# 39962         KZ 2019-09-01
# 39963         KZ 2019-09-01
# 39964         KZ 2019-09-01
# 39965         KZ 2019-09-01
#
# [39966 rows x 23 columns]

# %% [markdown]
# ### Округлим данные в столбцах 'цена_usd', 'продажа_usd' до целых значений

# %%
data[['цена_usd', 'продажа_usd']] = data[['цена_usd', 'продажа_usd']].astype(int)

# %% [markdown]
# ### Изменим порядок столбцов

# %%
second_cols = ['год', 'месяц', 'дата', 'компания', 'бренд', 'модель', 'год_выпуска',
       'страна_производитель', 'код_страны', 'вид_топлива', 'объём_двиг_л',
       'класс_двигателя', 'коробка_передач', 'тип_привода', 'регион', 'область',
       'наименование_дилерского_центра', 'тип_клиента', 'количество',
       'цена_usd', 'продажа_usd', 'сегментация_2013', 'класс_2013']

# %%
#change order of columns by name
data = data[second_cols]

# %% [markdown]
# ### Данные обработаны и мы можем провести исследование и анализ.
# Мы выгрузим данные в форматах .csv и .xlsx в том числе для их чтения в редакторе Excel.
#
# Для удобства пользования файлом .xlsx после выгрузки осуществим сортировку данных в следующем порядке:
# - год
# - месяц
# - компания
# - бренд
# - модель
# - год_выпуска

# %%
data.columns
# Out:
# Index(['год', 'месяц', 'дата', 'компания', 'бренд', 'модель', 'год_выпуска',
#        'страна_производитель', 'код_страны', 'вид_топлива', 'объём_двиг_л',
#        'класс_двигателя', 'коробка_передач', 'тип_привода', 'регион',
#        'область', 'наименование_дилерского_центра', 'тип_клиента',
#        'количество', 'цена_usd', 'продажа_usd', 'сегментация_2013',
#        'класс_2013'],
#       dtype='object')

# %%
data = data.sort_values(['год', 'месяц', 'компания', 'бренд', 'модель', 'год_выпуска']).reset_index(drop = True)

# %% [markdown]
# #### Выгрузим файл в папку в формате Excel в корневую папку
# Воспользуемся функцией `to_excel()` библиотеки `openpyxl`.
#
# Вызовем функцию `df_download`для выгрузки файлов в форматах:
# - .csv
# - .xlsx

# %%
# %time df_download(data, "kz_automarket_2019.xlsx", 'kz_automarket_2019.csv')
# Out:
# Выгружен файл  kz_automarket_2019.csv
# Выгружен файл  kz_automarket_2019.xlsx
# CPU times: user 19.7 s, sys: 437 ms, total: 20.2 s
# Wall time: 20.9 s
